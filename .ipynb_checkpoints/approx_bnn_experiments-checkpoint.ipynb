# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import random
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

from models import *
from utils import *
from train import *
from bvc import *
from gen_data import *

sns.set(font_scale=1.2)
seed = 1234
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## BNN Architectures

# %% [markdown]
# ### Feedforward BNN

# %%
X_train, Y_train = load_data('./data/', 'train_feedforward.pkl')
X_test, Y_test = load_data('./data/', 'test_feedforward.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_feedforward.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30,
    **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 5 layers, 128 hidden units, final eval loss: 337.57102584838875

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='feedforward_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='feedforward')

# %% [markdown]
# ####  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=2, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad(): 
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1), Y_test))

# %% [markdown]
# ### Residual BNN

# %%
X_train, Y_train = load_data('./data/', 'train_residual.pkl')
X_test, Y_test = load_data('./data/', 'test_residual.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_residual.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='residual_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='residual')

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=2, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1), Y_test))

# %% [markdown]
# ### Recurrent BNN

# %%
X_train, Y_train = load_data('./data/', 'train_recurrent.pkl')
X_test, Y_test = load_data('./data/', 'test_recurrent.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_recurrent.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
_X_train = X_train.view(-1, 16)
_Y_train = Y_train.view(-1, 16)
_X_test = X_test.view(-1, 16)
_Y_test = Y_test.view(-1, 16)

_train_dataset = BNN_Dataset(_X_train, _Y_train)
_train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

_test_dataset = BNN_Dataset(_X_test, _Y_test)
_test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_mlp_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_mlp')

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(_Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=_train_dataloader, test_loader=_test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:])) # visualise after training
# Out:
# Initial eval loss: 97.13646697998047
# Epoch 1: training loss 277.017902135849, eval loss 18.953993797302246. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 186.70098686218262, eval loss 18.439990043640137. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 181.18194198608398, eval loss 17.663910388946533. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 174.76826000213623, eval loss 17.33486247062683. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 172.85585403442383, eval loss 17.2236385345459. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 171.78336548805237, eval loss 17.12631630897522. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 170.82549333572388, eval loss 17.02446484565735. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 169.92324805259705, eval loss 16.96133828163147. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 169.25403332710266, eval loss 16.915497064590454. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 168.70635962486267, eval loss 16.84104633331299. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 168.2578248977661, eval loss 16.78542971611023. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 167.94520926475525, eval loss 16.783259868621826. Time elapsed: 0 h 0 m 2 s.
# Epoch 13: training loss 167.68077325820923, eval loss 16.73266291618347. Time elapsed: 0 h 0 m 2 s.
# Epoch 14: training loss 167.60155630111694, eval loss 16.735289573669434. Time elapsed: 0 h 0 m 2 s.
# Epoch 15: training loss 167.42604684829712, eval loss 16.733747243881226. Time elapsed: 0 h 0 m 2 s.
# Epoch 16: training loss 167.2549090385437, eval loss 16.727100372314453. Time elapsed: 0 h 0 m 2 s.
# Epoch 17: training loss 167.17780447006226, eval loss 16.725908994674683. Time elapsed: 0 h 0 m 3 s.
# Epoch 18: training loss 167.0714466571808, eval loss 16.71409583091736. Time elapsed: 0 h 0 m 3 s.
# Epoch 19: training loss 166.97673749923706, eval loss 16.71366024017334. Time elapsed: 0 h 0 m 3 s.
# Epoch 20: training loss 166.91340684890747, eval loss 16.709007263183594. Time elapsed: 0 h 0 m 3 s.
# Epoch 21: training loss 166.85382223129272, eval loss 16.701632261276245. Time elapsed: 0 h 0 m 3 s.
# Epoch 22: training loss 166.76609587669373, eval loss 16.70437216758728. Time elapsed: 0 h 0 m 4 s.
# Epoch 23: training loss 166.72550559043884, eval loss 16.694105625152588. Time elapsed: 0 h 0 m 4 s.
# Epoch 24: training loss 166.66915130615234, eval loss 16.69668960571289. Time elapsed: 0 h 0 m 4 s.
# Epoch 25: training loss 166.63981890678406, eval loss 16.68567395210266. Time elapsed: 0 h 0 m 4 s.
# Epoch 26: training loss 166.56898856163025, eval loss 16.68136692047119. Time elapsed: 0 h 0 m 4 s.
# Epoch 27: training loss 166.60489153862, eval loss 16.667527437210083. Time elapsed: 0 h 0 m 4 s.
# Epoch 28: training loss 166.47386479377747, eval loss 16.671674966812134. Time elapsed: 0 h 0 m 5 s.
# Epoch 29: training loss 166.47188520431519, eval loss 16.678348541259766. Time elapsed: 0 h 0 m 5 s.
# Epoch 30: training loss 166.46687531471252, eval loss 16.65501308441162. Time elapsed: 0 h 0 m 5 s.
# Epoch 31: training loss 166.41737842559814, eval loss 16.650935411453247. Time elapsed: 0 h 0 m 5 s.
# Epoch 32: training loss 166.3051290512085, eval loss 16.6738178730011. Time elapsed: 0 h 0 m 5 s.
# Epoch 33: training loss 166.37043452262878, eval loss 16.64845108985901. Time elapsed: 0 h 0 m 6 s.
# Epoch 34: training loss 166.26500391960144, eval loss 16.659609079360962. Time elapsed: 0 h 0 m 6 s.
# Epoch 35: training loss 166.30515789985657, eval loss 16.66153860092163. Time elapsed: 0 h 0 m 6 s.
# Epoch 36: training loss 166.25654315948486, eval loss 16.64940309524536. Time elapsed: 0 h 0 m 6 s.
# Epoch 37: training loss 166.22301363945007, eval loss 16.65719771385193. Time elapsed: 0 h 0 m 6 s.
# Epoch 38: training loss 166.1966507434845, eval loss 16.647186756134033. Time elapsed: 0 h 0 m 7 s.
# Epoch 39: training loss 166.17509698867798, eval loss 16.654640913009644. Time elapsed: 0 h 0 m 7 s.
# Epoch 40: training loss 166.16166639328003, eval loss 16.64376449584961. Time elapsed: 0 h 0 m 7 s.
# Epoch 41: training loss 166.14161705970764, eval loss 16.651806592941284. Time elapsed: 0 h 0 m 7 s.
# Epoch 42: training loss 166.11888122558594, eval loss 16.640469312667847. Time elapsed: 0 h 0 m 7 s.
# Epoch 43: training loss 166.08568024635315, eval loss 16.638089418411255. Time elapsed: 0 h 0 m 8 s.
# Epoch 44: training loss 166.08569359779358, eval loss 16.637268781661987. Time elapsed: 0 h 0 m 8 s.
# Epoch 45: training loss 166.0422420501709, eval loss 16.632017612457275. Time elapsed: 0 h 0 m 8 s.
# Epoch 46: training loss 166.0209391117096, eval loss 16.641650676727295. Time elapsed: 0 h 0 m 8 s.
# Epoch 47: training loss 166.00878047943115, eval loss 16.635116577148438. Time elapsed: 0 h 0 m 8 s.
# Epoch 48: training loss 166.00269556045532, eval loss 16.633801460266113. Time elapsed: 0 h 0 m 8 s.
# Epoch 49: training loss 165.98294925689697, eval loss 16.63248896598816. Time elapsed: 0 h 0 m 9 s.
# Epoch 50: training loss 165.95365953445435, eval loss 16.627520084381104. Time elapsed: 0 h 0 m 9 s.
# Training completed with final epoch loss 165.95365953445435. Time elapsed: 0 h 0 m 9 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(_X_test), _Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(_Y_test, dim=0).repeat([50000,1]), _Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(3.3255, device='cuda:0')
# Predicting mean MSE error on test set tensor(3.7158, device='cuda:0')

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_lstm_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_lstm')

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=7, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])
# Out:
# Initial eval loss: 611.4433288574219
# Epoch 1: training loss 2335.012689590454, eval loss 85.93816375732422. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 811.2748336791992, eval loss 77.15928936004639. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 751.4533176422119, eval loss 71.99549961090088. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 704.1851711273193, eval loss 68.26047897338867. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 678.1472940444946, eval loss 66.7960376739502. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 668.4779109954834, eval loss 66.16812992095947. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 662.3526668548584, eval loss 65.52876567840576. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 655.279990196228, eval loss 64.77088928222656. Time elapsed: 0 h 0 m 2 s.
# Epoch 9: training loss 647.5034198760986, eval loss 63.93972206115723. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 638.9517850875854, eval loss 63.076674461364746. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 630.5620183944702, eval loss 62.23571300506592. Time elapsed: 0 h 0 m 3 s.
# Epoch 12: training loss 622.2967100143433, eval loss 61.42776966094971. Time elapsed: 0 h 0 m 3 s.
# Epoch 13: training loss 614.8537702560425, eval loss 60.74635314941406. Time elapsed: 0 h 0 m 3 s.
# Epoch 14: training loss 608.5467309951782, eval loss 60.16716384887695. Time elapsed: 0 h 0 m 3 s.
# Epoch 15: training loss 603.3081789016724, eval loss 59.693241119384766. Time elapsed: 0 h 0 m 4 s.
# Epoch 16: training loss 599.0067949295044, eval loss 59.30289077758789. Time elapsed: 0 h 0 m 4 s.
# Epoch 17: training loss 595.3171520233154, eval loss 58.954522132873535. Time elapsed: 0 h 0 m 4 s.
# Epoch 18: training loss 591.9465074539185, eval loss 58.63192081451416. Time elapsed: 0 h 0 m 5 s.
# Epoch 19: training loss 588.7610387802124, eval loss 58.33049011230469. Time elapsed: 0 h 0 m 5 s.
# Epoch 20: training loss 585.7646389007568, eval loss 58.04825305938721. Time elapsed: 0 h 0 m 5 s.
# Epoch 21: training loss 583.0086221694946, eval loss 57.78887367248535. Time elapsed: 0 h 0 m 5 s.
# Epoch 22: training loss 580.4887313842773, eval loss 57.553789138793945. Time elapsed: 0 h 0 m 6 s.
# Epoch 23: training loss 578.1585760116577, eval loss 57.3282470703125. Time elapsed: 0 h 0 m 6 s.
# Epoch 24: training loss 575.9747877120972, eval loss 57.11993885040283. Time elapsed: 0 h 0 m 6 s.
# Epoch 25: training loss 573.9230127334595, eval loss 56.923556327819824. Time elapsed: 0 h 0 m 6 s.
# Epoch 26: training loss 571.9159708023071, eval loss 56.72300052642822. Time elapsed: 0 h 0 m 7 s.
# Epoch 27: training loss 569.9345178604126, eval loss 56.53184795379639. Time elapsed: 0 h 0 m 7 s.
# Epoch 28: training loss 568.0658960342407, eval loss 56.35591697692871. Time elapsed: 0 h 0 m 7 s.
# Epoch 29: training loss 566.3293180465698, eval loss 56.18760395050049. Time elapsed: 0 h 0 m 8 s.
# Epoch 30: training loss 564.6650543212891, eval loss 56.02582550048828. Time elapsed: 0 h 0 m 8 s.
# Epoch 31: training loss 563.079683303833, eval loss 55.87185478210449. Time elapsed: 0 h 0 m 8 s.
# Epoch 32: training loss 561.5771732330322, eval loss 55.72800159454346. Time elapsed: 0 h 0 m 8 s.
# Epoch 33: training loss 560.1699256896973, eval loss 55.59319496154785. Time elapsed: 0 h 0 m 9 s.
# Epoch 34: training loss 558.8696069717407, eval loss 55.46454334259033. Time elapsed: 0 h 0 m 9 s.
# Epoch 35: training loss 557.6451139450073, eval loss 55.3463830947876. Time elapsed: 0 h 0 m 9 s.
# Epoch 36: training loss 556.4991312026978, eval loss 55.23565864562988. Time elapsed: 0 h 0 m 10 s.
# Epoch 37: training loss 555.433271408081, eval loss 55.13215637207031. Time elapsed: 0 h 0 m 10 s.
# Epoch 38: training loss 554.4149227142334, eval loss 55.031535148620605. Time elapsed: 0 h 0 m 10 s.
# Epoch 39: training loss 553.4623184204102, eval loss 54.943464279174805. Time elapsed: 0 h 0 m 10 s.
# Epoch 40: training loss 552.5563974380493, eval loss 54.860114097595215. Time elapsed: 0 h 0 m 11 s.
# Epoch 41: training loss 551.7162580490112, eval loss 54.77638530731201. Time elapsed: 0 h 0 m 11 s.
# Epoch 42: training loss 550.8992357254028, eval loss 54.69507026672363. Time elapsed: 0 h 0 m 11 s.
# Epoch 43: training loss 550.1281204223633, eval loss 54.61650085449219. Time elapsed: 0 h 0 m 12 s.
# Epoch 44: training loss 549.391170501709, eval loss 54.546688079833984. Time elapsed: 0 h 0 m 12 s.
# Epoch 45: training loss 548.6780014038086, eval loss 54.4783878326416. Time elapsed: 0 h 0 m 12 s.
# Epoch 46: training loss 547.9906644821167, eval loss 54.41314506530762. Time elapsed: 0 h 0 m 12 s.
# Epoch 47: training loss 547.3019618988037, eval loss 54.34398174285889. Time elapsed: 0 h 0 m 13 s.
# Epoch 48: training loss 546.6389455795288, eval loss 54.27793025970459. Time elapsed: 0 h 0 m 13 s.
# Epoch 49: training loss 545.9436092376709, eval loss 54.20506191253662. Time elapsed: 0 h 0 m 13 s.
# Epoch 50: training loss 545.2203598022461, eval loss 54.13308620452881. Time elapsed: 0 h 0 m 14 s.
# Training completed with final epoch loss 545.2203598022461. Time elapsed: 0 h 0 m 14 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(10.8266, device='cuda:0')
# Predicting mean MSE error on test set tensor(16.4788, device='cuda:0')

# %% [markdown]
# ### Complex BNN

# %%
X_train, Y_train = load_data('./data/', 'train_complex.pkl')
X_test, Y_test = load_data('./data/', 'test_complex.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_complex.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
_X_train, _Y_train = X_train.view(-1, 16), Y_train.view(-1, 16)
_X_test, _Y_test = X_test.view(-1, 16), Y_test.view(-1, 16)
_X_valid, _Y_valid  = X_valid.view(-1, 16), Y_valid.view(-1, 16)

_train_dataset = BNN_Dataset(_X_train, _Y_train)
_train_dataloader = DataLoader(_train_dataset, batch_size=batch_size, shuffle=False)

_test_dataset = BNN_Dataset(_X_test, _Y_test)
_test_dataloader = DataLoader(_test_dataset, batch_size=batch_size, shuffle=False)

_valid_dataset = BNN_Dataset(_X_valid, _Y_valid)
_valid_dataloader = DataLoader(_valid_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.18239688873291, time elapsed: 0 h 3 m 18 s
# 2th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.221540927886963, time elapsed: 0 h 6 m 42 s
# 3th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.21207904815674, time elapsed: 0 h 10 m 7 s
# 4th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.20817804336548, time elapsed: 0 h 13 m 29 s
# 5th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.200093269348145, time elapsed: 0 h 16 m 54 s
# 6th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.21830129623413, time elapsed: 0 h 20 m 17 s
# 7th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.206290245056152, time elapsed: 0 h 23 m 40 s
# 8th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.185306072235107, time elapsed: 0 h 27 m 5 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.203392505645752, time elapsed: 0 h 30 m 29 s
# 10th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.19283962249756, time elapsed: 0 h 33 m 53 s
# 11th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.189187049865723, time elapsed: 0 h 37 m 14 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.201586723327637, time elapsed: 0 h 40 m 37 s
# 13th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.185060501098633, time elapsed: 0 h 44 m 1 s
# 14th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.200965881347656, time elapsed: 0 h 47 m 24 s
# 15th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.204774856567383, time elapsed: 0 h 50 m 51 s
# 16th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.18477773666382, time elapsed: 0 h 54 m 14 s
# 17th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.220033645629883, time elapsed: 0 h 57 m 37 s
# 18th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.206408500671387, time elapsed: 1 h 1 m 2 s
# 19th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.22953176498413, time elapsed: 1 h 4 m 26 s
# 20th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.189728260040283, time elapsed: 1 h 7 m 50 s
# 21th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.20211696624756, time elapsed: 1 h 11 m 14 s
# 22th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.217032432556152, time elapsed: 1 h 14 m 37 s
# 23th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.210511207580566, time elapsed: 1 h 18 m 0 s
# 24th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.183107376098633, time elapsed: 1 h 21 m 23 s
# 25th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.210452556610107, time elapsed: 1 h 24 m 45 s
# 26th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.20423698425293, time elapsed: 1 h 28 m 7 s
# 27th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.222087383270264, time elapsed: 1 h 31 m 32 s
# 28th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.22609519958496, time elapsed: 1 h 34 m 55 s
# 29th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.19760751724243, time elapsed: 1 h 38 m 19 s
# 30th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.211599349975586, time elapsed: 1 h 41 m 43 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp')
# Out:
# Best hidden unit: 256, best layers: 3

# %% [markdown]
# ##### b) Learning with best parameter

# %%
n_layers = 3
hidden_dim = 256

v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:])) # visualise after training

torch.save(DNN.state_dict(), f'./dnn_params/complex_mlp_{n_layers}_{hidden_dim}.pt')
# Out:
# Initial eval loss: 108.83092880249023
# Epoch 1: training loss 357.8929395675659, eval loss 25.461409091949463. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 249.69003438949585, eval loss 24.507137298583984. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 238.4595923423767, eval loss 23.500540256500244. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 232.62568521499634, eval loss 23.189361095428467. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 230.08226776123047, eval loss 23.031021118164062. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 228.3936357498169, eval loss 22.835205078125. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 227.0248203277588, eval loss 22.71684503555298. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 225.8558087348938, eval loss 22.57715940475464. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 224.98124027252197, eval loss 22.482999324798584. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 224.21086406707764, eval loss 22.422311305999756. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 223.5295548439026, eval loss 22.352341651916504. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 223.37308502197266, eval loss 22.342198848724365. Time elapsed: 0 h 0 m 2 s.
# Epoch 13: training loss 222.51416635513306, eval loss 22.283076286315918. Time elapsed: 0 h 0 m 2 s.
# Epoch 14: training loss 222.36293029785156, eval loss 22.261229991912842. Time elapsed: 0 h 0 m 2 s.
# Epoch 15: training loss 222.41365003585815, eval loss 22.24916172027588. Time elapsed: 0 h 0 m 2 s.
# Epoch 16: training loss 221.88675260543823, eval loss 22.22320795059204. Time elapsed: 0 h 0 m 2 s.
# Epoch 17: training loss 221.8314242362976, eval loss 22.20942783355713. Time elapsed: 0 h 0 m 3 s.
# Epoch 18: training loss 221.6504340171814, eval loss 22.195791244506836. Time elapsed: 0 h 0 m 3 s.
# Epoch 19: training loss 221.33916664123535, eval loss 22.18522357940674. Time elapsed: 0 h 0 m 3 s.
# Epoch 20: training loss 221.33373355865479, eval loss 22.17555332183838. Time elapsed: 0 h 0 m 3 s.
# Epoch 21: training loss 221.25482606887817, eval loss 22.16753625869751. Time elapsed: 0 h 0 m 3 s.
# Epoch 22: training loss 221.016179561615, eval loss 22.158461570739746. Time elapsed: 0 h 0 m 4 s.
# Epoch 23: training loss 221.0530047416687, eval loss 22.152509689331055. Time elapsed: 0 h 0 m 4 s.
# Epoch 24: training loss 220.83880186080933, eval loss 22.145826816558838. Time elapsed: 0 h 0 m 4 s.
# Epoch 25: training loss 220.87049055099487, eval loss 22.140810012817383. Time elapsed: 0 h 0 m 4 s.
# Epoch 26: training loss 220.75148725509644, eval loss 22.135834217071533. Time elapsed: 0 h 0 m 4 s.
# Epoch 27: training loss 220.65471029281616, eval loss 22.133066654205322. Time elapsed: 0 h 0 m 5 s.
# Epoch 28: training loss 220.67041540145874, eval loss 22.128457069396973. Time elapsed: 0 h 0 m 5 s.
# Epoch 29: training loss 220.49444198608398, eval loss 22.122533321380615. Time elapsed: 0 h 0 m 5 s.
# Epoch 30: training loss 220.52597618103027, eval loss 22.118229389190674. Time elapsed: 0 h 0 m 5 s.
# Epoch 31: training loss 220.4375400543213, eval loss 22.114960193634033. Time elapsed: 0 h 0 m 5 s.
# Epoch 32: training loss 220.39713621139526, eval loss 22.111600875854492. Time elapsed: 0 h 0 m 5 s.
# Epoch 33: training loss 220.33311367034912, eval loss 22.108257293701172. Time elapsed: 0 h 0 m 6 s.
# Epoch 34: training loss 220.2584924697876, eval loss 22.105012893676758. Time elapsed: 0 h 0 m 6 s.
# Epoch 35: training loss 220.26296710968018, eval loss 22.10335636138916. Time elapsed: 0 h 0 m 6 s.
# Epoch 36: training loss 220.15459156036377, eval loss 22.099265575408936. Time elapsed: 0 h 0 m 6 s.
# Epoch 37: training loss 220.12115907669067, eval loss 22.09566354751587. Time elapsed: 0 h 0 m 6 s.
# Epoch 38: training loss 220.08979558944702, eval loss 22.093902111053467. Time elapsed: 0 h 0 m 7 s.
# Epoch 39: training loss 220.0511302947998, eval loss 22.0921573638916. Time elapsed: 0 h 0 m 7 s.
# Epoch 40: training loss 220.03213500976562, eval loss 22.09102439880371. Time elapsed: 0 h 0 m 7 s.
# Epoch 41: training loss 219.97921657562256, eval loss 22.08646535873413. Time elapsed: 0 h 0 m 7 s.
# Epoch 42: training loss 219.94751262664795, eval loss 22.084843635559082. Time elapsed: 0 h 0 m 7 s.
# Epoch 43: training loss 219.839946269989, eval loss 22.084010124206543. Time elapsed: 0 h 0 m 8 s.
# Epoch 44: training loss 219.85714387893677, eval loss 22.08094358444214. Time elapsed: 0 h 0 m 8 s.
# Epoch 45: training loss 219.80289793014526, eval loss 22.080222606658936. Time elapsed: 0 h 0 m 8 s.
# Epoch 46: training loss 219.81616115570068, eval loss 22.076876163482666. Time elapsed: 0 h 0 m 8 s.
# Epoch 47: training loss 219.706871509552, eval loss 22.076786041259766. Time elapsed: 0 h 0 m 8 s.
# Epoch 48: training loss 219.7340440750122, eval loss 22.075165271759033. Time elapsed: 0 h 0 m 8 s.
# Epoch 49: training loss 219.65928030014038, eval loss 22.0735125541687. Time elapsed: 0 h 0 m 9 s.
# Epoch 50: training loss 219.64286088943481, eval loss 22.07247543334961. Time elapsed: 0 h 0 m 9 s.
# Training completed with final epoch loss 219.64286088943481. Time elapsed: 0 h 0 m 9 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(_X_test), _Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(_Y_test, dim=0).repeat([50000,1]), _Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(4.5323, device='cuda:0')
# Predicting mean MSE error on test set tensor(5.1290, device='cuda:0')

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.44295072555542, time elapsed: 0 h 3 m 8 s
# 2th repeat: best hidden unit: 256, best layers: 7, final eval loss: 22.46644878387451, time elapsed: 0 h 6 m 30 s
# 3th repeat: best hidden unit: 256, best layers: 5, final eval loss: 22.437827587127686, time elapsed: 0 h 9 m 51 s
# 4th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.431431770324707, time elapsed: 0 h 13 m 12 s
# 5th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.403598308563232, time elapsed: 0 h 16 m 33 s
# 6th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.390442371368408, time elapsed: 0 h 19 m 53 s
# 7th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.438467502593994, time elapsed: 0 h 23 m 17 s
# 8th repeat: best hidden unit: 256, best layers: 7, final eval loss: 22.435606956481934, time elapsed: 0 h 26 m 37 s
# 9th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.441537380218506, time elapsed: 0 h 29 m 59 s
# 10th repeat: best hidden unit: 256, best layers: 1, final eval loss: 22.411092281341553, time elapsed: 0 h 33 m 22 s
# 11th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.42854070663452, time elapsed: 0 h 36 m 43 s
# 12th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.43507432937622, time elapsed: 0 h 40 m 6 s
# 13th repeat: best hidden unit: 256, best layers: 7, final eval loss: 22.382784366607666, time elapsed: 0 h 43 m 28 s
# 14th repeat: best hidden unit: 256, best layers: 1, final eval loss: 22.42699098587036, time elapsed: 0 h 46 m 50 s
# 15th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.414024353027344, time elapsed: 0 h 50 m 12 s
# 16th repeat: best hidden unit: 256, best layers: 8, final eval loss: 22.387869834899902, time elapsed: 0 h 53 m 36 s
# 17th repeat: best hidden unit: 256, best layers: 7, final eval loss: 22.427481174468994, time elapsed: 0 h 56 m 57 s
# 18th repeat: best hidden unit: 256, best layers: 8, final eval loss: 22.39711046218872, time elapsed: 1 h 0 m 17 s
# 19th repeat: best hidden unit: 256, best layers: 6, final eval loss: 22.409476280212402, time elapsed: 1 h 3 m 40 s
# 20th repeat: best hidden unit: 256, best layers: 3, final eval loss: 22.403491973876953, time elapsed: 1 h 7 m 3 s
# 21th repeat: best hidden unit: 256, best layers: 7, final eval loss: 22.39510440826416, time elapsed: 1 h 10 m 22 s
# 22th repeat: best hidden unit: 256, best layers: 8, final eval loss: 22.418596744537354, time elapsed: 1 h 13 m 44 s
# 23th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.42322301864624, time elapsed: 1 h 17 m 6 s
# 24th repeat: best hidden unit: 256, best layers: 7, final eval loss: 22.435022354125977, time elapsed: 1 h 20 m 27 s
# 25th repeat: best hidden unit: 256, best layers: 8, final eval loss: 22.41024875640869, time elapsed: 1 h 23 m 51 s
# 26th repeat: best hidden unit: 256, best layers: 4, final eval loss: 22.45252513885498, time elapsed: 1 h 27 m 11 s
# 27th repeat: best hidden unit: 256, best layers: 5, final eval loss: 22.447346210479736, time elapsed: 1 h 30 m 39 s
# 28th repeat: best hidden unit: 256, best layers: 1, final eval loss: 22.41941261291504, time elapsed: 1 h 34 m 5 s
# 29th repeat: best hidden unit: 256, best layers: 6, final eval loss: 22.456825256347656, time elapsed: 1 h 37 m 26 s
# 30th repeat: best hidden unit: 256, best layers: 2, final eval loss: 22.476857662200928, time elapsed: 1 h 40 m 48 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_lstm_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_lstm')
# Out:
# Best hidden unit: 256, best layers: 4

# %% [markdown]
# ##### b) Learning with best parameter

# %%
hidden_dim=256
n_linear_layers=4

v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=hidden_dim, n_linear_layers=n_linear_layers, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

torch.save(DNN.state_dict(), f'./dnn_params/complex_lstm_{n_linear_layers}_{hidden_dim}.pt')
# Out:
# Initial eval loss: 94.61222267150879
# Epoch 1: training loss 351.70689582824707, eval loss 25.54685640335083. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 245.03328466415405, eval loss 23.777209758758545. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 234.12995719909668, eval loss 23.293432235717773. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 231.82623767852783, eval loss 23.204439640045166. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 231.09354257583618, eval loss 23.145094394683838. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 230.55225372314453, eval loss 23.096550464630127. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 230.02748823165894, eval loss 23.04082441329956. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 229.40071439743042, eval loss 22.9729323387146. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 228.75853824615479, eval loss 22.913642406463623. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 228.16613817214966, eval loss 22.85639238357544. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 227.62193298339844, eval loss 22.803529262542725. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 227.1186547279358, eval loss 22.757603645324707. Time elapsed: 0 h 0 m 2 s.
# Epoch 13: training loss 226.6372103691101, eval loss 22.711042881011963. Time elapsed: 0 h 0 m 3 s.
# Epoch 14: training loss 226.1893482208252, eval loss 22.66881227493286. Time elapsed: 0 h 0 m 3 s.
# Epoch 15: training loss 225.77488231658936, eval loss 22.62837839126587. Time elapsed: 0 h 0 m 3 s.
# Epoch 16: training loss 225.37744665145874, eval loss 22.58845806121826. Time elapsed: 0 h 0 m 3 s.
# Epoch 17: training loss 224.99469327926636, eval loss 22.554497718811035. Time elapsed: 0 h 0 m 3 s.
# Epoch 18: training loss 224.6441445350647, eval loss 22.522541999816895. Time elapsed: 0 h 0 m 4 s.
# Epoch 19: training loss 224.31709384918213, eval loss 22.491466999053955. Time elapsed: 0 h 0 m 4 s.
# Epoch 20: training loss 224.01866912841797, eval loss 22.46433401107788. Time elapsed: 0 h 0 m 4 s.
# Epoch 21: training loss 223.74566650390625, eval loss 22.439611434936523. Time elapsed: 0 h 0 m 4 s.
# Epoch 22: training loss 223.49714422225952, eval loss 22.4190354347229. Time elapsed: 0 h 0 m 5 s.
# Epoch 23: training loss 223.27538347244263, eval loss 22.398769855499268. Time elapsed: 0 h 0 m 5 s.
# Epoch 24: training loss 223.07512378692627, eval loss 22.38039493560791. Time elapsed: 0 h 0 m 5 s.
# Epoch 25: training loss 222.89331007003784, eval loss 22.364572048187256. Time elapsed: 0 h 0 m 5 s.
# Epoch 26: training loss 222.72251844406128, eval loss 22.347904205322266. Time elapsed: 0 h 0 m 6 s.
# Epoch 27: training loss 222.56671571731567, eval loss 22.333746910095215. Time elapsed: 0 h 0 m 6 s.
# Epoch 28: training loss 222.40656852722168, eval loss 22.31755781173706. Time elapsed: 0 h 0 m 6 s.
# Epoch 29: training loss 222.25515937805176, eval loss 22.30186700820923. Time elapsed: 0 h 0 m 6 s.
# Epoch 30: training loss 222.11309576034546, eval loss 22.286086082458496. Time elapsed: 0 h 0 m 7 s.
# Epoch 31: training loss 221.99226236343384, eval loss 22.273218631744385. Time elapsed: 0 h 0 m 7 s.
# Epoch 32: training loss 221.87723922729492, eval loss 22.26059055328369. Time elapsed: 0 h 0 m 7 s.
# Epoch 33: training loss 221.78331470489502, eval loss 22.251282215118408. Time elapsed: 0 h 0 m 7 s.
# Epoch 34: training loss 221.70394611358643, eval loss 22.241873741149902. Time elapsed: 0 h 0 m 7 s.
# Epoch 35: training loss 221.63013219833374, eval loss 22.23289442062378. Time elapsed: 0 h 0 m 8 s.
# Epoch 36: training loss 221.56438541412354, eval loss 22.22748613357544. Time elapsed: 0 h 0 m 8 s.
# Epoch 37: training loss 221.50882816314697, eval loss 22.22115135192871. Time elapsed: 0 h 0 m 8 s.
# Epoch 38: training loss 221.4553050994873, eval loss 22.215656757354736. Time elapsed: 0 h 0 m 8 s.
# Epoch 39: training loss 221.41016149520874, eval loss 22.21118402481079. Time elapsed: 0 h 0 m 9 s.
# Epoch 40: training loss 221.3615403175354, eval loss 22.20772647857666. Time elapsed: 0 h 0 m 9 s.
# Epoch 41: training loss 221.31884956359863, eval loss 22.203463554382324. Time elapsed: 0 h 0 m 9 s.
# Epoch 42: training loss 221.2764277458191, eval loss 22.1997332572937. Time elapsed: 0 h 0 m 9 s.
# Epoch 43: training loss 221.24041652679443, eval loss 22.19594955444336. Time elapsed: 0 h 0 m 10 s.
# Epoch 44: training loss 221.208345413208, eval loss 22.192737102508545. Time elapsed: 0 h 0 m 10 s.
# Epoch 45: training loss 221.17962169647217, eval loss 22.189898014068604. Time elapsed: 0 h 0 m 10 s.
# Epoch 46: training loss 221.1515383720398, eval loss 22.186842918395996. Time elapsed: 0 h 0 m 10 s.
# Epoch 47: training loss 221.12347078323364, eval loss 22.184502124786377. Time elapsed: 0 h 0 m 11 s.
# Epoch 48: training loss 221.09660053253174, eval loss 22.182247638702393. Time elapsed: 0 h 0 m 11 s.
# Epoch 49: training loss 221.06890869140625, eval loss 22.180083751678467. Time elapsed: 0 h 0 m 11 s.
# Epoch 50: training loss 221.046941280365, eval loss 22.177634716033936. Time elapsed: 0 h 0 m 11 s.
# Training completed with final epoch loss 221.046941280365. Time elapsed: 0 h 0 m 11 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(4.4355, device='cuda:0')
# Predicting mean MSE error on test set tensor(4.9846, device='cuda:0')

# %% [markdown]
# ## Complexity of DNN vs Data Efficiency
# What is the least complex DNN that does a good job of mimicking the approximate the complexBNN?

# %%
X_train, Y_train = load_data('./data/', 'train_complex.pkl')
X_test, Y_test = load_data('./data/', 'test_complex.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_complex.pkl')

hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

batch_size = 200                            # number of data points in each mini-batch
n_datas = [i*1000 for i in range(1,11,1)]   # number of train data used, from 1 to len(X_train)
n_epochs = 50                               # number of training epochs

# %%
train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %%
avg_final_eval_losses = repeated_complexity_varying_data_efficiency(
    hidden_dims=hidden_dims, n_layerss=n_layerss, n_repeats=10, verbose=True,
    **{'input_dim':16,
       'output_dim':16,
       'train_dataset':train_dataset, 
       'test_dataloader':test_dataloader,
       'n_datas':n_datas,
       'n_epochs':n_epochs,
       'batch_size': batch_size})
torch.save(avg_final_eval_losses, './temp/avg_final_eval_loss.pt')
# Out:
# 1 of 10 repeats. Time elapsed: time elapsed: 0 h 43 m 43 sints.
# 2 of 10 repeats. Time elapsed: time elapsed: 1 h 28 m 17 sints.
# 3 of 10 repeats. Time elapsed: time elapsed: 2 h 12 m 39 sints.
# 4 of 10 repeats. Time elapsed: time elapsed: 2 h 57 m 2 soints.
# 5 of 10 repeats. Time elapsed: time elapsed: 3 h 41 m 25 sints.
# 6 of 10 repeats. Time elapsed: time elapsed: 4 h 25 m 54 sints.
# 7 of 10 repeats. Time elapsed: time elapsed: 5 h 10 m 27 sints.
# 8 of 10 repeats. Time elapsed: time elapsed: 5 h 54 m 50 sints.
# 9 of 10 repeats. Time elapsed: time elapsed: 6 h 39 m 14 sints.
# 10 of 10 repeats. Time elapsed: time elapsed: 7 h 23 m 45 snts.

# %%
avg_final_eval_losses = torch.load('./temp/avg_final_eval_loss.pt')
for i, n_data in enumerate(n_datas):
    print(f'Using {n_data} out of 10000 training data points')
    plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_losses[:,:,i],
                    x_label='Hidden units', y_label='Layers', z_label= f'Test set MSE loss for {n_data} training data',
                    fname=False, figsize=(10,8))
# Out:
# Using 1000 out of 10000 training data points
# Using 2000 out of 10000 training data points
# Using 3000 out of 10000 training data points
# Using 4000 out of 10000 training data points
# Using 5000 out of 10000 training data points
# Using 6000 out of 10000 training data points
# Using 7000 out of 10000 training data points
# Using 8000 out of 10000 training data points
# Using 9000 out of 10000 training data points
# Using 10000 out of 10000 training data points

# %% [markdown]
# ## BNN Plasticity analysis
# We explore to what extent pre-training of a DNN helps when the plasticity of the approximate BNN is changed slightly (according to a Gaussian)

# %%
from approx_bnns import ComplexApproximateBNN

# BNN params
x, y, z = 256, 0.5, 4
bias = True
trainable = False
residual_in = [False, False, 1, 2]
num_epochs=25

input_dim = 16
output_dim = 16
batch_size = 200
transfer_functions=[nn.ReLU(), nn.ELU(), nn.SiLU(), nn.CELU(), nn.Tanh(), nn.Sigmoid(), nn.LeakyReLU(0.1), nn.LeakyReLU(0.2), nn.LeakyReLU(0.3)]

# initialise BNN, and load original weights
approx_bnn = ComplexApproximateBNN(
    x=x, y=y, z=z, 
    input_dim=input_dim, 
    output_dim=output_dim, 
    residual_in=residual_in, 
    recurrent_dim=-1, 
    transfer_functions=transfer_functions
).to(device)

BNN_weights = torch.load('./approx_bnn_params/complex.pt')
BNN_non_linearities = load_non_linearities('./approx_bnn_params/complex_activations.pkl')
approx_bnn.load_state_dict(BNN_weights)
approx_bnn.load_non_linearities(BNN_non_linearities)

# fixing input pattern
X_train, _ = load_data('./data/', 'train_complex.pkl')
X_test, _ = load_data('./data/', 'test_complex.pkl')
X_valid, _ = load_data('./data/', 'valid_complex.pkl')

# %%
# initialise DNN
hidden_dim = 256
n_layers = 8
DNN_params = torch.load(f'./dnn_params/complex_lstm_{n_layers}_{hidden_dim}.pt')
DNN = RecurrentDNN(input_dim=16, hidden_dim=hidden_dim, n_linear_layers=n_layers, output_dim=16).to(device)
DNN.load_state_dict(DNN_params)
# Out:
# <All keys matched successfully>

# %%
sigmas = torch.exp(torch.linspace(-10,0, 25))
params = {'DNN': DNN,
          'BNN': approx_bnn, 
          'DNN_params': DNN_params, 
          'BNN_params': (BNN_weights, BNN_non_linearities), 
          'sigmas': sigmas, 
          'batch_size': batch_size,
          'num_epochs': 10,
          'X_train': X_train, 
          'X_test': X_test,
          'verbose': 0}

# %%
mean_transfer, std_transfer = repeated_plasticity_analysis(n_repeats=15, transfer_learning=True, **params)
mean_retrain, std_retrain = repeated_plasticity_analysis(n_repeats=15, transfer_learning=False, **params)

train_losses_by_sigma_transfer, eval_losses_by_sigma_transfer, init_losses_by_sigma_transfer = mean_transfer
train_losses_by_sigma_reset, eval_losses_by_sigma_reset, init_losses_by_sigma_reset = mean_retrain
# Out:
# Repeat 1/5
# Repeat 2/5
# Repeat 3/5
# Repeat 4/5
# Repeat 5/5
# Repeat 1/5
# Repeat 2/5
# Repeat 3/5
# Repeat 4/5
# Repeat 5/5

# %%
plt.subplots(sharey=True, figsize=(16,8))
plt.subplot(121)
plt.title('Evaluation loss, tranfer learning')
for i in range(train_losses_by_sigma_transfer.shape[0]):
    plt.plot(train_losses_by_sigma_transfer[i,:], label=f'1e-{i}')

plt.xlabel('Epochs')
plt.ylabel('Evaluation loss')

plt.subplot(122)
plt.title('Evaluation loss, retrained learning')
for i in range(train_losses_by_sigma_transfer.shape[0]):
    plt.plot(train_losses_by_sigma_reset[i,:], label=f'1e-{i}')
    
plt.xlabel('Epochs')
plt.ylabel('Evaluation loss')

plt.show()

# %%
width=0.5
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(np.arange(init_losses_by_sigma_transfer.shape[0]) - width/4, init_losses_by_sigma_transfer, width/2, label='Transfer learning')
ax.bar(np.arange(init_losses_by_sigma_reset.shape[0]) + width/4, init_losses_by_sigma_reset, width/2, label='Random init')
plt.legend()
plt.xticks(np.arange(25), [str(i)[:4] for i in np.linspace(-10,0,25)])
plt.xlabel('Log Gaussian noise std')
plt.ylabel('Initial mean evaluation loss')
plt.title('Initial evaluation loss, varying sigma')
plt.show()

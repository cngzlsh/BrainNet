# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import random
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

from models import *
from utils import *
from train import *
from bvc import *
from gen_data import *

sns.set_theme(style='white', font_scale=1.25)

seed = 1234
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Feedforward BNN

# %%
X_train, Y_train = load_data('./data/', 'feedforward_train.pkl')
X_test, Y_test = load_data('./data/', 'feedforward_test.pkl')
X_valid, Y_valid = load_data('./data/', 'feedforward_valid.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30,
    **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %%
avg_final_eval_loss = torch.load('./temp/param_search_feedforward.pt')
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='feedforward_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='feedforward')
torch.save(avg_final_eval_loss, './temp/param_search_feedforward.pt')

# %% [markdown]
# ####  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=4, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,-1, :], DNN(X_test[v_idx,-1, :]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=1000,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,-1, :], DNN(X_test[v_idx,-1, :])) # visualise after training

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad(): 
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1,1), Y_test))

# %% [markdown]
# ### Residual BNN

# %%
X_train, Y_train = load_data('./data/', 'residual_train.pkl')
X_test, Y_test = load_data('./data/', 'residual_test.pkl')
X_valid, Y_valid = load_data('./data/', 'residual_valid.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %%
avg_final_eval_loss = torch.load('./temp/skip_param_search.pt')
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='residual_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='residual')
# torch.save(avg_final_eval_loss, './temp/skip_param_search.pt')

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=4, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=1000,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:])) # visualise after training

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1,1), Y_test))

# %% [markdown]
# ### Recurrent BNN

# %%
X_train, Y_train = load_data('./data/', 'recurrent_train_2.pkl')
X_test, Y_test = load_data('./data/', 'recurrent_test_2.pkl')
X_valid, Y_valid = load_data('./data/', 'recurrent_valid_2.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5527623891830444, time elapsed: 0 h 1 m 3 s
# 2th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5649966895580292, time elapsed: 0 h 2 m 14 s
# 3th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5370296835899353, time elapsed: 0 h 3 m 37 s
# 4th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5447198748588562, time elapsed: 0 h 4 m 57 s
# 5th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5523774027824402, time elapsed: 0 h 6 m 12 s
# 6th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5437135994434357, time elapsed: 0 h 7 m 33 s
# 7th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.543822467327118, time elapsed: 0 h 8 m 54 s
# 8th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.540532410144806, time elapsed: 0 h 10 m 14 s
# 9th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.556991159915924, time elapsed: 0 h 11 m 35 s
# 10th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5512875020503998, time elapsed: 0 h 12 m 56 s
# 11th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5827943980693817, time elapsed: 0 h 14 m 16 s
# 12th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5693901181221008, time elapsed: 0 h 15 m 37 s
# 13th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5550391972064972, time elapsed: 0 h 16 m 58 s
# 14th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5604937076568604, time elapsed: 0 h 18 m 19 s
# 15th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5335254967212677, time elapsed: 0 h 19 m 39 s
# 16th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5274328291416168, time elapsed: 0 h 21 m 0 s
# 17th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5870196223258972, time elapsed: 0 h 22 m 20 s
# 18th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5432526171207428, time elapsed: 0 h 23 m 42 s
# 19th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5482580065727234, time elapsed: 0 h 25 m 2 s
# 20th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.576849490404129, time elapsed: 0 h 26 m 23 s
# 21th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5508388876914978, time elapsed: 0 h 27 m 44 s
# 22th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5482310056686401, time elapsed: 0 h 29 m 5 s
# 23th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.538872241973877, time elapsed: 0 h 30 m 25 s
# 24th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5564886033535004, time elapsed: 0 h 31 m 46 s
# 25th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.550969660282135, time elapsed: 0 h 33 m 7 s
# 26th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5304640233516693, time elapsed: 0 h 34 m 26 s
# 27th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5590170919895172, time elapsed: 0 h 35 m 47 s
# 28th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5720049142837524, time elapsed: 0 h 37 m 8 s
# 29th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.5161104500293732, time elapsed: 0 h 38 m 28 s
# 30th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.536849707365036, time elapsed: 0 h 39 m 49 s

# %%
# avg_final_eval_loss = torch.load('./temp/recurrent_mlp_param_search_2.pt')
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_mlp_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_mlp')
torch.save(avg_final_eval_loss, './temp/recurrent_mlp_param_search_2.pt')
# Out:
# Best hidden unit: 256, best layers: 2

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=4, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=1000,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:])) # visualise after training
# Out:
# Initial eval loss: 5.019015908241272
# Epoch 1: training loss 32.56150797009468, eval loss 2.4001752734184265. Time elapsed: 0 h 0 m 0 s.
# Epoch 51: training loss 11.840946957468987, eval loss 1.2359782457351685. Time elapsed: 0 h 0 m 11 s.
# Epoch 101: training loss 11.154988124966621, eval loss 1.2326726168394089. Time elapsed: 0 h 0 m 22 s.
# Epoch 151: training loss 10.76580536365509, eval loss 1.2482489943504333. Time elapsed: 0 h 0 m 34 s.
# Epoch 201: training loss 10.428663492202759, eval loss 1.2917697578668594. Time elapsed: 0 h 0 m 46 s.
# Epoch 251: training loss 10.114714488387108, eval loss 1.3386063873767853. Time elapsed: 0 h 0 m 57 s.
# Epoch 301: training loss 10.443058297038078, eval loss 1.3541929423809052. Time elapsed: 0 h 1 m 9 s.
# Epoch 351: training loss 10.045028373599052, eval loss 1.3564774990081787. Time elapsed: 0 h 1 m 21 s.
# Epoch 401: training loss 9.914404913783073, eval loss 1.3754225075244904. Time elapsed: 0 h 1 m 32 s.
# Epoch 451: training loss 9.471675768494606, eval loss 1.3927095234394073. Time elapsed: 0 h 1 m 44 s.
# Epoch 501: training loss 9.374554738402367, eval loss 1.4348380863666534. Time elapsed: 0 h 1 m 56 s.
# Epoch 551: training loss 9.13315062224865, eval loss 1.57546865940094. Time elapsed: 0 h 2 m 8 s.
# Epoch 601: training loss 9.360175713896751, eval loss 1.393967181444168. Time elapsed: 0 h 2 m 19 s.
# Epoch 651: training loss 8.858951911330223, eval loss 1.4386579096317291. Time elapsed: 0 h 2 m 31 s.
# Epoch 701: training loss 8.762464806437492, eval loss 1.4633741676807404. Time elapsed: 0 h 2 m 43 s.
# Epoch 751: training loss 8.837325721979141, eval loss 1.4941162765026093. Time elapsed: 0 h 2 m 54 s.
# Epoch 801: training loss 8.64834275841713, eval loss 1.5147686302661896. Time elapsed: 0 h 3 m 6 s.
# Epoch 851: training loss 8.451142579317093, eval loss 1.5363889038562775. Time elapsed: 0 h 3 m 18 s.
# Epoch 901: training loss 8.39792150259018, eval loss 1.4821727275848389. Time elapsed: 0 h 3 m 29 s.
# Epoch 951: training loss 8.627222314476967, eval loss 1.5149053633213043. Time elapsed: 0 h 3 m 41 s.
# Training completed with final epoch loss 8.061084553599358. Time elapsed: 0 h 3 m 53 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1,1), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.2979, device='cuda:0')
# Predicting mean MSE error on test set tensor(0.9991, device='cuda:0')

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 6, final eval loss: 2.0243493020534515, time elapsed: 0 h 1 m 26 s
# 2th repeat: best hidden unit: 256, best layers: 4, final eval loss: 2.0125892758369446, time elapsed: 0 h 2 m 52 s
# 3th repeat: best hidden unit: 256, best layers: 3, final eval loss: 2.0111298859119415, time elapsed: 0 h 4 m 19 s
# 4th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.9976711571216583, time elapsed: 0 h 5 m 45 s
# 5th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.9947798550128937, time elapsed: 0 h 7 m 11 s
# 6th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.9764962792396545, time elapsed: 0 h 8 m 38 s
# 7th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.995891273021698, time elapsed: 0 h 10 m 4 s
# 8th repeat: best hidden unit: 256, best layers: 2, final eval loss: 2.029474288225174, time elapsed: 0 h 11 m 31 s
# 9th repeat: best hidden unit: 256, best layers: 8, final eval loss: 2.01204651594162, time elapsed: 0 h 12 m 57 s
# 10th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.9968310296535492, time elapsed: 0 h 14 m 23 s
# 11th repeat: best hidden unit: 256, best layers: 5, final eval loss: 2.0163682103157043, time elapsed: 0 h 15 m 50 s
# 12th repeat: best hidden unit: 256, best layers: 7, final eval loss: 2.012980282306671, time elapsed: 0 h 17 m 17 s
# 13th repeat: best hidden unit: 256, best layers: 3, final eval loss: 2.0361899733543396, time elapsed: 0 h 18 m 43 s
# 14th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.995017021894455, time elapsed: 0 h 20 m 10 s
# 15th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.9911621510982513, time elapsed: 0 h 21 m 37 s
# 16th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.9998314082622528, time elapsed: 0 h 23 m 3 s
# 17th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.9649681448936462, time elapsed: 0 h 24 m 30 s
# 18th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.977718323469162, time elapsed: 0 h 25 m 57 s
# 19th repeat: best hidden unit: 256, best layers: 6, final eval loss: 2.026309311389923, time elapsed: 0 h 27 m 24 s
# 20th repeat: best hidden unit: 256, best layers: 3, final eval loss: 2.0044488310813904, time elapsed: 0 h 28 m 50 s
# 21th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.9996272921562195, time elapsed: 0 h 30 m 17 s
# 22th repeat: best hidden unit: 256, best layers: 2, final eval loss: 2.007474273443222, time elapsed: 0 h 31 m 44 s
# 23th repeat: best hidden unit: 256, best layers: 2, final eval loss: 2.0363893508911133, time elapsed: 0 h 33 m 10 s
# 24th repeat: best hidden unit: 256, best layers: 6, final eval loss: 2.0502685606479645, time elapsed: 0 h 34 m 37 s
# 25th repeat: best hidden unit: 256, best layers: 4, final eval loss: 2.0076449811458588, time elapsed: 0 h 36 m 4 s
# 26th repeat: best hidden unit: 256, best layers: 3, final eval loss: 2.006528824567795, time elapsed: 0 h 37 m 30 s
# 27th repeat: best hidden unit: 256, best layers: 5, final eval loss: 2.0142875611782074, time elapsed: 0 h 38 m 57 s
# 28th repeat: best hidden unit: 256, best layers: 8, final eval loss: 2.014992743730545, time elapsed: 0 h 40 m 23 s
# 29th repeat: best hidden unit: 256, best layers: 7, final eval loss: 2.0302118062973022, time elapsed: 0 h 41 m 50 s
# 30th repeat: best hidden unit: 256, best layers: 2, final eval loss: 2.02547487616539, time elapsed: 0 h 43 m 17 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_lstm_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_lstm')
torch.save(avg_final_eval_loss, './temp/recurrent_lstm_param_search_2.pt')
# Out:
# Best hidden unit: 256, best layers: 2

# %% [markdown]
# ##### b) Learning with best parameter

# %%
# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=2, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,-1,:], Y_hats[v_idx,-1,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=1000,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0-1,:], Y_hats[v_idx,-1,:])
# Out:
# Initial eval loss: 11.59152626991272
# Epoch 1: training loss 43.55406415462494, eval loss 2.695393145084381. Time elapsed: 0 h 0 m 0 s.
# Epoch 51: training loss 14.09378457069397, eval loss 1.4040863811969757. Time elapsed: 0 h 0 m 11 s.
# Epoch 101: training loss 13.686558037996292, eval loss 1.369560867547989. Time elapsed: 0 h 0 m 22 s.
# Epoch 151: training loss 13.473427593708038, eval loss 1.348816305398941. Time elapsed: 0 h 0 m 33 s.
# Epoch 201: training loss 13.34138399362564, eval loss 1.3354604840278625. Time elapsed: 0 h 0 m 44 s.
# Epoch 251: training loss 13.269687861204147, eval loss 1.330497533082962. Time elapsed: 0 h 0 m 55 s.
# Epoch 301: training loss 13.213709264993668, eval loss 1.3236587047576904. Time elapsed: 0 h 1 m 6 s.
# Epoch 351: training loss 13.170224815607071, eval loss 1.3201920092105865. Time elapsed: 0 h 1 m 17 s.
# Epoch 401: training loss 13.133204013109207, eval loss 1.3173121809959412. Time elapsed: 0 h 1 m 29 s.
# Epoch 451: training loss 13.101568922400475, eval loss 1.3130446076393127. Time elapsed: 0 h 1 m 40 s.
# Epoch 501: training loss 13.073394179344177, eval loss 1.3118974566459656. Time elapsed: 0 h 1 m 51 s.
# Epoch 551: training loss 13.049138873815536, eval loss 1.3081139922142029. Time elapsed: 0 h 2 m 2 s.
# Epoch 601: training loss 13.02618919312954, eval loss 1.305940568447113. Time elapsed: 0 h 2 m 13 s.
# Epoch 651: training loss 13.006139755249023, eval loss 1.3045107126235962. Time elapsed: 0 h 2 m 24 s.
# Epoch 701: training loss 12.989688351750374, eval loss 1.3029678463935852. Time elapsed: 0 h 2 m 35 s.
# Epoch 751: training loss 12.974362954497337, eval loss 1.3002245426177979. Time elapsed: 0 h 2 m 46 s.
# Epoch 801: training loss 12.959871754050255, eval loss 1.29921954870224. Time elapsed: 0 h 2 m 58 s.
# Epoch 851: training loss 12.952137127518654, eval loss 1.2989399433135986. Time elapsed: 0 h 3 m 9 s.
# Epoch 901: training loss 12.934568345546722, eval loss 1.297348976135254. Time elapsed: 0 h 3 m 20 s.
# Epoch 951: training loss 12.926753863692284, eval loss 1.2976999580860138. Time elapsed: 0 h 3 m 31 s.
# Training completed with final epoch loss 12.921606540679932. Time elapsed: 0 h 3 m 42 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.2591, device='cuda:0')
# Predicting mean MSE error on test set tensor(0.9991, device='cuda:0')

# %% [markdown]
# ### Complex BNN

# %% [markdown]
# #### USE MLP

# %%
X_train, Y_train = load_data('./data/', 'complex_train_2.pkl')
X_test, Y_test = load_data('./data/', 'complex_test_2.pkl')
X_valid, Y_valid = load_data('./data/', 'complex_valid_2.pkl')

batch_size = 200   # number of data points in each mini-batch
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})
torch.save(avg_final_eval_loss, './temp/complex_mlp_param_search_2.pt')
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 2 layers, 2 hidden units, final eval loss: 4.084392428398132
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7363/701684908.py in <module>
#       2 n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]
#       3
# ----> 4 avg_final_eval_loss = repeated_param_grid_search(
#       5     hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF',
#       6                                              'train_loader':train_dataloader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in repeated_param_grid_search(hidden_dims, n_layerss, n_repeats, **kwargs)
#     253     for i in range(n_repeats):
#     254
# --> 255         final_eval_loss = param_grid_search(hidden_dims, n_layerss, **kwargs)
#     256         final_eval_loss_matrix += final_eval_loss
#     257
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in param_grid_search(hidden_dims, n_layerss, **kwargs)
#     217                 criterion = nn.MSELoss()
#     218
# --> 219                 train_losses, eval_losses = train(
#     220                     model=DNN,
#     221                     train_loader=valid_loader, test_loader=test_loader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop, return_init_eval_loss)
#      45                 break
#      46
# ---> 47         eval_loss = eval(model, test_loader, criterion)
#      48
#      49         train_losses.append(epoch_loss)
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in eval(model, test_loader, criterion)
#      84         eval_loss = 0
#      85
# ---> 86         for _, (X, Y) in enumerate(iter(test_loader)):
#      87
#      88             Y_hat = model(X)
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in __getitem__(self, idx)
#      89     def __getitem__(self, idx):
#      90         input = self.inputs[idx,:]
# ---> 91         label = self.labels[idx,:]
#      92         return input, label
#      93
#
# KeyboardInterrupt:

# %%
avg_final_eval_loss = torch.load('./temp/complex_mlp_param_search_2.pt')
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp')
# Out:
# Best hidden unit: 256, best layers: 2

# %% [markdown]
# ##### b) Learning with best parameter

# %%
hidden_dim = 256
n_layers = 2

v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,-1,:], DNN(X_test[v_idx,-1,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=1000,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,-1, :], DNN(X_test[v_idx,-1,:]))
torch.save(DNN.state_dict(), f'./dnn_params/complex_mlp_{n_layers}_{hidden_dim}.pt')
# Out:
# Initial eval loss: 4.092541396617889
# Epoch 1: training loss 25.56628394126892, eval loss 1.8482505083084106. Time elapsed: 0 h 0 m 0 s.
# Epoch 51: training loss 12.212447628378868, eval loss 1.074571505188942. Time elapsed: 0 h 0 m 7 s.
# Epoch 101: training loss 11.762211486697197, eval loss 1.0539315342903137. Time elapsed: 0 h 0 m 14 s.
# Epoch 151: training loss 11.434387773275375, eval loss 1.0533316284418106. Time elapsed: 0 h 0 m 22 s.
# Epoch 201: training loss 11.082538038492203, eval loss 1.057873710989952. Time elapsed: 0 h 0 m 29 s.
# Epoch 251: training loss 10.490802004933357, eval loss 1.0837719291448593. Time elapsed: 0 h 0 m 36 s.
# Epoch 301: training loss 9.521281525492668, eval loss 1.0925378203392029. Time elapsed: 0 h 0 m 44 s.
# Epoch 351: training loss 9.536293283104897, eval loss 1.1449617892503738. Time elapsed: 0 h 0 m 52 s.
# Epoch 401: training loss 9.095141798257828, eval loss 1.1532844305038452. Time elapsed: 0 h 1 m 0 s.
# Epoch 451: training loss 8.701698184013367, eval loss 1.158899500966072. Time elapsed: 0 h 1 m 8 s.
# Epoch 501: training loss 8.558701917529106, eval loss 1.147188276052475. Time elapsed: 0 h 1 m 16 s.
# Epoch 551: training loss 8.624333694577217, eval loss 1.1631138175725937. Time elapsed: 0 h 1 m 24 s.
# Epoch 601: training loss 8.057433560490608, eval loss 1.1630964279174805. Time elapsed: 0 h 1 m 32 s.
# Epoch 651: training loss 8.364704981446266, eval loss 1.1746976524591446. Time elapsed: 0 h 1 m 40 s.
# Epoch 701: training loss 8.118329271674156, eval loss 1.171644240617752. Time elapsed: 0 h 1 m 49 s.
# Epoch 751: training loss 7.8897805362939835, eval loss 1.187486931681633. Time elapsed: 0 h 1 m 57 s.
# Epoch 801: training loss 8.403751879930496, eval loss 1.1784954220056534. Time elapsed: 0 h 2 m 5 s.
# Epoch 851: training loss 7.799748972058296, eval loss 1.2417059540748596. Time elapsed: 0 h 2 m 13 s.
# Epoch 901: training loss 7.616098329424858, eval loss 1.2494358718395233. Time elapsed: 0 h 2 m 21 s.
# Epoch 951: training loss 7.864007189869881, eval loss 1.2513233572244644. Time elapsed: 0 h 2 m 29 s.
# Training completed with final epoch loss 7.517199888825417. Time elapsed: 0 h 2 m 37 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set:', F.mse_loss(DNN(X_test), Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1,1), Y_test))
# Out:
# DNN prediction MSE error on test set: tensor(0.2523, device='cuda:0', grad_fn=<MseLossBackward0>)
# Predicting mean MSE error on test set tensor(0.7593, device='cuda:0')

# %% [markdown]
# #### USE RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 
                                             'train_loader':train_dataloader, 
                                             'valid_loader':valid_dataloader, 
                                             'test_loader':test_dataloader, 
                                             'n_epochs':n_epochs})
torch.save(avg_final_eval_loss, './temp/complex_lstm_param_search.pt')
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.2770877182483673, time elapsed: 0 h 1 m 23 s
# 2th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.2555730640888214, time elapsed: 0 h 2 m 42 s
# 3th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.3009092062711716, time elapsed: 0 h 4 m 6 s
# 4th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.3368390202522278, time elapsed: 0 h 5 m 25 s
# 5th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.2939794212579727, time elapsed: 0 h 6 m 46 s
# 6th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3152471482753754, time elapsed: 0 h 8 m 8 s
# 7th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.308289498090744, time elapsed: 0 h 9 m 28 s
# 8th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.313738465309143, time elapsed: 0 h 10 m 51 s
# 9th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.2798123508691788, time elapsed: 0 h 12 m 13 s
# 10th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.3668481707572937, time elapsed: 0 h 13 m 36 s
# 11th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.318321019411087, time elapsed: 0 h 14 m 58 s
# 12th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.3227838277816772, time elapsed: 0 h 16 m 20 s
# 13th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.3149412274360657, time elapsed: 0 h 17 m 43 s
# 14th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.2988088130950928, time elapsed: 0 h 19 m 4 s
# 15th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.2933253943920135, time elapsed: 0 h 20 m 27 s
# 16th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.2908632159233093, time elapsed: 0 h 21 m 52 s
# 17th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.3107638657093048, time elapsed: 0 h 23 m 16 s
# 18th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.2702286839485168, time elapsed: 0 h 24 m 37 s
# 19th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.3214483559131622, time elapsed: 0 h 25 m 59 s
# 20th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.3200027346611023, time elapsed: 0 h 27 m 21 s
# 21th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.3189491629600525, time elapsed: 0 h 28 m 43 s
# 22th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.279077485203743, time elapsed: 0 h 30 m 3 s
# 23th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.2773401141166687, time elapsed: 0 h 31 m 27 s
# 24th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.3572616279125214, time elapsed: 0 h 32 m 52 s
# 25th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3276887238025665, time elapsed: 0 h 34 m 12 s
# 26th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.2946425378322601, time elapsed: 0 h 35 m 31 s
# 27th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.2755337208509445, time elapsed: 0 h 36 m 55 s
# 28th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.2973250895738602, time elapsed: 0 h 38 m 16 s
# 29th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.3136481046676636, time elapsed: 0 h 39 m 37 s
# 30th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.324808955192566, time elapsed: 0 h 41 m 2 s

# %%
avg_final_eval_loss = torch.load('./temp/complex_lstm_param_search_2.pt')
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_lstm_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_lstm')
# Out:
# Best hidden unit: 256, best layers: 5

# %% [markdown]
# ##### b) Learning with best parameter

# %%
hidden_dim = 256
n_linear_layers = 5

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=5, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,-1,:], Y_hats[v_idx,-1,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=1000,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,-1,:], Y_hats[v_idx,-1,:])

torch.save(DNN.state_dict(), f'./dnn_params/complex_lstm_{n_linear_layers}_{hidden_dim}.pt')
# Out:
# Initial eval loss: 10.64778995513916
# Epoch 1: training loss 35.289625108242035, eval loss 2.0225718319416046. Time elapsed: 0 h 0 m 0 s.
# Epoch 51: training loss 6.849455587565899, eval loss 0.6671555191278458. Time elapsed: 0 h 0 m 12 s.
# Epoch 101: training loss 6.387531854212284, eval loss 0.6262188702821732. Time elapsed: 0 h 0 m 25 s.
# Epoch 151: training loss 6.141045421361923, eval loss 0.6036364510655403. Time elapsed: 0 h 0 m 38 s.
# Epoch 201: training loss 5.995130889117718, eval loss 0.5898348465561867. Time elapsed: 0 h 0 m 52 s.
# Epoch 251: training loss 5.896536640822887, eval loss 0.5779453590512276. Time elapsed: 0 h 1 m 5 s.
# Epoch 301: training loss 5.819055452942848, eval loss 0.5690546110272408. Time elapsed: 0 h 1 m 18 s.
# Epoch 351: training loss 5.737643174827099, eval loss 0.5606697872281075. Time elapsed: 0 h 1 m 31 s.
# Epoch 401: training loss 5.688775949180126, eval loss 0.555403895676136. Time elapsed: 0 h 1 m 45 s.
# Epoch 451: training loss 5.656822353601456, eval loss 0.5533092692494392. Time elapsed: 0 h 1 m 58 s.
# Epoch 501: training loss 5.615412265062332, eval loss 0.5495402663946152. Time elapsed: 0 h 2 m 11 s.
# Epoch 551: training loss 5.58909173309803, eval loss 0.5469239950180054. Time elapsed: 0 h 2 m 25 s.
# Epoch 601: training loss 5.559095166623592, eval loss 0.5430294126272202. Time elapsed: 0 h 2 m 38 s.
# Epoch 651: training loss 5.51867388933897, eval loss 0.5409378111362457. Time elapsed: 0 h 2 m 51 s.
# Epoch 701: training loss 5.497773975133896, eval loss 0.5391425341367722. Time elapsed: 0 h 3 m 5 s.
# Epoch 751: training loss 5.477803081274033, eval loss 0.5381991416215897. Time elapsed: 0 h 3 m 18 s.
# Epoch 801: training loss 5.45960907638073, eval loss 0.5341884419322014. Time elapsed: 0 h 3 m 31 s.
# Epoch 851: training loss 5.4473903849720955, eval loss 0.5356985554099083. Time elapsed: 0 h 3 m 44 s.
# Epoch 901: training loss 5.433062896132469, eval loss 0.534009650349617. Time elapsed: 0 h 3 m 58 s.
# Epoch 951: training loss 5.416720487177372, eval loss 0.5383085310459137. Time elapsed: 0 h 4 m 11 s.
# Training completed with final epoch loss 5.403483971953392. Time elapsed: 0 h 4 m 24 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set:', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))
# Out:
# DNN prediction MSE error on test set: tensor(0.1061, device='cuda:0')
# Predicting mean MSE error on test set tensor(0.7494, device='cuda:0')

# %%
# MSE by output neuron
DNN_params = torch.load(f'./dnn_params/complex_lstm_5_256.pt')
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=5, output_dim=16).to(device)
DNN.load_state_dict(DNN_params)
_Y_train = 

Y_hats, Y_test = Y_hats.view(-1, 16), Y_test.view(-1,16)
for neuron in range(16):
    print(f'Output neuron {neuron+1}: \n Entropy: {str(float(calc_entropy(Y_train[:,:,neuron])))[:5]}, MSE = {str(F.mse_loss(Y_hats[:,neuron], Y_test[:, neuron]).cpu().numpy())[:5]}')
# Out:
#   File "/tmp/ipykernel_19102/1431319907.py", line 5
#     _Y_train =
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Complexity of DNN vs Data Efficiency
# What is the least complex DNN that does a good job of mimicking the approximate the complexBNN?

# %%
X_train, Y_train = load_data('./data/', 'complex_train_2.pkl')
X_test, Y_test = load_data('./data/', 'complex_test_2.pkl')
X_valid, Y_valid = load_data('./data/', 'complex_valid_2.pkl')

hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

batch_size = 200                            # number of data points in each mini-batch
n_datas = [200, 400, 800, 1600, 3200, 6400, 10000]   # number of train data used, from 1 to len(X_train)
n_epochs = 50                               # number of training epochs

# %%
train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
avg_final_eval_losses = repeated_complexity_varying_data_efficiency(
    hidden_dims=hidden_dims, n_layerss=n_layerss, n_repeats=20, verbose=True,
    **{'input_dim':16,
       'output_dim':16,
       'train_dataset':train_dataset, 
       'test_dataloader':test_dataloader,
       'n_datas':n_datas,
       'n_epochs':n_epochs,
       'batch_size': batch_size,
       'type':'MLP'})
torch.save(avg_final_eval_losses, './temp/avg_final_eval_loss_f.pt')
# Out:
# 1 of 20 repeats. Time elapsed: time elapsed: 0 h 20 m 1 soints.
# 2 of 20 repeats. Time elapsed: time elapsed: 0 h 40 m 14 sints.
# 3 of 20 repeats. Time elapsed: time elapsed: 1 h 0 m 35 soints.
# 4 of 20 repeats. Time elapsed: time elapsed: 1 h 20 m 49 sints.
# 5 of 20 repeats. Time elapsed: time elapsed: 1 h 41 m 3 soints.
# 6 of 20 repeats. Time elapsed: time elapsed: 2 h 1 m 30 soints.
# 7 of 20 repeats. Time elapsed: time elapsed: 2 h 21 m 46 sints.
# 8 of 20 repeats. Time elapsed: time elapsed: 2 h 42 m 1 soints.
# 9 of 20 repeats. Time elapsed: time elapsed: 3 h 2 m 21 soints.
# 10 of 20 repeats. Time elapsed: time elapsed: 3 h 22 m 50 snts.
# 11 of 20 repeats. Time elapsed: time elapsed: 3 h 43 m 0 sints.
# 12 of 20 repeats. Time elapsed: time elapsed: 4 h 3 m 15 sints.
# 13 of 20 repeats. Time elapsed: time elapsed: 4 h 23 m 33 snts.
# 14 of 20 repeats. Time elapsed: time elapsed: 4 h 43 m 54 snts.
# 15 of 20 repeats. Time elapsed: time elapsed: 5 h 4 m 2 soints.
# 16 of 20 repeats. Time elapsed: time elapsed: 5 h 24 m 15 snts.
# 17 of 20 repeats. Time elapsed: time elapsed: 5 h 44 m 27 snts.
# 18 of 20 repeats. Time elapsed: time elapsed: 6 h 4 m 42 sints.
# 19 of 20 repeats. Time elapsed: time elapsed: 6 h 24 m 53 snts.
# 20 of 20 repeats. Time elapsed: time elapsed: 6 h 45 m 7 sints.

# %%
avg_final_eval_losses = torch.load('./temp/avg_final_eval_loss_f.pt')
for i, n_data in enumerate(n_datas):
    print(f'Using {n_data} out of 10000 training data points')
    plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_losses[:,:,i],
                    x_label='Hidden units', y_label='Layers', z_label= f'Test set MSE loss for {n_data} training data',
                    fname='data_efficiency', figsize=(10,8))
# Out:
# Using 200 out of 10000 training data points
# Using 400 out of 10000 training data points
# Using 800 out of 10000 training data points
# Using 1600 out of 10000 training data points
# Using 3200 out of 10000 training data points
# Using 6400 out of 10000 training data points
# Using 10000 out of 10000 training data points

# %% [markdown]
# #### MLP

# %%
X_train, Y_train = load_data('./data/', 'complex_train_2.pkl')
X_test, Y_test = load_data('./data/', 'complex_test_2.pkl')
X_valid, Y_valid = load_data('./data/', 'complex_valid_2.pkl')

hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

batch_size = 200                            # number of data points in each mini-batch
n_datas = [200, 400, 800, 1600, 3200, 6400, 10000]   # number of train data used, from 1 to len(X_train)
n_epochs = 50                               # number of training epochs

# %%
train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
avg_final_eval_losses = repeated_complexity_varying_data_efficiency(
    hidden_dims=hidden_dims, n_layerss=n_layerss, n_repeats=20, verbose=True,
    **{'input_dim':16,
       'output_dim':16,
       'train_dataset':train_dataset, 
       'test_dataloader':test_dataloader,
       'n_datas':n_datas,
       'n_epochs':n_epochs,
       'batch_size': batch_size,
       'type':'RNN'})
torch.save(avg_final_eval_losses, './temp/avg_final_eval_loss_rnn.pt')

# %%
avg_final_eval_losses = torch.load('./temp/avg_final_eval_loss_f.pt')
for i, n_data in enumerate(n_datas):
    print(f'Using {n_data} out of 10000 training data points')
    plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_losses[:,:,i],
                    x_label='Hidden units', y_label='Layers', z_label= f'Test set MSE loss for {n_data} training data',
                    fname='data_efficiency', figsize=(10,8))

# %% [markdown]
# ## BNN Plasticity analysis
# We explore to what extent pre-training of a DNN helps when the plasticity of the approximate BNN is changed slightly (according to a Gaussian)

# %%
from approx_bnns import ComplexApproximateBNN

# BNN params
x, y, z = 256, 0.5, 4
bias = True
trainable = False
residual_in = [False, False, 1, 2]
num_epochs= 25

input_dim = 16
output_dim = 16
batch_size = 200
transfer_functions=[nn.ReLU(), nn.ELU(), nn.SiLU(), nn.CELU(), nn.Tanh(), nn.Sigmoid(), nn.LeakyReLU(0.1), nn.LeakyReLU(0.2), nn.LeakyReLU(0.3)]

# initialise BNN, and load original weights
approx_bnn = ComplexApproximateBNN(
    x=x, y=y, z=z, 
    input_dim=input_dim, 
    output_dim=output_dim, 
    residual_in=residual_in, 
    recurrent_dim=-1, 
    transfer_functions=transfer_functions
).to(device)

BNN_weights = torch.load('./approx_bnn_params/complex.pt')
BNN_non_linearities = load_non_linearities('./approx_bnn_params/complex_activations.pkl')
approx_bnn.load_state_dict(BNN_weights)
approx_bnn.load_non_linearities(BNN_non_linearities)

# fixing input pattern
X_train, _ = load_data('./data/', 'complex_train_2.pkl')
X_test, _ = load_data('./data/', 'complex_test_2.pkl')
X_valid, _ = load_data('./data/', 'complex_valid_2.pkl')

# %%
# initialise DNN
hidden_dim = 256
n_layers = 5
DNN_params = torch.load(f'./dnn_params/complex_lstm_5_256.pt')
DNN = RecurrentDNN(input_dim=16, hidden_dim=hidden_dim, n_linear_layers=n_layers, output_dim=16).to(device)
DNN.load_state_dict(DNN_params)
# Out:
# <All keys matched successfully>

# %%
sigmas = torch.exp(torch.linspace(-7, 4, 12))
num_epochs = 30
params = {'DNN': DNN,
          'BNN': approx_bnn, 
          'DNN_params': DNN_params, 
          'BNN_params': (BNN_weights, BNN_non_linearities), 
          'sigmas': sigmas, 
          'batch_size': batch_size,
          'num_epochs': num_epochs,
          'X_train': X_train, 
          'X_test': X_test,
          'verbose': 2}

# %%
mean_transfer, std_transfer = repeated_plasticity_analysis(n_repeats=30, transfer_learning=True, **params)
mean_retrain, std_retrain = repeated_plasticity_analysis(n_repeats=30, transfer_learning=False, **params)

train_losses_by_sigma_transfer, eval_losses_by_sigma_transfer, init_losses_by_sigma_transfer = mean_transfer
train_losses_by_sigma_reset, eval_losses_by_sigma_reset, init_losses_by_sigma_reset = mean_retrain
# Out:
# Repeat 1/30
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Plasticity applied.
# 	 New output patterns generated.
# Initial eval loss: 1.1690982431173325
# Epoch 1: training loss 15.110472276806831, eval loss 1.123396173119545. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 13.206132680177689, eval loss 1.1119572222232819. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 13.154474630951881, eval loss 1.1098483204841614. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 13.118544906377792, eval loss 1.110694631934166. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 13.099058359861374, eval loss 1.1065900325775146. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 13.083110004663467, eval loss 1.105558305978775. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 13.065491124987602, eval loss 1.1065135449171066. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 13.067638128995895, eval loss 1.1037986725568771. Time elapsed: 0 h 0 m 2 s.
# Epoch 9: training loss 13.042888164520264, eval loss 1.1021020114421844. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 13.034738972783089, eval loss 1.1047339141368866. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 13.028096154332161, eval loss 1.1032912582159042. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 13.03795213997364, eval loss 1.1027250289916992. Time elapsed: 0 h 0 m 3 s.
# Epoch 13: training loss 13.023735746741295, eval loss 1.1011472940444946. Time elapsed: 0 h 0 m 3 s.
# Epoch 14: training loss 13.025029182434082, eval loss 1.1013336181640625. Time elapsed: 0 h 0 m 3 s.
# Epoch 15: training loss 13.009921163320541, eval loss 1.0977233201265335. Time elapsed: 0 h 0 m 3 s.
# Epoch 16: training loss 13.003929123282433, eval loss 1.097551316022873. Time elapsed: 0 h 0 m 4 s.
# Epoch 17: training loss 12.999516740441322, eval loss 1.1016092598438263. Time elapsed: 0 h 0 m 4 s.
# Epoch 18: training loss 12.995905086398125, eval loss 1.0987628549337387. Time elapsed: 0 h 0 m 4 s.
# Epoch 19: training loss 12.98973959684372, eval loss 1.0964751243591309. Time elapsed: 0 h 0 m 4 s.
# Epoch 20: training loss 12.989534318447113, eval loss 1.0978201031684875. Time elapsed: 0 h 0 m 5 s.
# Epoch 21: training loss 12.99378365278244, eval loss 1.0979219824075699. Time elapsed: 0 h 0 m 5 s.
# Epoch 22: training loss 12.98722979426384, eval loss 1.0987989902496338. Time elapsed: 0 h 0 m 5 s.
# Epoch 23: training loss 12.999904975295067, eval loss 1.0993376076221466. Time elapsed: 0 h 0 m 5 s.
# Epoch 24: training loss 12.980299413204193, eval loss 1.0977834910154343. Time elapsed: 0 h 0 m 6 s.
# Epoch 25: training loss 12.990143090486526, eval loss 1.0998822152614594. Time elapsed: 0 h 0 m 6 s.
# Epoch 26: training loss 12.97320307791233, eval loss 1.0967225134372711. Time elapsed: 0 h 0 m 6 s.
# Epoch 27: training loss 12.976965561509132, eval loss 1.097282350063324. Time elapsed: 0 h 0 m 6 s.
# Epoch 28: training loss 12.981312036514282, eval loss 1.0958867222070694. Time elapsed: 0 h 0 m 7 s.
# Epoch 29: training loss 12.97924728691578, eval loss 1.0947582423686981. Time elapsed: 0 h 0 m 7 s.
# Epoch 30: training loss 12.969355627894402, eval loss 1.0973491221666336. Time elapsed: 0 h 0 m 7 s.
# Training completed with final epoch loss 12.969355627894402. Time elapsed: 0 h 0 m 7 s.
# 	 Inital eval loss: tensor([1.1691]), final eval loss: 1.0973491668701172
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Plasticity applied.
# 	 New output patterns generated.
# Initial eval loss: 1.2608115077018738
# Epoch 1: training loss 17.09084029495716, eval loss 1.1696352362632751. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 15.284054085612297, eval loss 1.151111364364624. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 15.191093191504478, eval loss 1.1470706313848495. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 15.136133015155792, eval loss 1.1433209031820297. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 15.096397116780281, eval loss 1.139659821987152. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 15.062522813677788, eval loss 1.1372406333684921. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 15.040215715765953, eval loss 1.135563150048256. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 15.01483365893364, eval loss 1.1323928087949753. Time elapsed: 0 h 0 m 2 s.
# Epoch 9: training loss 14.998757317662239, eval loss 1.1357131004333496. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 14.99208290874958, eval loss 1.1312536299228668. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 14.97640486061573, eval loss 1.1302715986967087. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 14.960882008075714, eval loss 1.128659501671791. Time elapsed: 0 h 0 m 3 s.
# Epoch 13: training loss 14.950358256697655, eval loss 1.1304891556501389. Time elapsed: 0 h 0 m 3 s.
# Epoch 14: training loss 14.94249214231968, eval loss 1.12783083319664. Time elapsed: 0 h 0 m 3 s.
# Epoch 15: training loss 14.951642960309982, eval loss 1.1286911815404892. Time elapsed: 0 h 0 m 3 s.
# Epoch 16: training loss 14.942114636301994, eval loss 1.1259512454271317. Time elapsed: 0 h 0 m 4 s.
# Epoch 17: training loss 14.927750140428543, eval loss 1.1254395842552185. Time elapsed: 0 h 0 m 4 s.
# Epoch 18: training loss 14.927884563803673, eval loss 1.128870964050293. Time elapsed: 0 h 0 m 4 s.
# Epoch 19: training loss 14.9155984967947, eval loss 1.1249786764383316. Time elapsed: 0 h 0 m 4 s.
# Epoch 20: training loss 14.905619397759438, eval loss 1.1245848536491394. Time elapsed: 0 h 0 m 5 s.
# Epoch 21: training loss 14.90103043615818, eval loss 1.1225756108760834. Time elapsed: 0 h 0 m 5 s.
# Epoch 22: training loss 14.895016714930534, eval loss 1.1248221397399902. Time elapsed: 0 h 0 m 5 s.
# Epoch 23: training loss 14.90624287724495, eval loss 1.1221534758806229. Time elapsed: 0 h 0 m 6 s.
# Epoch 24: training loss 14.897022858262062, eval loss 1.1233681291341782. Time elapsed: 0 h 0 m 6 s.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8472/3213508223.py in <module>
# ----> 1 mean_transfer, std_transfer = repeated_plasticity_analysis(n_repeats=30, transfer_learning=True, **params)
#       2 mean_retrain, std_retrain = repeated_plasticity_analysis(n_repeats=30, transfer_learning=False, **params)
#       3
#       4 train_losses_by_sigma_transfer, eval_losses_by_sigma_transfer, init_losses_by_sigma_transfer = mean_transfer
#       5 train_losses_by_sigma_reset, eval_losses_by_sigma_reset, init_losses_by_sigma_reset = mean_retrain
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in repeated_plasticity_analysis(n_repeats, transfer_learning, **kwargs)
#     442     for i in range(n_repeats):
#     443         print(f'Repeat {i+1}/{n_repeats}')
# --> 444         train_losses_by_sigma, eval_losses_by_sigma, init_eval_losses_by_sigma = plasticity_analysis(transfer_learning=transfer_learning, **kwargs)
#     445
#     446         train_losses_by_sigma_tensor[i,:] = train_losses_by_sigma
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in plasticity_analysis(transfer_learning, **kwargs)
#     418             print(f'Processing sigma={sigma} ({i+1}/{n_sigmas})')
#     419
# --> 420         sigma_train_losses, sigma_eval_losses, sigma_init_eval_loss = learning_with_plasticity(
#     421             sigma, alpha=1,
#     422             transfer_learning=transfer_learning,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in learning_with_plasticity(sigma, alpha, transfer_learning, **kwargs)
#     378
#     379     if isinstance(DNN, RecurrentDNN):
# --> 380         train_losses, eval_losses, init_eval_loss = train_rnn(
#     381             model=DNN,
#     382             train_loader=train_dataloader, test_loader=test_dataloader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in train_rnn(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop, return_init_eval_loss)
#     129                 break
#     130
# --> 131         eval_loss = eval_rnn(model, test_loader, criterion)
#     132
#     133         train_losses.append(epoch_loss)
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in eval_rnn(model, test_loader, criterion, save_Y_hat)
#     172
#     173         h_prev = torch.zeros([model.n_lstm_layers, test_loader.batch_size, model.hidden_dim]).to(device)
# --> 174         c_prev = torch.zeros([model.n_lstm_layers, test_loader.batch_size, model.hidden_dim]).to(device)
#     175         rec_prev = (h_prev, c_prev)
#     176
#
# KeyboardInterrupt:

# %%
torch.save((mean_transfer, std_transfer), './temp/RNN_plasticity_transfer_n.pt')
torch.save((mean_retrain, std_retrain), './temp/RNN_plasticity_retrain_n.pt')

# %%
(mean_transfer, std_transfer) = torch.load('./temp/RNN_plasticity_transfer_n.pt')
(mean_retrain, std_retrain) = torch.load('./temp/RNN_plasticity_retrain_n.pt')
train_losses_by_sigma_transfer, eval_losses_by_sigma_transfer, init_losses_by_sigma_transfer = mean_transfer
train_losses_by_sigma_reset, eval_losses_by_sigma_reset, init_losses_by_sigma_reset = mean_retrain

# %%
std_transfer[2]
# Out:
# tensor([0.0298, 0.1082, 0.2155, 0.3449, 0.4122, 0.7631, 0.5081, 0.4954, 0.6074,
#         0.7179, 0.5838, 0.4877])

# %%
# normal scale loss
n_sigma = sigmas.shape[0]

f, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(16,8))
plt.subplot(121)
plt.title('Evaluation loss, using trained model')
n_sigmas = len(sigmas)
for i in range(n_sigma): # for each sigma
    ax1.errorbar(np.arange(1, num_epochs+1), mean_transfer[1][i,:], yerr=std_transfer[1][i,:], label=f'sigma = e^{str(torch.log(sigmas[i]).cpu().numpy())[:4]}')
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Evaluation loss')

plt.subplot(122)
plt.title('Evaluation loss, using random initialised model')
for i in range(train_losses_by_sigma_transfer.shape[0]):
    ax2.errorbar(np.arange(1, num_epochs+1), mean_retrain[1][i,:], yerr=std_retrain[1][i,:], label=f'sigma = e^{str(torch.log(sigmas[i]).cpu().numpy())[:4]}')
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Evaluation loss')

plt.legend(bbox_to_anchor =(1, 1))

plt.savefig('./figures/plasticity_lstm.png')
plt.show()

width = 0.5
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(np.arange(mean_transfer[2].shape[0]) - width/4, mean_transfer[2], width/2, yerr = std_transfer[2], label='Trained RNN')
ax.bar(np.arange(mean_retrain[2].shape[0]) + width/4, mean_retrain[2], width/2, yerr=std_retrain[2], label='Random initialised RNN')
plt.legend()
plt.xticks(np.arange(n_sigmas), [str(i.cpu().numpy())[:4] for i in torch.log(sigmas)])
plt.xlabel('Log sigma (base e)')
plt.ylabel('Initial mean evaluation loss')
plt.title('Initial evaluation loss, varying sigma')
plt.savefig('./figures/plasticity_2_lstm.png')
plt.show()

# %%
# log scale loss
n_sigma = sigmas.shape[0]

f, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(16,8))
plt.subplot(121)
plt.title('Log evaluation loss, tranfer learning')
n_sigmas = len(sigmas)
for i in range(n_sigma): # fsor each sigma
    ax1.plot(np.arange(1, num_epochs+1), torch.log(mean_transfer[1][i,:]), label=f'sigma = e^{str(torch.log(sigmas[i]).cpu().numpy())[:4]}')

plt.xlabel('Epochs')
plt.ylabel('Log evaluation loss')

plt.subplot(122)
plt.title('Log evaluation loss, retrained learning')
for i in range(train_losses_by_sigma_transfer.shape[0]):
    ax2.plot(np.arange(1, num_epochs+1), torch.log(mean_retrain[1][i,:]), label=f'sigma = e^{str(torch.log(sigmas[i]).cpu().numpy())[:4]}')
    
plt.xlabel('Epochs')
plt.ylabel('Log evaluation loss')

plt.legend(bbox_to_anchor =(1, 1))

plt.savefig('./figures/plasticity_lstm_log.png')
plt.show()

width = 0.5
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(np.arange(mean_transfer[2].shape[0]) - width/4, mean_transfer[2], width/2, label='Transfer learning')
ax.bar(np.arange(mean_retrain[2].shape[0]) + width/4, mean_retrain[2], width/2, label='Random init')
plt.legend()
plt.xticks(np.arange(n_sigmas), [str(i.cpu().numpy())[:4] for i in torch.log(sigmas)])
plt.xlabel('Log Gaussian noise std')
plt.ylabel('Initial mean evaluation loss')
plt.title('Initial evaluation loss, varying sigma')
plt.savefig('./figures/plasticity_2_lstm_log.png')
plt.show()

# %% [markdown]
# #### MLP

# %%
from approx_bnns import ComplexApproximateBNN

# BNN params
x, y, z = 256, 0.5, 4
bias = True
trainable = False
residual_in = [False, False, 1, 2]
num_epochs= 25

input_dim = 16
output_dim = 16
batch_size = 200
transfer_functions=[nn.ReLU(), nn.ELU(), nn.SiLU(), nn.CELU(), nn.Tanh(), nn.Sigmoid(), nn.LeakyReLU(0.1), nn.LeakyReLU(0.2), nn.LeakyReLU(0.3)]

# initialise BNN, and load original weights
approx_bnn = ComplexApproximateBNN(
    x=x, y=y, z=z, 
    input_dim=input_dim, 
    output_dim=output_dim, 
    residual_in=residual_in, 
    recurrent_dim=-1, 
    transfer_functions=transfer_functions
).to(device)

BNN_weights = torch.load('./approx_bnn_params/complex.pt')
BNN_non_linearities = load_non_linearities('./approx_bnn_params/complex_activations.pkl')
approx_bnn.load_state_dict(BNN_weights)
approx_bnn.load_non_linearities(BNN_non_linearities)

# fixing input pattern
X_train, _ = load_data('./data/', 'complex_train_2.pkl')
X_test, _ = load_data('./data/', 'complex_test_2.pkl')
X_valid, _ = load_data('./data/', 'complex_valid_2.pkl')

# initialise DNN
hidden_dim = 256
n_layers = 2
DNN_params = torch.load(f'./dnn_params/complex_mlp_{n_layers}_{hidden_dim}.pt')
DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)
DNN.load_state_dict(DNN_params)
# Out:
# <All keys matched successfully>

# %%
sigmas = torch.exp(torch.linspace(-7, 4, 12))
num_epochs = 30
params = {'DNN': DNN,
          'BNN': approx_bnn, 
          'DNN_params': DNN_params, 
          'BNN_params': (BNN_weights, BNN_non_linearities), 
          'sigmas': sigmas, 
          'batch_size': batch_size,
          'num_epochs': num_epochs,
          'X_train': X_train, 
          'X_test': X_test,
          'verbose': 1}

# %%
mean_transfer, std_transfer = repeated_plasticity_analysis(n_repeats=20, transfer_learning=True, **params)
mean_retrain, std_retrain = repeated_plasticity_analysis(n_repeats=20, transfer_learning=False, **params)

train_losses_by_sigma_transfer, eval_losses_by_sigma_transfer, init_losses_by_sigma_transfer = mean_transfer
train_losses_by_sigma_reset, eval_losses_by_sigma_reset, init_losses_by_sigma_reset = mean_retrain

torch.save((mean_transfer, std_transfer), './temp/MLP_plasticity_transfer_n.pt')
torch.save((mean_retrain, std_retrain), './temp/MLP_plasticity_retrain_n.pt')
# Out:
# Repeat 1/20
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Inital eval loss: tensor([1.3016]), final eval loss: 1.3024948835372925
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Inital eval loss: tensor([1.4119]), final eval loss: 1.2958441972732544
# Processing sigma=0.0067379469983279705 (3/12)
# 	 Inital eval loss: tensor([1.7993]), final eval loss: 1.173655390739441
# Processing sigma=0.018315639346837997 (4/12)
# 	 Inital eval loss: tensor([2.9221]), final eval loss: 1.2977118492126465
# Processing sigma=0.049787066876888275 (5/12)
# 	 Inital eval loss: tensor([4.1855]), final eval loss: 1.1416559219360352
# Processing sigma=0.1353352814912796 (6/12)
# 	 Inital eval loss: tensor([6.1602]), final eval loss: 0.8572940826416016
# Processing sigma=0.3678794503211975 (7/12)
# 	 Inital eval loss: tensor([6.9574]), final eval loss: 0.9857178926467896
# Processing sigma=1.0 (8/12)
# 	 Inital eval loss: tensor([6.4211]), final eval loss: 0.4323742985725403
# Processing sigma=2.7182817459106445 (9/12)
# 	 Inital eval loss: tensor([6.8091]), final eval loss: 0.5438365936279297
# Processing sigma=7.389056205749512 (10/12)
# 	 Inital eval loss: tensor([7.4446]), final eval loss: 0.3789437711238861
# Processing sigma=20.08553695678711 (11/12)
# 	 Inital eval loss: tensor([7.4060]), final eval loss: 0.45673733949661255
# Processing sigma=54.598148345947266 (12/12)
# 	 Inital eval loss: tensor([7.8467]), final eval loss: 0.44909173250198364
# Repeat 2/20
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Inital eval loss: tensor([1.3306]), final eval loss: 1.2731356620788574
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Inital eval loss: tensor([1.2816]), final eval loss: 1.1902024745941162
# Processing sigma=0.0067379469983279705 (3/12)
# 	 Inital eval loss: tensor([1.7326]), final eval loss: 1.199836254119873
# Processing sigma=0.018315639346837997 (4/12)
# 	 Inital eval loss: tensor([3.5919]), final eval loss: 1.1695044040679932
# Processing sigma=0.049787066876888275 (5/12)
# 	 Inital eval loss: tensor([5.1579]), final eval loss: 1.6438961029052734
# Processing sigma=0.1353352814912796 (6/12)
# 	 Inital eval loss: tensor([6.3524]), final eval loss: 1.0105617046356201
# Processing sigma=0.3678794503211975 (7/12)
# 	 Inital eval loss: tensor([6.1177]), final eval loss: 0.7963167428970337
# Processing sigma=1.0 (8/12)
# 	 Inital eval loss: tensor([6.7604]), final eval loss: 0.5689099431037903
# Processing sigma=2.7182817459106445 (9/12)
# 	 Inital eval loss: tensor([6.8999]), final eval loss: 0.6093606352806091
# Processing sigma=7.389056205749512 (10/12)
# 	 Inital eval loss: tensor([7.2560]), final eval loss: 0.7306768894195557
# Processing sigma=20.08553695678711 (11/12)
# 	 Inital eval loss: tensor([7.5332]), final eval loss: 0.6834443807601929
# Processing sigma=54.598148345947266 (12/12)
# 	 Inital eval loss: tensor([7.7724]), final eval loss: 0.4046460688114166
# Repeat 3/20
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Inital eval loss: tensor([1.2716]), final eval loss: 1.1468802690505981
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Inital eval loss: tensor([1.3198]), final eval loss: 1.221559762954712
# Processing sigma=0.0067379469983279705 (3/12)
# 	 Inital eval loss: tensor([1.7340]), final eval loss: 1.3701730966567993
# Processing sigma=0.018315639346837997 (4/12)
# 	 Inital eval loss: tensor([2.5870]), final eval loss: 0.9516468048095703
# Processing sigma=0.049787066876888275 (5/12)
# 	 Inital eval loss: tensor([3.9563]), final eval loss: 0.8715723752975464
# Processing sigma=0.1353352814912796 (6/12)
# 	 Inital eval loss: tensor([6.7561]), final eval loss: 0.9700832366943359
# Processing sigma=0.3678794503211975 (7/12)
# 	 Inital eval loss: tensor([6.7759]), final eval loss: 1.070881962776184
# Processing sigma=1.0 (8/12)
# 	 Inital eval loss: tensor([7.3471]), final eval loss: 0.8726704716682434
# Processing sigma=2.7182817459106445 (9/12)
# 	 Inital eval loss: tensor([6.5984]), final eval loss: 0.4797401428222656
# Processing sigma=7.389056205749512 (10/12)
# 	 Inital eval loss: tensor([6.8246]), final eval loss: 0.6423709988594055
# Processing sigma=20.08553695678711 (11/12)
# 	 Inital eval loss: tensor([6.6082]), final eval loss: 0.7284692525863647
# Processing sigma=54.598148345947266 (12/12)
# 	 Inital eval loss: tensor([6.9297]), final eval loss: 0.4173714816570282
# Repeat 4/20
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Inital eval loss: tensor([1.2753]), final eval loss: 1.3189669847488403
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Inital eval loss: tensor([1.3478]), final eval loss: 1.147181510925293
# Processing sigma=0.0067379469983279705 (3/12)
# 	 Inital eval loss: tensor([1.4635]), final eval loss: 0.9322077631950378
# Processing sigma=0.018315639346837997 (4/12)
# 	 Inital eval loss: tensor([2.7055]), final eval loss: 1.149505376815796
# Processing sigma=0.049787066876888275 (5/12)
# 	 Inital eval loss: tensor([5.1359]), final eval loss: 1.3345190286636353
# Processing sigma=0.1353352814912796 (6/12)
# 	 Inital eval loss: tensor([6.4310]), final eval loss: 0.8028721809387207
# Processing sigma=0.3678794503211975 (7/12)
# 	 Inital eval loss: tensor([6.7946]), final eval loss: 1.1277496814727783
# Processing sigma=1.0 (8/12)
# 	 Inital eval loss: tensor([6.6434]), final eval loss: 0.9091914892196655
# Processing sigma=2.7182817459106445 (9/12)
# 	 Inital eval loss: tensor([6.7497]), final eval loss: 0.3458471894264221
# Processing sigma=7.389056205749512 (10/12)
# 	 Inital eval loss: tensor([6.2244]), final eval loss: 0.42233604192733765
# Processing sigma=20.08553695678711 (11/12)
# 	 Inital eval loss: tensor([6.4629]), final eval loss: 0.25431370735168457
# Processing sigma=54.598148345947266 (12/12)
# 	 Inital eval loss: tensor([5.9314]), final eval loss: 0.14953738451004028
# Repeat 5/20
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Inital eval loss: tensor([1.3194]), final eval loss: 1.2521421909332275
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Inital eval loss: tensor([1.3260]), final eval loss: 1.0966567993164062
# Processing sigma=0.0067379469983279705 (3/12)
# 	 Inital eval loss: tensor([2.0971]), final eval loss: 1.4028950929641724
# Processing sigma=0.018315639346837997 (4/12)
# 	 Inital eval loss: tensor([1.8824]), final eval loss: 0.8167215585708618
# Processing sigma=0.049787066876888275 (5/12)
# 	 Inital eval loss: tensor([4.2794]), final eval loss: 1.0455971956253052
# Processing sigma=0.1353352814912796 (6/12)
# 	 Inital eval loss: tensor([6.9177]), final eval loss: 1.0877737998962402
# Processing sigma=0.3678794503211975 (7/12)
# 	 Inital eval loss: tensor([7.5826]), final eval loss: 0.9753514528274536
# Processing sigma=1.0 (8/12)
# 	 Inital eval loss: tensor([6.6604]), final eval loss: 0.6899504065513611
# Processing sigma=2.7182817459106445 (9/12)
# 	 Inital eval loss: tensor([6.7029]), final eval loss: 0.25298094749450684
# Processing sigma=7.389056205749512 (10/12)
# 	 Inital eval loss: tensor([6.5629]), final eval loss: 0.21162210404872894
# Processing sigma=20.08553695678711 (11/12)
# 	 Inital eval loss: tensor([6.5908]), final eval loss: 0.4294951558113098
# Processing sigma=54.598148345947266 (12/12)
# 	 Inital eval loss: tensor([7.0732]), final eval loss: 0.7625426650047302
# Repeat 6/20
# Processing sigma=0.0009118819725699723 (1/12)
# 	 Inital eval loss: tensor([1.2756]), final eval loss: 1.1836419105529785
# Processing sigma=0.0024787522852420807 (2/12)
# 	 Inital eval loss: tensor([1.3544]), final eval loss: 1.2518969774246216
# Processing sigma=0.0067379469983279705 (3/12)
# 	 Inital eval loss: tensor([1.7191]), final eval loss: 0.8862298727035522
# Processing sigma=0.018315639346837997 (4/12)
# 	 Inital eval loss: tensor([3.0549]), final eval loss: 0.9583472013473511
# Processing sigma=0.049787066876888275 (5/12)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9803/1438207648.py in <module>
# ----> 1 mean_transfer, std_transfer = repeated_plasticity_analysis(n_repeats=20, transfer_learning=True, **params)
#       2 mean_retrain, std_retrain = repeated_plasticity_analysis(n_repeats=20, transfer_learning=False, **params)
#       3
#       4 train_losses_by_sigma_transfer, eval_losses_by_sigma_transfer, init_losses_by_sigma_transfer = mean_transfer
#       5 train_losses_by_sigma_reset, eval_losses_by_sigma_reset, init_losses_by_sigma_reset = mean_retrain
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in repeated_plasticity_analysis(n_repeats, transfer_learning, **kwargs)
#     435     for i in range(n_repeats):
#     436         print(f'Repeat {i+1}/{n_repeats}')
# --> 437         train_losses_by_sigma, eval_losses_by_sigma, init_eval_losses_by_sigma = plasticity_analysis(transfer_learning=transfer_learning, **kwargs)
#     438
#     439         train_losses_by_sigma_tensor[i,:] = train_losses_by_sigma
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in plasticity_analysis(transfer_learning, **kwargs)
#     411             print(f'Processing sigma={sigma} ({i+1}/{n_sigmas})')
#     412
# --> 413         sigma_train_losses, sigma_eval_losses, sigma_init_eval_loss = learning_with_plasticity(
#     414             sigma, alpha=1,
#     415             transfer_learning=transfer_learning,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in learning_with_plasticity(sigma, alpha, transfer_learning, **kwargs)
#     364
#     365     if isinstance(DNN, FeedForwardDNN):
# --> 366         train_losses, eval_losses, init_eval_loss = train(
#     367             model=DNN,
#     368             train_loader=train_dataloader, test_loader=test_dataloader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop, return_init_eval_loss)
#      37
#      38             optimiser.zero_grad()
# ---> 39             loss.backward()
#      40             optimiser.step()
#      41
#
# ~/.local/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# ~/.local/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ######

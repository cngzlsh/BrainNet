# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import random
import numpy as np
import time
import seaborn as sns

from models import *
from utils import *
from train import *
from bvc import *
from gen_data import *

sns.set(font_scale=1.2)
seed = 1234
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## BNN Architectures

# %% [markdown]
# ### Feedforward BNN

# %%
X_train, Y_train = load_data('./data/', 'train_feedforward.pkl')
X_test, Y_test = load_data('./data/', 'test_feedforward.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_feedforward.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30,
    **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 2, final eval loss: 141.22335052490234, time elapsed: 0 h 2 m 34 s
# 2th repeat: best hidden unit: 256, best layers: 2, final eval loss: 141.7338581085205, time elapsed: 0 h 5 m 14 s
# 3th repeat: best hidden unit: 256, best layers: 2, final eval loss: 138.85082054138184, time elapsed: 0 h 7 m 56 s
# 4th repeat: best hidden unit: 256, best layers: 1, final eval loss: 144.4536018371582, time elapsed: 0 h 10 m 37 s
# 5th repeat: best hidden unit: 256, best layers: 2, final eval loss: 142.92336654663086, time elapsed: 0 h 13 m 16 s
# 6th repeat: best hidden unit: 256, best layers: 2, final eval loss: 137.20208740234375, time elapsed: 0 h 15 m 56 s
# 7th repeat: best hidden unit: 256, best layers: 2, final eval loss: 139.44629669189453, time elapsed: 0 h 18 m 32 s
# 8th repeat: best hidden unit: 256, best layers: 1, final eval loss: 144.1831169128418, time elapsed: 0 h 21 m 8 s
# 9th repeat: best hidden unit: 256, best layers: 2, final eval loss: 140.70091247558594, time elapsed: 0 h 23 m 47 s
# 10th repeat: best hidden unit: 256, best layers: 2, final eval loss: 142.487154006958, time elapsed: 0 h 26 m 25 s
# 11th repeat: best hidden unit: 256, best layers: 3, final eval loss: 141.04235458374023, time elapsed: 0 h 29 m 0 s
# 12th repeat: best hidden unit: 256, best layers: 2, final eval loss: 140.63730430603027, time elapsed: 0 h 31 m 42 s
# 13th repeat: best hidden unit: 256, best layers: 3, final eval loss: 141.8565673828125, time elapsed: 0 h 34 m 24 s
# 14th repeat: best hidden unit: 256, best layers: 2, final eval loss: 140.32196044921875, time elapsed: 0 h 37 m 3 s
# 15th repeat: best hidden unit: 256, best layers: 2, final eval loss: 139.84855461120605, time elapsed: 0 h 39 m 37 s
# 16th repeat: best hidden unit: 256, best layers: 3, final eval loss: 142.1920623779297, time elapsed: 0 h 42 m 15 s
# 17th repeat: best hidden unit: 256, best layers: 3, final eval loss: 140.15893363952637, time elapsed: 0 h 44 m 53 s
# 18th repeat: best hidden unit: 256, best layers: 3, final eval loss: 143.05124855041504, time elapsed: 0 h 47 m 28 s
# 19th repeat: best hidden unit: 256, best layers: 2, final eval loss: 139.59173774719238, time elapsed: 0 h 50 m 6 s
# 20th repeat: best hidden unit: 256, best layers: 3, final eval loss: 142.52979278564453, time elapsed: 0 h 52 m 40 s
# 21th repeat: best hidden unit: 256, best layers: 2, final eval loss: 141.32933044433594, time elapsed: 0 h 55 m 19 s
# 22th repeat: best hidden unit: 256, best layers: 2, final eval loss: 140.7585620880127, time elapsed: 0 h 57 m 56 s
# 23th repeat: best hidden unit: 256, best layers: 3, final eval loss: 141.69279861450195, time elapsed: 1 h 0 m 33 s
# 24th repeat: best hidden unit: 256, best layers: 1, final eval loss: 142.86149978637695, time elapsed: 1 h 3 m 9 s
# 25th repeat: best hidden unit: 256, best layers: 2, final eval loss: 142.05709648132324, time elapsed: 1 h 5 m 45 s
# 26th repeat: best hidden unit: 256, best layers: 3, final eval loss: 143.43553733825684, time elapsed: 1 h 8 m 20 s
# 27th repeat: best hidden unit: 256, best layers: 2, final eval loss: 142.43503189086914, time elapsed: 1 h 10 m 57 s
# 28th repeat: best hidden unit: 256, best layers: 3, final eval loss: 140.97901344299316, time elapsed: 1 h 13 m 32 s
# 29th repeat: best hidden unit: 256, best layers: 2, final eval loss: 143.46271896362305, time elapsed: 1 h 16 m 10 s
# 30th repeat: best hidden unit: 256, best layers: 2, final eval loss: 139.8723602294922, time elapsed: 1 h 18 m 45 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='feedforward_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='feedforward')
# Out:
# Best hidden unit: 256, best layers: 2

# %% [markdown]
# ####  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=2, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 938.6788635253906
# Epoch 1: training loss 3683.9919624328613, eval loss 231.30731964111328. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 2259.350528717041, eval loss 194.38750839233398. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 1965.1255493164062, eval loss 174.22750854492188. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 1833.3203659057617, eval loss 167.44962120056152. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 1759.7200355529785, eval loss 162.05692291259766. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 1714.5260963439941, eval loss 161.70360565185547. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 1667.273115158081, eval loss 160.11888885498047. Time elapsed: 0 h 0 m 0 s.
# Epoch 8: training loss 1642.380527496338, eval loss 166.23450660705566. Time elapsed: 0 h 0 m 0 s.
# Epoch 9: training loss 1620.2456741333008, eval loss 152.46929359436035. Time elapsed: 0 h 0 m 0 s.
# Epoch 10: training loss 1576.1107196807861, eval loss 149.77209663391113. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 1557.5366954803467, eval loss 148.69305229187012. Time elapsed: 0 h 0 m 1 s.
# Epoch 12: training loss 1535.6963481903076, eval loss 148.96282196044922. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 1511.49294090271, eval loss 144.44221687316895. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 1514.7649002075195, eval loss 143.3098487854004. Time elapsed: 0 h 0 m 1 s.
# Epoch 15: training loss 1484.1605911254883, eval loss 143.83123588562012. Time elapsed: 0 h 0 m 1 s.
# Epoch 16: training loss 1470.767744064331, eval loss 141.9089813232422. Time elapsed: 0 h 0 m 1 s.
# Epoch 17: training loss 1445.4355926513672, eval loss 140.85528945922852. Time elapsed: 0 h 0 m 1 s.
# Epoch 18: training loss 1448.275556564331, eval loss 139.3789176940918. Time elapsed: 0 h 0 m 1 s.
# Epoch 19: training loss 1423.578441619873, eval loss 138.91377067565918. Time elapsed: 0 h 0 m 1 s.
# Epoch 20: training loss 1406.7482643127441, eval loss 140.09947395324707. Time elapsed: 0 h 0 m 2 s.
# Epoch 21: training loss 1387.8071212768555, eval loss 136.76476669311523. Time elapsed: 0 h 0 m 2 s.
# Epoch 22: training loss 1398.7671127319336, eval loss 137.22430229187012. Time elapsed: 0 h 0 m 2 s.
# Epoch 23: training loss 1374.660535812378, eval loss 136.14634895324707. Time elapsed: 0 h 0 m 2 s.
# Epoch 24: training loss 1355.1491775512695, eval loss 136.160400390625. Time elapsed: 0 h 0 m 2 s.
# Epoch 25: training loss 1341.3583736419678, eval loss 135.07309913635254. Time elapsed: 0 h 0 m 2 s.
# Epoch 26: training loss 1337.073968887329, eval loss 133.2978744506836. Time elapsed: 0 h 0 m 2 s.
# Epoch 27: training loss 1323.3251209259033, eval loss 133.1180934906006. Time elapsed: 0 h 0 m 2 s.
# Epoch 28: training loss 1322.921775817871, eval loss 134.0179958343506. Time elapsed: 0 h 0 m 2 s.
# Epoch 29: training loss 1305.7043228149414, eval loss 132.94062614440918. Time elapsed: 0 h 0 m 2 s.
# Epoch 30: training loss 1298.028636932373, eval loss 134.60043716430664. Time elapsed: 0 h 0 m 3 s.
# Epoch 31: training loss 1300.6336994171143, eval loss 136.46331214904785. Time elapsed: 0 h 0 m 3 s.
# Epoch 32: training loss 1289.4035415649414, eval loss 132.62932205200195. Time elapsed: 0 h 0 m 3 s.
# Epoch 33: training loss 1269.5166320800781, eval loss 131.48725700378418. Time elapsed: 0 h 0 m 3 s.
# Epoch 34: training loss 1254.8462257385254, eval loss 131.53752326965332. Time elapsed: 0 h 0 m 3 s.
# Epoch 35: training loss 1259.116750717163, eval loss 131.22965812683105. Time elapsed: 0 h 0 m 3 s.
# Epoch 36: training loss 1240.741439819336, eval loss 130.18469429016113. Time elapsed: 0 h 0 m 3 s.
# Epoch 37: training loss 1231.037784576416, eval loss 130.4675235748291. Time elapsed: 0 h 0 m 3 s.
# Epoch 38: training loss 1232.626163482666, eval loss 133.42804718017578. Time elapsed: 0 h 0 m 3 s.
# Epoch 39: training loss 1219.9860286712646, eval loss 131.17528915405273. Time elapsed: 0 h 0 m 3 s.
# Epoch 40: training loss 1215.997817993164, eval loss 129.45221328735352. Time elapsed: 0 h 0 m 3 s.
# Epoch 41: training loss 1201.2181663513184, eval loss 129.19656562805176. Time elapsed: 0 h 0 m 4 s.
# Epoch 42: training loss 1201.9436130523682, eval loss 129.4945831298828. Time elapsed: 0 h 0 m 4 s.
# Epoch 43: training loss 1206.740758895874, eval loss 129.4179401397705. Time elapsed: 0 h 0 m 4 s.
# Epoch 44: training loss 1186.8278732299805, eval loss 129.1261920928955. Time elapsed: 0 h 0 m 4 s.
# Epoch 45: training loss 1178.8952751159668, eval loss 129.3380947113037. Time elapsed: 0 h 0 m 4 s.
# Epoch 46: training loss 1169.0529136657715, eval loss 130.23491859436035. Time elapsed: 0 h 0 m 4 s.
# Epoch 47: training loss 1180.9518032073975, eval loss 130.685640335083. Time elapsed: 0 h 0 m 4 s.
# Epoch 48: training loss 1163.4279823303223, eval loss 128.7744197845459. Time elapsed: 0 h 0 m 4 s.
# Epoch 49: training loss 1158.4260654449463, eval loss 134.60566520690918. Time elapsed: 0 h 0 m 4 s.
# Epoch 50: training loss 1154.0984153747559, eval loss 131.135160446167. Time elapsed: 0 h 0 m 5 s.
# Training completed with final epoch loss 1154.0984153747559. Time elapsed: 0 h 0 m 5 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad(): 
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(26.2254, device='cuda:0')
# Predicting mean MSE error on test set tensor(49.7605, device='cuda:0')

# %% [markdown]
# ### Residual BNN

# %%
X_train, Y_train = load_data('./data/', 'train_residual.pkl')
X_test, Y_test = load_data('./data/', 'test_residual.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_residual.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 4, final eval loss: 129.3865509033203, time elapsed: 0 h 2 m 31 s
# 2th repeat: best hidden unit: 256, best layers: 3, final eval loss: 126.16235733032227, time elapsed: 0 h 5 m 8 s
# 3th repeat: best hidden unit: 256, best layers: 2, final eval loss: 130.1229419708252, time elapsed: 0 h 7 m 45 s
# 4th repeat: best hidden unit: 256, best layers: 2, final eval loss: 128.64162254333496, time elapsed: 0 h 10 m 21 s
# 5th repeat: best hidden unit: 256, best layers: 3, final eval loss: 130.41333770751953, time elapsed: 0 h 12 m 58 s
# 6th repeat: best hidden unit: 128, best layers: 2, final eval loss: 130.77836227416992, time elapsed: 0 h 15 m 32 s
# 7th repeat: best hidden unit: 256, best layers: 2, final eval loss: 126.63008308410645, time elapsed: 0 h 18 m 9 s
# 8th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.68722152709961, time elapsed: 0 h 20 m 45 s
# 9th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.49601936340332, time elapsed: 0 h 23 m 23 s
# 10th repeat: best hidden unit: 256, best layers: 3, final eval loss: 129.8715991973877, time elapsed: 0 h 26 m 0 s
# 11th repeat: best hidden unit: 256, best layers: 2, final eval loss: 128.29298210144043, time elapsed: 0 h 28 m 35 s
# 12th repeat: best hidden unit: 256, best layers: 2, final eval loss: 128.78513145446777, time elapsed: 0 h 31 m 11 s
# 13th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.99510383605957, time elapsed: 0 h 33 m 47 s
# 14th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.53011894226074, time elapsed: 0 h 36 m 24 s
# 15th repeat: best hidden unit: 256, best layers: 3, final eval loss: 127.72626495361328, time elapsed: 0 h 39 m 4 s
# 16th repeat: best hidden unit: 256, best layers: 2, final eval loss: 126.64908599853516, time elapsed: 0 h 41 m 40 s
# 17th repeat: best hidden unit: 256, best layers: 2, final eval loss: 126.64358139038086, time elapsed: 0 h 44 m 17 s
# 18th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.10261154174805, time elapsed: 0 h 46 m 52 s
# 19th repeat: best hidden unit: 256, best layers: 2, final eval loss: 125.42268371582031, time elapsed: 0 h 49 m 29 s
# 20th repeat: best hidden unit: 256, best layers: 2, final eval loss: 130.1729965209961, time elapsed: 0 h 52 m 6 s
# 21th repeat: best hidden unit: 256, best layers: 3, final eval loss: 127.20020866394043, time elapsed: 0 h 54 m 44 s
# 22th repeat: best hidden unit: 256, best layers: 3, final eval loss: 130.04102325439453, time elapsed: 0 h 57 m 18 s
# 23th repeat: best hidden unit: 256, best layers: 2, final eval loss: 126.17791748046875, time elapsed: 0 h 59 m 55 s
# 24th repeat: best hidden unit: 256, best layers: 3, final eval loss: 127.09599494934082, time elapsed: 1 h 2 m 32 s
# 25th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.78939437866211, time elapsed: 1 h 5 m 10 s
# 26th repeat: best hidden unit: 256, best layers: 2, final eval loss: 126.64213562011719, time elapsed: 1 h 7 m 48 s
# 27th repeat: best hidden unit: 256, best layers: 2, final eval loss: 127.76581001281738, time elapsed: 1 h 10 m 25 s
# 28th repeat: best hidden unit: 256, best layers: 2, final eval loss: 128.61893272399902, time elapsed: 1 h 13 m 2 s
# 29th repeat: best hidden unit: 256, best layers: 2, final eval loss: 129.85380172729492, time elapsed: 1 h 15 m 37 s
# 30th repeat: best hidden unit: 256, best layers: 2, final eval loss: 129.09510803222656, time elapsed: 1 h 18 m 15 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='residual_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='residual')
# Out:
# Best hidden unit: 256, best layers: 2

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=2, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 356.96697998046875
# Epoch 1: training loss 2341.1155738830566, eval loss 197.21641540527344. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 1703.3797092437744, eval loss 161.9344539642334. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 1546.9731063842773, eval loss 155.7658863067627. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 1493.5850925445557, eval loss 150.28374481201172. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 1450.0882110595703, eval loss 149.32929611206055. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 1422.2779331207275, eval loss 142.55597496032715. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 1377.0714702606201, eval loss 140.67930030822754. Time elapsed: 0 h 0 m 0 s.
# Epoch 8: training loss 1352.8391914367676, eval loss 137.65377807617188. Time elapsed: 0 h 0 m 0 s.
# Epoch 9: training loss 1321.9972286224365, eval loss 135.46502304077148. Time elapsed: 0 h 0 m 0 s.
# Epoch 10: training loss 1300.6969757080078, eval loss 133.16209983825684. Time elapsed: 0 h 0 m 0 s.
# Epoch 11: training loss 1286.7621002197266, eval loss 131.7626667022705. Time elapsed: 0 h 0 m 1 s.
# Epoch 12: training loss 1254.8009128570557, eval loss 129.5515308380127. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 1241.01877784729, eval loss 130.67212104797363. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 1226.6707744598389, eval loss 126.84977531433105. Time elapsed: 0 h 0 m 1 s.
# Epoch 15: training loss 1208.438377380371, eval loss 127.32165718078613. Time elapsed: 0 h 0 m 1 s.
# Epoch 16: training loss 1198.8464488983154, eval loss 125.2487564086914. Time elapsed: 0 h 0 m 1 s.
# Epoch 17: training loss 1184.5005340576172, eval loss 125.69072723388672. Time elapsed: 0 h 0 m 1 s.
# Epoch 18: training loss 1177.162181854248, eval loss 124.52946090698242. Time elapsed: 0 h 0 m 1 s.
# Epoch 19: training loss 1156.236738204956, eval loss 122.02039527893066. Time elapsed: 0 h 0 m 1 s.
# Epoch 20: training loss 1160.0827045440674, eval loss 124.08483123779297. Time elapsed: 0 h 0 m 2 s.
# Epoch 21: training loss 1152.6403713226318, eval loss 122.6728286743164. Time elapsed: 0 h 0 m 2 s.
# Epoch 22: training loss 1117.8942985534668, eval loss 121.04107856750488. Time elapsed: 0 h 0 m 2 s.
# Epoch 23: training loss 1110.4965744018555, eval loss 122.01426315307617. Time elapsed: 0 h 0 m 2 s.
# Epoch 24: training loss 1110.0361022949219, eval loss 122.80097389221191. Time elapsed: 0 h 0 m 2 s.
# Epoch 25: training loss 1102.1770572662354, eval loss 120.44303894042969. Time elapsed: 0 h 0 m 2 s.
# Epoch 26: training loss 1095.5538177490234, eval loss 120.56372833251953. Time elapsed: 0 h 0 m 2 s.
# Epoch 27: training loss 1079.4001998901367, eval loss 120.59339714050293. Time elapsed: 0 h 0 m 2 s.
# Epoch 28: training loss 1078.4584789276123, eval loss 119.94881439208984. Time elapsed: 0 h 0 m 2 s.
# Epoch 29: training loss 1065.8374423980713, eval loss 119.66458320617676. Time elapsed: 0 h 0 m 2 s.
# Epoch 30: training loss 1053.1533298492432, eval loss 118.17912483215332. Time elapsed: 0 h 0 m 3 s.
# Epoch 31: training loss 1045.851022720337, eval loss 118.03595352172852. Time elapsed: 0 h 0 m 3 s.
# Epoch 32: training loss 1038.7396354675293, eval loss 119.39124488830566. Time elapsed: 0 h 0 m 3 s.
# Epoch 33: training loss 1031.1475811004639, eval loss 117.90824317932129. Time elapsed: 0 h 0 m 3 s.
# Epoch 34: training loss 1027.9474906921387, eval loss 119.28504753112793. Time elapsed: 0 h 0 m 3 s.
# Epoch 35: training loss 1022.4565505981445, eval loss 117.48520278930664. Time elapsed: 0 h 0 m 3 s.
# Epoch 36: training loss 1009.4344120025635, eval loss 118.68157196044922. Time elapsed: 0 h 0 m 3 s.
# Epoch 37: training loss 1002.5474262237549, eval loss 117.1242904663086. Time elapsed: 0 h 0 m 3 s.
# Epoch 38: training loss 1001.0015239715576, eval loss 118.2498893737793. Time elapsed: 0 h 0 m 3 s.
# Epoch 39: training loss 992.8280429840088, eval loss 117.21410369873047. Time elapsed: 0 h 0 m 3 s.
# Epoch 40: training loss 990.6069660186768, eval loss 117.69160842895508. Time elapsed: 0 h 0 m 4 s.
# Epoch 41: training loss 981.0418109893799, eval loss 115.88250732421875. Time elapsed: 0 h 0 m 4 s.
# Epoch 42: training loss 967.625452041626, eval loss 116.22832489013672. Time elapsed: 0 h 0 m 4 s.
# Epoch 43: training loss 974.3389015197754, eval loss 117.06332778930664. Time elapsed: 0 h 0 m 4 s.
# Epoch 44: training loss 967.1609401702881, eval loss 115.40846252441406. Time elapsed: 0 h 0 m 4 s.
# Epoch 45: training loss 957.8436794281006, eval loss 116.29640769958496. Time elapsed: 0 h 0 m 4 s.
# Epoch 46: training loss 955.3015689849854, eval loss 117.20666885375977. Time elapsed: 0 h 0 m 4 s.
# Epoch 47: training loss 958.434175491333, eval loss 115.26151657104492. Time elapsed: 0 h 0 m 4 s.
# Epoch 48: training loss 935.9335117340088, eval loss 115.94505882263184. Time elapsed: 0 h 0 m 4 s.
# Epoch 49: training loss 927.9811973571777, eval loss 114.72525405883789. Time elapsed: 0 h 0 m 4 s.
# Epoch 50: training loss 920.8930778503418, eval loss 115.83560752868652. Time elapsed: 0 h 0 m 4 s.
# Training completed with final epoch loss 920.8930778503418. Time elapsed: 0 h 0 m 4 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(23.1672, device='cuda:0')
# Predicting mean MSE error on test set tensor(46.0941, device='cuda:0')

# %% [markdown]
# ### Recurrent BNN

# %%
X_train, Y_train = load_data('./data/', 'train_recurrent.pkl')
X_test, Y_test = load_data('./data/', 'test_recurrent.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_recurrent.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
_X_train = X_train.view(-1, 16)
_Y_train = Y_train.view(-1, 16)
_X_test = X_test.view(-1, 16)
_Y_test = Y_test.view(-1, 16)

_train_dataset = BNN_Dataset(_X_train, _Y_train)
_train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

_test_dataset = BNN_Dataset(_X_test, _Y_test)
_test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 4, final eval loss: 52.54654312133789, time elapsed: 0 h 3 m 11 s
# 2th repeat: best hidden unit: 256, best layers: 3, final eval loss: 52.23818778991699, time elapsed: 0 h 6 m 36 s
# 3th repeat: best hidden unit: 256, best layers: 2, final eval loss: 52.10281276702881, time elapsed: 0 h 9 m 56 s
# 4th repeat: best hidden unit: 256, best layers: 5, final eval loss: 52.79069423675537, time elapsed: 0 h 13 m 20 s
# 5th repeat: best hidden unit: 256, best layers: 5, final eval loss: 52.33492946624756, time elapsed: 0 h 16 m 44 s
# 6th repeat: best hidden unit: 256, best layers: 4, final eval loss: 51.27721881866455, time elapsed: 0 h 20 m 6 s
# 7th repeat: best hidden unit: 256, best layers: 2, final eval loss: 51.7866268157959, time elapsed: 0 h 23 m 32 s
# 8th repeat: best hidden unit: 256, best layers: 2, final eval loss: 52.00541400909424, time elapsed: 0 h 26 m 56 s
# 9th repeat: best hidden unit: 256, best layers: 3, final eval loss: 52.1135892868042, time elapsed: 0 h 30 m 19 s
# 10th repeat: best hidden unit: 256, best layers: 2, final eval loss: 52.531402587890625, time elapsed: 0 h 33 m 42 s
# 11th repeat: best hidden unit: 256, best layers: 4, final eval loss: 51.889492988586426, time elapsed: 0 h 37 m 2 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 52.05812168121338, time elapsed: 0 h 40 m 24 s
# 13th repeat: best hidden unit: 256, best layers: 4, final eval loss: 52.32824230194092, time elapsed: 0 h 43 m 48 s
# 14th repeat: best hidden unit: 256, best layers: 3, final eval loss: 51.799498558044434, time elapsed: 0 h 47 m 10 s
# 15th repeat: best hidden unit: 256, best layers: 5, final eval loss: 51.835384368896484, time elapsed: 0 h 50 m 31 s
# 16th repeat: best hidden unit: 256, best layers: 5, final eval loss: 52.34824085235596, time elapsed: 0 h 53 m 54 s
# 17th repeat: best hidden unit: 256, best layers: 3, final eval loss: 52.40164279937744, time elapsed: 0 h 57 m 18 s
# 18th repeat: best hidden unit: 256, best layers: 3, final eval loss: 51.42704200744629, time elapsed: 1 h 0 m 39 s
# 19th repeat: best hidden unit: 256, best layers: 3, final eval loss: 51.8006010055542, time elapsed: 1 h 4 m 2 s
# 20th repeat: best hidden unit: 256, best layers: 4, final eval loss: 51.39415264129639, time elapsed: 1 h 7 m 27 s
# 21th repeat: best hidden unit: 256, best layers: 3, final eval loss: 51.606078147888184, time elapsed: 1 h 10 m 49 s
# 22th repeat: best hidden unit: 256, best layers: 2, final eval loss: 52.33298206329346, time elapsed: 1 h 14 m 11 s
# 23th repeat: best hidden unit: 256, best layers: 5, final eval loss: 51.6727352142334, time elapsed: 1 h 17 m 33 s
# 24th repeat: best hidden unit: 256, best layers: 4, final eval loss: 52.10299301147461, time elapsed: 1 h 20 m 51 s
# 25th repeat: best hidden unit: 256, best layers: 3, final eval loss: 52.15207290649414, time elapsed: 1 h 24 m 14 s
# 26th repeat: best hidden unit: 256, best layers: 4, final eval loss: 52.37910079956055, time elapsed: 1 h 27 m 41 s
# 27th repeat: best hidden unit: 256, best layers: 3, final eval loss: 52.010236740112305, time elapsed: 1 h 31 m 3 s
# 28th repeat: best hidden unit: 256, best layers: 2, final eval loss: 51.82246780395508, time elapsed: 1 h 34 m 28 s
# 29th repeat: best hidden unit: 256, best layers: 3, final eval loss: 51.71995162963867, time elapsed: 1 h 37 m 51 s
# 30th repeat: best hidden unit: 256, best layers: 3, final eval loss: 51.50101852416992, time elapsed: 1 h 41 m 14 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_mlp_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_mlp')
# Out:
# Best hidden unit: 256, best layers: 3

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(_Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(_Y_test[v_idx,:], DNN(_X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=_train_dataloader, test_loader=_test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(_Y_test[v_idx,:], DNN(_X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 97.13646697998047
# Epoch 1: training loss 277.017902135849, eval loss 18.953993797302246. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 186.70098686218262, eval loss 18.439990043640137. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 181.18194198608398, eval loss 17.663910388946533. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 174.76826000213623, eval loss 17.33486247062683. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 172.85585403442383, eval loss 17.2236385345459. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 171.78336548805237, eval loss 17.12631630897522. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 170.82549333572388, eval loss 17.02446484565735. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 169.92324805259705, eval loss 16.96133828163147. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 169.25403332710266, eval loss 16.915497064590454. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 168.70635962486267, eval loss 16.84104633331299. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 168.2578248977661, eval loss 16.78542971611023. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 167.94520926475525, eval loss 16.783259868621826. Time elapsed: 0 h 0 m 2 s.
# Epoch 13: training loss 167.68077325820923, eval loss 16.73266291618347. Time elapsed: 0 h 0 m 2 s.
# Epoch 14: training loss 167.60155630111694, eval loss 16.735289573669434. Time elapsed: 0 h 0 m 2 s.
# Epoch 15: training loss 167.42604684829712, eval loss 16.733747243881226. Time elapsed: 0 h 0 m 2 s.
# Epoch 16: training loss 167.2549090385437, eval loss 16.727100372314453. Time elapsed: 0 h 0 m 2 s.
# Epoch 17: training loss 167.17780447006226, eval loss 16.725908994674683. Time elapsed: 0 h 0 m 3 s.
# Epoch 18: training loss 167.0714466571808, eval loss 16.71409583091736. Time elapsed: 0 h 0 m 3 s.
# Epoch 19: training loss 166.97673749923706, eval loss 16.71366024017334. Time elapsed: 0 h 0 m 3 s.
# Epoch 20: training loss 166.91340684890747, eval loss 16.709007263183594. Time elapsed: 0 h 0 m 3 s.
# Epoch 21: training loss 166.85382223129272, eval loss 16.701632261276245. Time elapsed: 0 h 0 m 3 s.
# Epoch 22: training loss 166.76609587669373, eval loss 16.70437216758728. Time elapsed: 0 h 0 m 4 s.
# Epoch 23: training loss 166.72550559043884, eval loss 16.694105625152588. Time elapsed: 0 h 0 m 4 s.
# Epoch 24: training loss 166.66915130615234, eval loss 16.69668960571289. Time elapsed: 0 h 0 m 4 s.
# Epoch 25: training loss 166.63981890678406, eval loss 16.68567395210266. Time elapsed: 0 h 0 m 4 s.
# Epoch 26: training loss 166.56898856163025, eval loss 16.68136692047119. Time elapsed: 0 h 0 m 4 s.
# Epoch 27: training loss 166.60489153862, eval loss 16.667527437210083. Time elapsed: 0 h 0 m 4 s.
# Epoch 28: training loss 166.47386479377747, eval loss 16.671674966812134. Time elapsed: 0 h 0 m 5 s.
# Epoch 29: training loss 166.47188520431519, eval loss 16.678348541259766. Time elapsed: 0 h 0 m 5 s.
# Epoch 30: training loss 166.46687531471252, eval loss 16.65501308441162. Time elapsed: 0 h 0 m 5 s.
# Epoch 31: training loss 166.41737842559814, eval loss 16.650935411453247. Time elapsed: 0 h 0 m 5 s.
# Epoch 32: training loss 166.3051290512085, eval loss 16.6738178730011. Time elapsed: 0 h 0 m 5 s.
# Epoch 33: training loss 166.37043452262878, eval loss 16.64845108985901. Time elapsed: 0 h 0 m 6 s.
# Epoch 34: training loss 166.26500391960144, eval loss 16.659609079360962. Time elapsed: 0 h 0 m 6 s.
# Epoch 35: training loss 166.30515789985657, eval loss 16.66153860092163. Time elapsed: 0 h 0 m 6 s.
# Epoch 36: training loss 166.25654315948486, eval loss 16.64940309524536. Time elapsed: 0 h 0 m 6 s.
# Epoch 37: training loss 166.22301363945007, eval loss 16.65719771385193. Time elapsed: 0 h 0 m 6 s.
# Epoch 38: training loss 166.1966507434845, eval loss 16.647186756134033. Time elapsed: 0 h 0 m 7 s.
# Epoch 39: training loss 166.17509698867798, eval loss 16.654640913009644. Time elapsed: 0 h 0 m 7 s.
# Epoch 40: training loss 166.16166639328003, eval loss 16.64376449584961. Time elapsed: 0 h 0 m 7 s.
# Epoch 41: training loss 166.14161705970764, eval loss 16.651806592941284. Time elapsed: 0 h 0 m 7 s.
# Epoch 42: training loss 166.11888122558594, eval loss 16.640469312667847. Time elapsed: 0 h 0 m 7 s.
# Epoch 43: training loss 166.08568024635315, eval loss 16.638089418411255. Time elapsed: 0 h 0 m 8 s.
# Epoch 44: training loss 166.08569359779358, eval loss 16.637268781661987. Time elapsed: 0 h 0 m 8 s.
# Epoch 45: training loss 166.0422420501709, eval loss 16.632017612457275. Time elapsed: 0 h 0 m 8 s.
# Epoch 46: training loss 166.0209391117096, eval loss 16.641650676727295. Time elapsed: 0 h 0 m 8 s.
# Epoch 47: training loss 166.00878047943115, eval loss 16.635116577148438. Time elapsed: 0 h 0 m 8 s.
# Epoch 48: training loss 166.00269556045532, eval loss 16.633801460266113. Time elapsed: 0 h 0 m 8 s.
# Epoch 49: training loss 165.98294925689697, eval loss 16.63248896598816. Time elapsed: 0 h 0 m 9 s.
# Epoch 50: training loss 165.95365953445435, eval loss 16.627520084381104. Time elapsed: 0 h 0 m 9 s.
# Training completed with final epoch loss 165.95365953445435. Time elapsed: 0 h 0 m 9 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(_X_test), _Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(_Y_test, dim=0).repeat([50000,1]), _Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(3.3255, device='cuda:0')
# Predicting mean MSE error on test set tensor(3.7158, device='cuda:0')

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 1, final eval loss: 57.830491065979004, time elapsed: 0 h 3 m 18 s
# 2th repeat: best hidden unit: 256, best layers: 8, final eval loss: 57.46029281616211, time elapsed: 0 h 6 m 36 s
# 3th repeat: best hidden unit: 256, best layers: 3, final eval loss: 57.76633358001709, time elapsed: 0 h 9 m 55 s
# 4th repeat: best hidden unit: 256, best layers: 8, final eval loss: 57.48705005645752, time elapsed: 0 h 13 m 16 s
# 5th repeat: best hidden unit: 256, best layers: 2, final eval loss: 57.72569465637207, time elapsed: 0 h 16 m 37 s
# 6th repeat: best hidden unit: 256, best layers: 2, final eval loss: 57.610167503356934, time elapsed: 0 h 19 m 57 s
# 7th repeat: best hidden unit: 256, best layers: 7, final eval loss: 57.757269859313965, time elapsed: 0 h 23 m 17 s
# 8th repeat: best hidden unit: 256, best layers: 8, final eval loss: 57.651615142822266, time elapsed: 0 h 26 m 34 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 57.785128593444824, time elapsed: 0 h 29 m 52 s
# 10th repeat: best hidden unit: 256, best layers: 7, final eval loss: 58.03749179840088, time elapsed: 0 h 33 m 11 s
# 11th repeat: best hidden unit: 256, best layers: 7, final eval loss: 57.945350646972656, time elapsed: 0 h 36 m 28 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 57.73918056488037, time elapsed: 0 h 39 m 49 s
# 13th repeat: best hidden unit: 256, best layers: 7, final eval loss: 58.213151931762695, time elapsed: 0 h 43 m 13 s
# 14th repeat: best hidden unit: 256, best layers: 7, final eval loss: 57.80510139465332, time elapsed: 0 h 46 m 34 s
# 15th repeat: best hidden unit: 256, best layers: 6, final eval loss: 57.72766590118408, time elapsed: 0 h 49 m 55 s
# 16th repeat: best hidden unit: 256, best layers: 1, final eval loss: 57.80631732940674, time elapsed: 0 h 53 m 14 s
# 17th repeat: best hidden unit: 256, best layers: 5, final eval loss: 57.593125343322754, time elapsed: 0 h 56 m 32 s
# 18th repeat: best hidden unit: 256, best layers: 2, final eval loss: 57.789286613464355, time elapsed: 0 h 59 m 52 s
# 19th repeat: best hidden unit: 256, best layers: 2, final eval loss: 57.835082054138184, time elapsed: 1 h 3 m 13 s
# 20th repeat: best hidden unit: 256, best layers: 1, final eval loss: 57.68686389923096, time elapsed: 1 h 6 m 34 s
# 21th repeat: best hidden unit: 256, best layers: 8, final eval loss: 57.752352714538574, time elapsed: 1 h 9 m 54 s
# 22th repeat: best hidden unit: 256, best layers: 4, final eval loss: 57.53674793243408, time elapsed: 1 h 13 m 15 s
# 23th repeat: best hidden unit: 256, best layers: 6, final eval loss: 57.85565376281738, time elapsed: 1 h 16 m 34 s
# 24th repeat: best hidden unit: 256, best layers: 4, final eval loss: 57.87855815887451, time elapsed: 1 h 19 m 57 s
# 25th repeat: best hidden unit: 256, best layers: 2, final eval loss: 57.739479064941406, time elapsed: 1 h 23 m 15 s
# 26th repeat: best hidden unit: 256, best layers: 7, final eval loss: 57.729350090026855, time elapsed: 1 h 26 m 36 s
# 27th repeat: best hidden unit: 256, best layers: 7, final eval loss: 57.57176208496094, time elapsed: 1 h 29 m 54 s
# 28th repeat: best hidden unit: 256, best layers: 6, final eval loss: 57.8416862487793, time elapsed: 1 h 33 m 15 s
# 29th repeat: best hidden unit: 256, best layers: 7, final eval loss: 57.24705696105957, time elapsed: 1 h 36 m 38 s
# 30th repeat: best hidden unit: 256, best layers: 1, final eval loss: 57.90426063537598, time elapsed: 1 h 39 m 58 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_lstm_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='recurrent_lstm')
# Out:
# Best hidden unit: 256, best layers: 7

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=7, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])
# Out:
# Initial eval loss: 611.4433288574219
# Epoch 1: training loss 2335.012689590454, eval loss 85.93816375732422. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 811.2748336791992, eval loss 77.15928936004639. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 751.4533176422119, eval loss 71.99549961090088. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 704.1851711273193, eval loss 68.26047897338867. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 678.1472940444946, eval loss 66.7960376739502. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 668.4779109954834, eval loss 66.16812992095947. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 662.3526668548584, eval loss 65.52876567840576. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 655.279990196228, eval loss 64.77088928222656. Time elapsed: 0 h 0 m 2 s.
# Epoch 9: training loss 647.5034198760986, eval loss 63.93972206115723. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 638.9517850875854, eval loss 63.076674461364746. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 630.5620183944702, eval loss 62.23571300506592. Time elapsed: 0 h 0 m 3 s.
# Epoch 12: training loss 622.2967100143433, eval loss 61.42776966094971. Time elapsed: 0 h 0 m 3 s.
# Epoch 13: training loss 614.8537702560425, eval loss 60.74635314941406. Time elapsed: 0 h 0 m 3 s.
# Epoch 14: training loss 608.5467309951782, eval loss 60.16716384887695. Time elapsed: 0 h 0 m 3 s.
# Epoch 15: training loss 603.3081789016724, eval loss 59.693241119384766. Time elapsed: 0 h 0 m 4 s.
# Epoch 16: training loss 599.0067949295044, eval loss 59.30289077758789. Time elapsed: 0 h 0 m 4 s.
# Epoch 17: training loss 595.3171520233154, eval loss 58.954522132873535. Time elapsed: 0 h 0 m 4 s.
# Epoch 18: training loss 591.9465074539185, eval loss 58.63192081451416. Time elapsed: 0 h 0 m 5 s.
# Epoch 19: training loss 588.7610387802124, eval loss 58.33049011230469. Time elapsed: 0 h 0 m 5 s.
# Epoch 20: training loss 585.7646389007568, eval loss 58.04825305938721. Time elapsed: 0 h 0 m 5 s.
# Epoch 21: training loss 583.0086221694946, eval loss 57.78887367248535. Time elapsed: 0 h 0 m 5 s.
# Epoch 22: training loss 580.4887313842773, eval loss 57.553789138793945. Time elapsed: 0 h 0 m 6 s.
# Epoch 23: training loss 578.1585760116577, eval loss 57.3282470703125. Time elapsed: 0 h 0 m 6 s.
# Epoch 24: training loss 575.9747877120972, eval loss 57.11993885040283. Time elapsed: 0 h 0 m 6 s.
# Epoch 25: training loss 573.9230127334595, eval loss 56.923556327819824. Time elapsed: 0 h 0 m 6 s.
# Epoch 26: training loss 571.9159708023071, eval loss 56.72300052642822. Time elapsed: 0 h 0 m 7 s.
# Epoch 27: training loss 569.9345178604126, eval loss 56.53184795379639. Time elapsed: 0 h 0 m 7 s.
# Epoch 28: training loss 568.0658960342407, eval loss 56.35591697692871. Time elapsed: 0 h 0 m 7 s.
# Epoch 29: training loss 566.3293180465698, eval loss 56.18760395050049. Time elapsed: 0 h 0 m 8 s.
# Epoch 30: training loss 564.6650543212891, eval loss 56.02582550048828. Time elapsed: 0 h 0 m 8 s.
# Epoch 31: training loss 563.079683303833, eval loss 55.87185478210449. Time elapsed: 0 h 0 m 8 s.
# Epoch 32: training loss 561.5771732330322, eval loss 55.72800159454346. Time elapsed: 0 h 0 m 8 s.
# Epoch 33: training loss 560.1699256896973, eval loss 55.59319496154785. Time elapsed: 0 h 0 m 9 s.
# Epoch 34: training loss 558.8696069717407, eval loss 55.46454334259033. Time elapsed: 0 h 0 m 9 s.
# Epoch 35: training loss 557.6451139450073, eval loss 55.3463830947876. Time elapsed: 0 h 0 m 9 s.
# Epoch 36: training loss 556.4991312026978, eval loss 55.23565864562988. Time elapsed: 0 h 0 m 10 s.
# Epoch 37: training loss 555.433271408081, eval loss 55.13215637207031. Time elapsed: 0 h 0 m 10 s.
# Epoch 38: training loss 554.4149227142334, eval loss 55.031535148620605. Time elapsed: 0 h 0 m 10 s.
# Epoch 39: training loss 553.4623184204102, eval loss 54.943464279174805. Time elapsed: 0 h 0 m 10 s.
# Epoch 40: training loss 552.5563974380493, eval loss 54.860114097595215. Time elapsed: 0 h 0 m 11 s.
# Epoch 41: training loss 551.7162580490112, eval loss 54.77638530731201. Time elapsed: 0 h 0 m 11 s.
# Epoch 42: training loss 550.8992357254028, eval loss 54.69507026672363. Time elapsed: 0 h 0 m 11 s.
# Epoch 43: training loss 550.1281204223633, eval loss 54.61650085449219. Time elapsed: 0 h 0 m 12 s.
# Epoch 44: training loss 549.391170501709, eval loss 54.546688079833984. Time elapsed: 0 h 0 m 12 s.
# Epoch 45: training loss 548.6780014038086, eval loss 54.4783878326416. Time elapsed: 0 h 0 m 12 s.
# Epoch 46: training loss 547.9906644821167, eval loss 54.41314506530762. Time elapsed: 0 h 0 m 12 s.
# Epoch 47: training loss 547.3019618988037, eval loss 54.34398174285889. Time elapsed: 0 h 0 m 13 s.
# Epoch 48: training loss 546.6389455795288, eval loss 54.27793025970459. Time elapsed: 0 h 0 m 13 s.
# Epoch 49: training loss 545.9436092376709, eval loss 54.20506191253662. Time elapsed: 0 h 0 m 13 s.
# Epoch 50: training loss 545.2203598022461, eval loss 54.13308620452881. Time elapsed: 0 h 0 m 14 s.
# Training completed with final epoch loss 545.2203598022461. Time elapsed: 0 h 0 m 14 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(10.8266, device='cuda:0')
# Predicting mean MSE error on test set tensor(16.4788, device='cuda:0')

# %% [markdown]
# ### Complex BNN

# %%
X_train, Y_train = load_data('./data/', 'train_complex.pkl')
X_test, Y_test = load_data('./data/', 'test_complex.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_complex.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
Y_train
# Out:
# tensor([[[-1.0000e+00,  9.9838e-01,  2.2943e+00,  ...,  1.0826e+00,
#            3.5864e+00, -3.8321e-01],
#          [-9.9921e-01,  4.3924e-01, -2.8931e-01,  ...,  5.2424e-01,
#            4.3874e+00, -2.2534e+00],
#          [-4.4558e-01,  9.7699e-01, -6.5637e-01,  ...,  5.6974e+00,
#            1.6389e+01, -2.2122e+00],
#          ...,
#          [-9.8829e-01,  8.9607e-01, -4.3776e-01,  ...,  0.0000e+00,
#           -1.0263e+00, -4.8937e-01],
#          [-8.5531e-01,  3.4695e-01, -6.9870e-01,  ...,  0.0000e+00,
#            1.7253e+01, -1.2846e+00],
#          [-9.9998e-01,  4.9827e-01, -1.0925e+00,  ...,  0.0000e+00,
#            1.6125e+01, -9.1117e-01]],
#
#         [[-9.9959e-01,  6.7011e-03, -7.8926e-01,  ...,  6.5370e+00,
#           -1.1759e+00, -7.3119e-01],
#          [-8.8988e-01,  8.4187e-05, -6.6618e-01,  ...,  0.0000e+00,
#            6.4855e+00,  5.8302e+00],
#          [-9.9857e-01,  1.6947e-02, -5.6555e-01,  ...,  5.8301e+00,
#            9.2021e-01, -1.6590e+00],
#          ...,
#          [-9.9901e-01,  9.4054e-01,  1.7076e+00,  ...,  5.6227e-01,
#            1.2216e+01, -2.5925e+00],
#          [-9.9958e-01,  3.7302e-01, -5.2439e-01,  ...,  4.0506e+00,
#            9.0570e+00, -1.3509e+00],
#          [-9.9996e-01,  3.1014e-01, -4.2129e-01,  ...,  3.7663e+00,
#            7.3801e+00,  2.2291e+00]],
#
#         [[-1.0000e+00,  9.3051e-01, -3.2142e-02,  ...,  0.0000e+00,
#           -3.0084e-01, -1.1616e-01],
#          [-9.9996e-01,  4.3082e-01, -6.2369e-01,  ...,  1.6498e+00,
#            7.7682e+00,  8.0233e+00],
#          [-1.0000e+00,  5.4236e-06, -6.9278e-02,  ...,  1.0475e+01,
#            6.8799e+00, -1.2669e+00],
#          ...,
#          [-9.9969e-01,  9.0110e-01,  2.0083e-01,  ...,  0.0000e+00,
#           -2.8038e+00,  8.9714e-02],
#          [-1.0000e+00,  5.9436e-01, -2.9012e-01,  ...,  1.1668e+01,
#            3.7337e+00, -2.3457e-01],
#          [-9.9167e-01,  8.3964e-01, -1.6781e-01,  ...,  5.5366e-01,
#            4.8503e+00,  2.4208e-01]],
#
#         ...,
#
#         [[-1.0000e+00,  6.3624e-01,  9.6749e-01,  ...,  2.0157e+00,
#           -3.4051e-01,  3.6109e+00],
#          [-9.9998e-01,  8.4543e-01,  3.4939e-01,  ...,  5.2557e+00,
#            1.7050e-01, -6.2479e-02],
#          [-1.0000e+00,  8.8982e-01, -1.6777e-01,  ...,  1.3477e+00,
#            7.0011e+00,  1.8036e-01],
#          ...,
#          [-1.0000e+00,  8.6799e-01, -9.3453e-01,  ...,  2.1394e+00,
#            5.4006e+00, -1.5319e+00],
#          [-1.0000e+00,  4.4214e-02,  9.1441e-01,  ...,  0.0000e+00,
#            3.0122e+00,  6.9718e+00],
#          [-7.7301e-01,  5.7478e-01,  9.5719e-01,  ...,  0.0000e+00,
#           -8.8802e-01,  3.8380e+00]],
#
#         [[-9.9994e-01,  8.1132e-01, -2.2082e-01,  ...,  1.6536e+00,
#           -2.0277e+00, -1.3540e+00],
#          [-1.0000e+00,  1.1406e-01,  1.1248e+00,  ...,  6.5117e+00,
#            7.2887e-01,  3.5685e+00],
#          [-1.0000e+00,  3.4268e-02,  2.6096e+00,  ...,  6.2026e+00,
#           -5.7044e-01, -3.2653e-02],
#          ...,
#          [-1.0000e+00,  4.1096e-02, -4.9690e-01,  ...,  3.0795e+00,
#            1.0157e+00,  1.4665e+00],
#          [-1.0000e+00,  2.1009e-02, -1.5306e+00,  ...,  6.7902e+00,
#            6.8549e+00,  3.6690e-01],
#          [-9.9995e-01,  4.7788e-02, -1.1279e-01,  ...,  1.0894e+01,
#            3.1595e+00, -1.8051e+00]],
#
#         [[-1.0000e+00,  8.5249e-01,  4.4882e-01,  ...,  0.0000e+00,
#            1.8951e+00,  4.5397e+00],
#          [-9.9892e-01,  9.9524e-01, -3.6417e-01,  ...,  9.9107e+00,
#            5.1914e-01, -7.2390e-01],
#          [-9.9991e-01,  6.8751e-01, -5.8792e-01,  ...,  1.1259e-01,
#            8.4566e+00, -1.2516e+00],
#          ...,
#          [-9.9991e-01,  2.1195e-01, -7.0571e-01,  ...,  6.1583e+00,
#            2.8658e+00, -5.5298e-01],
#          [-1.0000e+00,  1.4256e-04, -9.2600e-01,  ...,  0.0000e+00,
#            3.1385e+00,  2.5023e-01],
#          [-9.9992e-01,  4.2296e-01, -7.4837e-01,  ...,  9.0931e+00,
#            1.2959e+01, -9.0440e-01]]], device='cuda:0')

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
_X_train = X_train.view(-1, 16)
_Y_train = Y_train.view(-1, 16)
_X_test = X_test.view(-1, 16)
_Y_test = Y_test.view(-1, 16)

_train_dataset = BNN_Dataset(_X_train, _Y_train)
_train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

_test_dataset = BNN_Dataset(_X_test, _Y_test)
_test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1 layers, 2 hidden units, final eval loss: 25.492475509643555
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23716/3407263236.py in <module>
#       2 n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]
#       3
# ----> 4 avg_final_eval_loss = repeated_param_grid_search(
#       5     hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in repeated_param_grid_search(hidden_dims, n_layerss, n_repeats, **kwargs)
#     226     for i in range(n_repeats):
#     227
# --> 228         final_eval_loss = param_grid_search(hidden_dims, n_layerss, **kwargs)
#     229         final_eval_loss_matrix += final_eval_loss
#     230
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in param_grid_search(hidden_dims, n_layerss, **kwargs)
#     190                 criterion = nn.MSELoss()
#     191
# --> 192                 train_losses, eval_losses = train(
#     193                     model=DNN,
#     194                     train_loader=valid_loader, test_loader=test_loader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#      29         epoch_loss = 0
#      30
# ---> 31         for i, (X, Y) in enumerate(iter(train_loader)):
#      32
#      33             Y_hat = model(X)
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in __getitem__(self, idx)
#      80
#      81     def __getitem__(self, idx):
# ---> 82         input = self.inputs[idx,:]
#      83         label = self.labels[idx,:]
#      84         return input, label
#
# KeyboardInterrupt:

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23716/1022359905.py in <module>
# ----> 1 r, c = find_argmin_in_matrix(avg_final_eval_loss)
#       2 print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
#       3 plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
#       4                x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_mlp_log')
#       5 plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
#
# NameError: name 'avg_final_eval_loss' is not defined

# %% [markdown]
# ##### b) Learning with best parameter

# %%
n_layers = 2
hidden_dim = 256

v_idx = np.random.randint(0, len(_Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(_Y_test[v_idx,:], DNN(_X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=_train_dataloader, test_loader=_test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(_Y_test[v_idx,:], DNN(_X_test[v_idx,:])) # visualise after training

torch.save(DNN.state_dict(), f'./dnn_params/complex_mlp_{n_layers}_{hidden_dim}.pt')
# Out:
# Initial eval loss: 111.94297409057617
# Epoch 1: training loss 357.33676767349243, eval loss 25.281514644622803. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 244.97451257705688, eval loss 23.69260263442993. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 233.97761631011963, eval loss 23.211686611175537. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 231.14537858963013, eval loss 23.045779705047607. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 229.8657603263855, eval loss 22.92711591720581. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 228.83962535858154, eval loss 22.857040882110596. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 227.90220832824707, eval loss 22.73949670791626. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 226.8474669456482, eval loss 22.686718940734863. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 225.83007144927979, eval loss 22.539713859558105. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 224.8785891532898, eval loss 22.512635231018066. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 224.01541137695312, eval loss 22.36860227584839. Time elapsed: 0 h 0 m 1 s.
# Epoch 12: training loss 223.3368992805481, eval loss 22.3124098777771. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 222.90914297103882, eval loss 22.2821102142334. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 222.6151328086853, eval loss 22.27311372756958. Time elapsed: 0 h 0 m 2 s.
# Epoch 15: training loss 222.27996587753296, eval loss 22.24092388153076. Time elapsed: 0 h 0 m 2 s.
# Epoch 16: training loss 222.14444589614868, eval loss 22.25334119796753. Time elapsed: 0 h 0 m 2 s.
# Epoch 17: training loss 221.94336938858032, eval loss 22.260875701904297. Time elapsed: 0 h 0 m 2 s.
# Epoch 18: training loss 221.82163286209106, eval loss 22.283812046051025. Time elapsed: 0 h 0 m 2 s.
# Epoch 19: training loss 221.72365617752075, eval loss 22.296406745910645. Time elapsed: 0 h 0 m 2 s.
# Epoch 20: training loss 221.54393815994263, eval loss 22.23599624633789. Time elapsed: 0 h 0 m 2 s.
# Epoch 21: training loss 221.4954171180725, eval loss 22.26295566558838. Time elapsed: 0 h 0 m 3 s.
# Epoch 22: training loss 221.35838651657104, eval loss 22.181103706359863. Time elapsed: 0 h 0 m 3 s.
# Epoch 23: training loss 221.28888988494873, eval loss 22.220594882965088. Time elapsed: 0 h 0 m 3 s.
# Epoch 24: training loss 221.20963096618652, eval loss 22.196176528930664. Time elapsed: 0 h 0 m 3 s.
# Epoch 25: training loss 221.13626623153687, eval loss 22.192555904388428. Time elapsed: 0 h 0 m 3 s.
# Epoch 26: training loss 221.08504390716553, eval loss 22.178428649902344. Time elapsed: 0 h 0 m 3 s.
# Epoch 27: training loss 221.02331352233887, eval loss 22.18477153778076. Time elapsed: 0 h 0 m 4 s.
# Epoch 28: training loss 220.9848189353943, eval loss 22.176973819732666. Time elapsed: 0 h 0 m 4 s.
# Epoch 29: training loss 220.917236328125, eval loss 22.16272735595703. Time elapsed: 0 h 0 m 4 s.
# Epoch 30: training loss 220.8738145828247, eval loss 22.160841464996338. Time elapsed: 0 h 0 m 4 s.
# Epoch 31: training loss 220.8112931251526, eval loss 22.154329776763916. Time elapsed: 0 h 0 m 4 s.
# Epoch 32: training loss 220.77490997314453, eval loss 22.15542697906494. Time elapsed: 0 h 0 m 4 s.
# Epoch 33: training loss 220.71564054489136, eval loss 22.15443468093872. Time elapsed: 0 h 0 m 4 s.
# Epoch 34: training loss 220.67784214019775, eval loss 22.140631198883057. Time elapsed: 0 h 0 m 5 s.
# Epoch 35: training loss 220.62643671035767, eval loss 22.135746002197266. Time elapsed: 0 h 0 m 5 s.
# Epoch 36: training loss 220.5817322731018, eval loss 22.14369297027588. Time elapsed: 0 h 0 m 5 s.
# Epoch 37: training loss 220.5451464653015, eval loss 22.137892723083496. Time elapsed: 0 h 0 m 5 s.
# Epoch 38: training loss 220.52600717544556, eval loss 22.134196758270264. Time elapsed: 0 h 0 m 5 s.
# Epoch 39: training loss 220.4862937927246, eval loss 22.13102674484253. Time elapsed: 0 h 0 m 5 s.
# Epoch 40: training loss 220.44203329086304, eval loss 22.134217739105225. Time elapsed: 0 h 0 m 5 s.
# Epoch 41: training loss 220.41421747207642, eval loss 22.134501934051514. Time elapsed: 0 h 0 m 6 s.
# Epoch 42: training loss 220.37069463729858, eval loss 22.117713451385498. Time elapsed: 0 h 0 m 6 s.
# Epoch 43: training loss 220.32592153549194, eval loss 22.117268562316895. Time elapsed: 0 h 0 m 6 s.
# Epoch 44: training loss 220.30404949188232, eval loss 22.11971139907837. Time elapsed: 0 h 0 m 6 s.
# Epoch 45: training loss 220.28184127807617, eval loss 22.117457389831543. Time elapsed: 0 h 0 m 6 s.
# Epoch 46: training loss 220.25394439697266, eval loss 22.11561393737793. Time elapsed: 0 h 0 m 6 s.
# Epoch 47: training loss 220.22829008102417, eval loss 22.111432552337646. Time elapsed: 0 h 0 m 6 s.
# Epoch 48: training loss 220.19515132904053, eval loss 22.1054368019104. Time elapsed: 0 h 0 m 7 s.
# Epoch 49: training loss 220.1461534500122, eval loss 22.102756023406982. Time elapsed: 0 h 0 m 7 s.
# Epoch 50: training loss 220.11538743972778, eval loss 22.103381156921387. Time elapsed: 0 h 0 m 7 s.
# Training completed with final epoch loss 220.11538743972778. Time elapsed: 0 h 0 m 7 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(_X_test), _Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(_Y_test, dim=0).repeat([50000,1]), _Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(4.4207, device='cuda:0')
# Predicting mean MSE error on test set tensor(5.1189, device='cuda:0')

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 5, final eval loss: 16.800305366516113, time elapsed: 0 h 3 m 17 s
# 2th repeat: best hidden unit: 256, best layers: 4, final eval loss: 16.771487951278687, time elapsed: 0 h 6 m 37 s
# 3th repeat: best hidden unit: 256, best layers: 1, final eval loss: 16.787353515625, time elapsed: 0 h 9 m 55 s
# 4th repeat: best hidden unit: 256, best layers: 3, final eval loss: 16.782240390777588, time elapsed: 0 h 13 m 13 s
# 5th repeat: best hidden unit: 256, best layers: 1, final eval loss: 16.80350613594055, time elapsed: 0 h 16 m 33 s
# 6th repeat: best hidden unit: 256, best layers: 8, final eval loss: 16.766926288604736, time elapsed: 0 h 19 m 53 s
# 7th repeat: best hidden unit: 256, best layers: 2, final eval loss: 16.75939965248108, time elapsed: 0 h 23 m 14 s
# 8th repeat: best hidden unit: 256, best layers: 1, final eval loss: 16.763249397277832, time elapsed: 0 h 26 m 34 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 16.778460025787354, time elapsed: 0 h 29 m 53 s
# 10th repeat: best hidden unit: 256, best layers: 8, final eval loss: 16.783103466033936, time elapsed: 0 h 33 m 11 s
# 11th repeat: best hidden unit: 256, best layers: 5, final eval loss: 16.774744749069214, time elapsed: 0 h 36 m 31 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 16.788334369659424, time elapsed: 0 h 39 m 46 s
# 13th repeat: best hidden unit: 256, best layers: 5, final eval loss: 16.772538423538208, time elapsed: 0 h 43 m 5 s
# 14th repeat: best hidden unit: 256, best layers: 5, final eval loss: 16.793164491653442, time elapsed: 0 h 46 m 26 s
# 15th repeat: best hidden unit: 256, best layers: 6, final eval loss: 16.78217649459839, time elapsed: 0 h 49 m 46 s
# 16th repeat: best hidden unit: 256, best layers: 3, final eval loss: 16.77511763572693, time elapsed: 0 h 53 m 10 s
# 17th repeat: best hidden unit: 256, best layers: 2, final eval loss: 16.781064987182617, time elapsed: 0 h 56 m 29 s
# 18th repeat: best hidden unit: 256, best layers: 3, final eval loss: 16.79396414756775, time elapsed: 0 h 59 m 50 s
# 19th repeat: best hidden unit: 256, best layers: 5, final eval loss: 16.761529445648193, time elapsed: 1 h 3 m 11 s
# 20th repeat: best hidden unit: 256, best layers: 2, final eval loss: 16.779645919799805, time elapsed: 1 h 6 m 32 s
# 21th repeat: best hidden unit: 256, best layers: 7, final eval loss: 16.7601101398468, time elapsed: 1 h 9 m 53 s
# 22th repeat: best hidden unit: 256, best layers: 1, final eval loss: 16.78307819366455, time elapsed: 1 h 13 m 12 s
# 23th repeat: best hidden unit: 256, best layers: 2, final eval loss: 16.785703897476196, time elapsed: 1 h 16 m 31 s
# 24th repeat: best hidden unit: 256, best layers: 5, final eval loss: 16.771676063537598, time elapsed: 1 h 19 m 53 s
# 25th repeat: best hidden unit: 256, best layers: 6, final eval loss: 16.79551386833191, time elapsed: 1 h 23 m 11 s
# 26th repeat: best hidden unit: 256, best layers: 2, final eval loss: 16.804838180541992, time elapsed: 1 h 26 m 31 s
# 27th repeat: best hidden unit: 256, best layers: 3, final eval loss: 16.763237714767456, time elapsed: 1 h 29 m 50 s
# 28th repeat: best hidden unit: 256, best layers: 3, final eval loss: 16.79707407951355, time elapsed: 1 h 33 m 9 s
# 29th repeat: best hidden unit: 256, best layers: 6, final eval loss: 16.7895450592041, time elapsed: 1 h 36 m 31 s
# 30th repeat: best hidden unit: 256, best layers: 4, final eval loss: 16.754611492156982, time elapsed: 1 h 39 m 51 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_lstm_log')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='complex_lstm')
# Out:
# Best hidden unit: 256, best layers: 8

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=8, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])
# Out:
# Initial eval loss: 128.48339462280273
# Epoch 1: training loss 322.1035327911377, eval loss 19.166228771209717. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 184.42746472358704, eval loss 17.840476274490356. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 176.23664259910583, eval loss 17.459607362747192. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 174.42587757110596, eval loss 17.389069318771362. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 173.8741991519928, eval loss 17.343405961990356. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 173.44140338897705, eval loss 17.302836179733276. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 173.03529620170593, eval loss 17.26335382461548. Time elapsed: 0 h 0 m 2 s.
# Epoch 8: training loss 172.6338574886322, eval loss 17.226418018341064. Time elapsed: 0 h 0 m 2 s.
# Epoch 9: training loss 172.20463299751282, eval loss 17.180680751800537. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 171.7469310760498, eval loss 17.135493993759155. Time elapsed: 0 h 0 m 3 s.
# Epoch 11: training loss 171.2808871269226, eval loss 17.08952283859253. Time elapsed: 0 h 0 m 3 s.
# Epoch 12: training loss 170.78621101379395, eval loss 17.042168617248535. Time elapsed: 0 h 0 m 3 s.
# Epoch 13: training loss 170.32088160514832, eval loss 16.9963641166687. Time elapsed: 0 h 0 m 4 s.
# Epoch 14: training loss 169.87592792510986, eval loss 16.953996419906616. Time elapsed: 0 h 0 m 4 s.
# Epoch 15: training loss 169.44997024536133, eval loss 16.913205862045288. Time elapsed: 0 h 0 m 4 s.
# Epoch 16: training loss 169.05359292030334, eval loss 16.877065658569336. Time elapsed: 0 h 0 m 4 s.
# Epoch 17: training loss 168.70088481903076, eval loss 16.844361305236816. Time elapsed: 0 h 0 m 5 s.
# Epoch 18: training loss 168.39317154884338, eval loss 16.814600706100464. Time elapsed: 0 h 0 m 5 s.
# Epoch 19: training loss 168.12121891975403, eval loss 16.79125142097473. Time elapsed: 0 h 0 m 5 s.
# Epoch 20: training loss 167.89397072792053, eval loss 16.77131199836731. Time elapsed: 0 h 0 m 6 s.
# Epoch 21: training loss 167.71434903144836, eval loss 16.754557371139526. Time elapsed: 0 h 0 m 6 s.
# Epoch 22: training loss 167.57059502601624, eval loss 16.742003202438354. Time elapsed: 0 h 0 m 6 s.
# Epoch 23: training loss 167.4520275592804, eval loss 16.731408834457397. Time elapsed: 0 h 0 m 7 s.
# Epoch 24: training loss 167.35690116882324, eval loss 16.723227977752686. Time elapsed: 0 h 0 m 7 s.
# Epoch 25: training loss 167.27576971054077, eval loss 16.716398000717163. Time elapsed: 0 h 0 m 7 s.
# Epoch 26: training loss 167.20895195007324, eval loss 16.710674047470093. Time elapsed: 0 h 0 m 8 s.
# Epoch 27: training loss 167.15320754051208, eval loss 16.705808401107788. Time elapsed: 0 h 0 m 8 s.
# Epoch 28: training loss 167.1034665107727, eval loss 16.701879739761353. Time elapsed: 0 h 0 m 8 s.
# Epoch 29: training loss 167.0613443851471, eval loss 16.698293447494507. Time elapsed: 0 h 0 m 8 s.
# Epoch 30: training loss 167.02161645889282, eval loss 16.695400714874268. Time elapsed: 0 h 0 m 9 s.
# Epoch 31: training loss 166.99138188362122, eval loss 16.694337844848633. Time elapsed: 0 h 0 m 9 s.
# Epoch 32: training loss 166.95184016227722, eval loss 16.6896071434021. Time elapsed: 0 h 0 m 9 s.
# Epoch 33: training loss 166.91490817070007, eval loss 16.687461853027344. Time elapsed: 0 h 0 m 10 s.
# Epoch 34: training loss 166.885648727417, eval loss 16.684170246124268. Time elapsed: 0 h 0 m 10 s.
# Epoch 35: training loss 166.85369443893433, eval loss 16.682491064071655. Time elapsed: 0 h 0 m 10 s.
# Epoch 36: training loss 166.82983136177063, eval loss 16.67969799041748. Time elapsed: 0 h 0 m 10 s.
# Epoch 37: training loss 166.8068871498108, eval loss 16.67781114578247. Time elapsed: 0 h 0 m 11 s.
# Epoch 38: training loss 166.78464341163635, eval loss 16.67580246925354. Time elapsed: 0 h 0 m 11 s.
# Epoch 39: training loss 166.76060795783997, eval loss 16.674768447875977. Time elapsed: 0 h 0 m 11 s.
# Epoch 40: training loss 166.74868631362915, eval loss 16.673948526382446. Time elapsed: 0 h 0 m 12 s.
# Epoch 41: training loss 166.72599911689758, eval loss 16.670907735824585. Time elapsed: 0 h 0 m 12 s.
# Epoch 42: training loss 166.71113801002502, eval loss 16.670482397079468. Time elapsed: 0 h 0 m 12 s.
# Epoch 43: training loss 166.6936755180359, eval loss 16.66861915588379. Time elapsed: 0 h 0 m 13 s.
# Epoch 44: training loss 166.6802728176117, eval loss 16.668248176574707. Time elapsed: 0 h 0 m 13 s.
# Epoch 45: training loss 166.66378903388977, eval loss 16.667152166366577. Time elapsed: 0 h 0 m 13 s.
# Epoch 46: training loss 166.64937448501587, eval loss 16.665506839752197. Time elapsed: 0 h 0 m 14 s.
# Epoch 47: training loss 166.634516954422, eval loss 16.664403200149536. Time elapsed: 0 h 0 m 14 s.
# Epoch 48: training loss 166.61891436576843, eval loss 16.66330862045288. Time elapsed: 0 h 0 m 14 s.
# Epoch 49: training loss 166.6071240901947, eval loss 16.66182541847229. Time elapsed: 0 h 0 m 14 s.
# Epoch 50: training loss 166.5935573577881, eval loss 16.66195273399353. Time elapsed: 0 h 0 m 15 s.
# Training completed with final epoch loss 166.5935573577881. Time elapsed: 0 h 0 m 15 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(3.3324, device='cuda:0')
# Predicting mean MSE error on test set tensor(2.4206, device='cuda:0')

# %% [markdown]
# ## Complexity of DNN vs Data Efficiency
# What is the least complex DNN that does a good job of mimicking the approximate the complexBNN?

# %%
X_train, Y_train = load_data('./data/', 'train_complex.pkl')
X_test, Y_test = load_data('./data/', 'test_complex.pkl')
X_valid, Y_valid = load_data('./data/', 'valid_complex.pkl')

hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

batch_size = 200                            # number of data points in each mini-batch
n_datas = [i*1000 for i in range(1,11,1)]   # number of train data used, from 1 to len(X_train)
n_epochs = 50                               # number of training epochs

# %%
train_dataset = BNN_Dataset(X_train, Y_train)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %%
avg_final_eval_losses = repeated_complexity_varying_data_efficiency(
    hidden_dims=hidden_dims, n_layerss=n_layerss, n_repeats=10, verbose=True,
    **{'input_dim':16,
       'output_dim':16,
       'train_dataset':train_dataset, 
       'test_dataloader':test_dataloader,
       'n_datas':n_datas,
       'n_epochs':n_epochs,
       'batch_size': batch_size})
torch.save(avg_final_eval_losses, './temp/avg_final_eval_loss.pt')
# Out:
# 1 of 10 repeats. Time elapsed: time elapsed: 0 h 43 m 43 sints.
# 2 of 10 repeats. Time elapsed: time elapsed: 1 h 28 m 17 sints.
# 3 of 10 repeats. Time elapsed: time elapsed: 2 h 12 m 39 sints.
# 4 of 10 repeats. Time elapsed: time elapsed: 2 h 57 m 2 soints.
# 5 of 10 repeats. Time elapsed: time elapsed: 3 h 41 m 25 sints.
# 6 of 10 repeats. Time elapsed: time elapsed: 4 h 25 m 54 sints.
# 7 of 10 repeats. Time elapsed: time elapsed: 5 h 10 m 27 sints.
# 8 of 10 repeats. Time elapsed: time elapsed: 5 h 54 m 50 sints.
# 9 of 10 repeats. Time elapsed: time elapsed: 6 h 39 m 14 sints.
# 10 of 10 repeats. Time elapsed: time elapsed: 7 h 23 m 45 snts.

# %%
avg_final_eval_losses = torch.load('./temp/avg_final_eval_loss.pt')
for i, n_data in enumerate(n_datas):
    print(f'Using {n_data} out of 10000 training data points')
    plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_losses[:,:,i],
                    x_label='Hidden units', y_label='Layers', z_label= f'Test set MSE loss for {n_data} training data',
                    fname=False, figsize=(10,8))
# Out:
# Using 1000 out of 10000 training data points
# Using 2000 out of 10000 training data points
# Using 3000 out of 10000 training data points
# Using 4000 out of 10000 training data points
# Using 5000 out of 10000 training data points
# Using 6000 out of 10000 training data points
# Using 7000 out of 10000 training data points
# Using 8000 out of 10000 training data points
# Using 9000 out of 10000 training data points
# Using 10000 out of 10000 training data points

# %% [markdown]
# ## BNN Plasticity analysis
# We explore to what extent pre-training of a DNN helps when the plasticity of the approximate BNN is changed slightly (according to a Gaussian)

# %%
from approx_bnns import ComplexApproximateBNN

# BNN params
x, y, z = 256, 0.5, 4
bias = True
trainable = False
residual_in = [False, False, 1, 2]
num_epochs=25

input_dim = 16
output_dim = 16
batch_size = 200
transfer_functions=[nn.ReLU(), nn.ELU(), nn.SiLU(), nn.CELU(), nn.Tanh(), nn.Sigmoid(), nn.LeakyReLU(0.1), nn.LeakyReLU(0.2), nn.LeakyReLU(0.3)]

# initialise BNN, and load original weights
approx_bnn = ComplexApproximateBNN(
    x=x, y=y, z=z, 
    input_dim=input_dim, 
    output_dim=output_dim, 
    residual_in=residual_in, 
    recurrent_dim=-1, 
    transfer_functions=transfer_functions
).to(device)

BNN_weights = torch.load('./approx_bnn_params/complex.pt')
BNN_non_linearities = load_non_linearities('./approx_bnn_params/complex_activations.pkl')
approx_bnn.load_state_dict(BNN_weights)
approx_bnn.load_non_linearities(BNN_non_linearities)

# initialise DNN
hidden_dim = 256
n_layers = 2
DNN_params = torch.load(f'./dnn_params/complex_mlp_{n_layers}_{hidden_dim}.pt')
DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)
DNN.load_state_dict(DNN_params)

# fixing input pattern
X_train, _ = load_data('./data/', 'train_complex.pkl')
X_test, _ = load_data('./data/', 'test_complex.pkl')
X_valid, _ = load_data('./data/', 'valid_complex.pkl')
# Out:
# Non-linearities loaded successfully.

# %%
def apply_plasticity_and_generate_new_output(BNN, BNN_params:tuple, X_train, X_test, sigma, alpha, verbose=True):
    '''
    Slightly alter each non-zero weight in the biological neural network, and generate new output patterns
    '''
    
    BNN.load_state_dict(BNN_params[0])
    BNN.load_non_linearities(BNN_params[1])

    BNN.gaussian_plasticity_update(sigma, alpha)
    
    if verbose:
        print('\t Plasticity applied.')
    
    _Y_train = BNN(X_train.to(device))
    _Y_test = BNN(X_test.to(device))
    print(_Y_train)
    
    if verbose:
        print('\t New output patterns generated.')

    return _Y_train, _Y_test

# %%
def transfer_learning_with_plasticity(DNN, BNN, DNN_params, BNN_params:tuple, sigma, batch_size, num_epochs, X_train, X_test, alpha=1, verbose=True):
    '''
    Explores how much DNN must be retrained to approximate a BNN with small plasticity changes.
    Transfer learning is applied using saved DNN weights, on the same training input and new output generated by BNN
    
    returns:
    train_loss:    1D torch.Tensor, history of training losses by epoch
    eval_loss:     1D torch.Tensor, history of evaluation losses by epoch
    '''
    _Y_train, _Y_test = apply_plasticity_and_generate_new_output(BNN, BNN_params, X_train, X_test, sigma, alpha, verbose=verbose)
    
    if isinstance(DNN, FeedForwardDNN):
        # For feedforward MLP, merge first two dimensions
        X_train = X_train.view(-1, 16)
        _Y_train = _Y_train.view(-1, 16)
        X_test = X_test.view(-1, 16)
        _Y_test = _Y_test.view(-1, 16)
    
    # prepare dataloader
    train_dataset, test_dataset = BNN_Dataset(X_train, _Y_train), BNN_Dataset(X_test, _Y_test)
    train_dataloader, test_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True), DataLoader(test_dataset, batch_size=batch_size, shuffle=True) 
    
    # load trained DNN
    DNN.load_state_dict(DNN_params)
    optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
    criterion = nn.MSELoss()
    
    if isinstance(DNN, FeedForwardDNN):
        train_losses, eval_losses = train(
            model=DNN, 
            train_loader=train_dataloader, test_loader=test_dataloader,
            optimiser=optimiser, criterion=criterion, num_epochs=num_epochs,
            verbose=True, force_stop=False)
        
    if isinstance(DNN, RecurrentDNN):
        train_losses, eval_losses = train_rnn(
            model=DNN,
            train_loader=train_dataloader, test_loader=test_dataloader,
            optimiser=optimiser, criterion=criterion, num_epochs=num_epochs,
            verbose=True, force_step=False)
    
    return torch.Tensor(train_losses), torch.Tensor(eval_losses)

# %%
def plasticity_analysis(DNN, BNN, DNN_params, BNN_params:tuple, sigmas, batch_size, num_epochs, X_train, X_test, verbose):
    '''
    Varying plasticity parameter sigma (and alpha), explores how well the trained DNN can approximate the approximate DNN with plasticity changes
    
    :params:
    verbose:                0 or 1 or 2. 0=No log; 1=Only showing progress on which sigma; 2=showing progress for each epoch
    
    returns:
    train_losses_by_sigma:  2D torch.Tensor, training loss history per epoch for each sigma
    eval_losses_by_sigma:   2D torch.Tensor, evaluation loss history per epoch for each sigma
    '''
    
    # store all loss history in tensor
    n_sigmas = sigmas.shape[0]
    train_losses_by_sigma = torch.zeros(n_sigmas, num_epochs)
    eval_losses_by_sigma = torch.zeros(n_sigmas, num_epochs)
    v = True if verbose == 2 else False
    
    for i, sigma in enumerate(sigmas):
        if verbose >= 1:
            print(f'Processing simga={sigma} ({i+1}/{n_sigmas})')
            
        sigma_train_losses, sigma_eval_losses = transfer_learning_with_plasticity(
            DNN, BNN, DNN_params, BNN_params, 
            sigma, batch_size, num_epochs, 
            X_train, X_test, verbose=v)
        
        train_losses_by_sigma[i,:] = sigma_train_losses
        eval_losses_by_sigma[i,:] = sigma_eval_losses
        
    return train_losses_by_sigma, eval_losses_by_sigma

# %%
sigmas = torch.exp(torch.linspace(-10,0, 6))
sigmas
# Out:
# tensor([4.5400e-05, 3.3546e-04, 2.4788e-03, 1.8316e-02, 1.3534e-01, 1.0000e+00])

# %%
train_losses_by_sigma, eval_losses_by_sigma = plasticity_analysis(DNN, approx_bnn, 
                    DNN_params, (BNN_weights, BNN_non_linearities),
                    sigmas, batch_size, num_epochs, X_train, X_test, verbose=2)
# Out:
# Processing simga=4.539993096841499e-05 (1/6)
# Non-linearities loaded successfully.
# 	 Plasticity applied.
# tensor([[[-1.0000e+00,  9.9836e-01,  2.2648e+00,  ...,  1.0597e+00,
#            3.6154e+00, -3.8006e-01],
#          [-9.9925e-01,  4.4494e-01, -2.5653e-01,  ...,  1.2037e+00,
#            4.2840e+00, -2.3671e+00],
#          [-3.6079e-01,  9.5075e-01, -5.9066e-01,  ...,  5.4995e+00,
#            1.5724e+01, -2.2905e+00],
#          ...,
#          [-9.9600e-01,  2.0700e-01, -5.7628e-01,  ...,  0.0000e+00,
#            1.1663e+01, -6.1751e-02],
#          [-9.9998e-01,  8.4218e-01, -4.3859e-01,  ...,  6.2150e+00,
#            5.4584e+00,  5.2941e+00],
#          [-9.9944e-01,  5.0589e-03, -3.3126e-01,  ...,  2.2822e-01,
#            8.7102e+00, -6.5506e-01]],
#
#         [[-9.9958e-01,  6.7678e-03, -7.8937e-01,  ...,  6.5359e+00,
#           -1.1730e+00, -7.3419e-01],
#          [-8.8935e-01,  8.6505e-05, -6.6638e-01,  ...,  0.0000e+00,
#            6.5398e+00,  5.9145e+00],
#          [-9.9877e-01,  1.1975e-02, -5.5428e-01,  ...,  6.0317e+00,
#            1.1317e+00, -1.6454e+00],
#          ...,
#          [-9.9998e-01,  1.0722e-03, -6.3959e-01,  ...,  5.0601e+00,
#            8.5136e-01, -8.7628e-01],
#          [-9.9787e-01,  9.1265e-04, -3.1467e-01,  ...,  0.0000e+00,
#            4.8530e+00,  4.1782e+00],
#          [-1.0000e+00,  3.8642e-01, -8.2187e-01,  ...,  5.6785e+00,
#            1.0873e+01,  5.6747e+00]],
#
#         [[-1.0000e+00,  9.2994e-01, -3.2162e-02,  ...,  0.0000e+00,
#           -2.9222e-01, -1.1514e-01],
#          [-9.9996e-01,  4.5026e-01, -6.2559e-01,  ...,  1.8262e+00,
#            7.3792e+00,  8.2104e+00],
#          [-1.0000e+00,  7.2588e-06,  9.4593e-01,  ...,  9.2226e+00,
#            9.3946e+00, -1.0043e+00],
#          ...,
#          [-9.9975e-01,  9.4389e-01, -4.3588e-01,  ...,  4.7234e+00,
#            5.7468e+00, -1.3662e+00],
#          [-9.9956e-01,  8.9445e-01, -2.4968e-01,  ...,  0.0000e+00,
#           -8.6076e-01, -6.9803e-01],
#          [-1.0000e+00,  4.9653e-01, -7.4581e-01,  ...,  4.1869e+00,
#            1.2719e+01, -8.5775e-01]],
#
#         ...,
#
#         [[-1.0000e+00,  6.3596e-01,  9.3882e-01,  ...,  1.9992e+00,
#           -3.3634e-01,  3.6027e+00],
#          [-9.9998e-01,  8.3745e-01, -2.3779e-02,  ...,  4.8151e+00,
#            2.4483e-01, -2.3067e-02],
#          [-1.0000e+00,  8.6511e-01, -1.2046e-01,  ...,  1.3402e+00,
#            7.0322e+00, -9.9107e-02],
#          ...,
#          [-9.9978e-01,  1.3361e-01,  1.0282e+00,  ...,  1.6831e+00,
#            6.2064e+00, -8.1877e-01],
#          [-1.0000e+00,  9.8610e-01, -6.6891e-01,  ...,  6.0020e+00,
#            1.0263e+01, -3.6893e-01],
#          [-9.9993e-01,  9.0306e-01,  3.7272e+00,  ...,  4.9984e+00,
#            1.9760e+00,  1.6436e+00]],
#
#         [[-9.9994e-01,  8.0794e-01, -2.2098e-01,  ...,  1.6761e+00,
#           -2.0138e+00, -1.3581e+00],
#          [-1.0000e+00,  8.4783e-02,  1.0691e+00,  ...,  6.4007e+00,
#            8.6686e-01,  3.6223e+00],
#          [-1.0000e+00,  5.4180e-02,  2.5935e+00,  ...,  6.4050e+00,
#           -5.9008e-01,  1.0422e-01],
#          ...,
#          [-9.9941e-01,  5.0988e-01, -4.9172e-01,  ...,  0.0000e+00,
#           -6.2493e-01, -3.4825e-01],
#          [-9.9998e-01,  1.2778e-01, -6.4967e-01,  ...,  4.6173e+00,
#            3.6256e+00, -2.9319e-01],
#          [-9.9880e-01,  9.6333e-01, -2.1660e-01,  ...,  1.7420e+00,
#            1.7756e+00, -4.6379e-01]],
#
#         [[-1.0000e+00,  8.5063e-01,  4.4994e-01,  ...,  0.0000e+00,
#            1.9025e+00,  4.5131e+00],
#          [-9.9879e-01,  9.9528e-01, -3.8272e-01,  ...,  9.9268e+00,
#            4.6800e-01, -7.1392e-01],
#          [-9.9997e-01,  7.8567e-01, -6.7360e-01,  ...,  7.4831e-01,
#            9.0978e+00, -1.3059e+00],
#          ...,
#          [-1.5470e-01,  4.5960e-01, -1.1218e-01,  ...,  0.0000e+00,
#            1.3191e+01, -1.9444e+00],
#          [-9.9754e-01,  5.3192e-03, -3.4689e-01,  ...,  2.1469e+00,
#            9.5291e-01,  1.6337e+00],
#          [-9.9851e-01,  1.1413e-01, -5.0445e-02,  ...,  1.8107e+00,
#            1.0655e+01,  5.0011e+00]]], device='cuda:0')
# 	 New output patterns generated.
# Initial eval loss: 1103.442300081253
# Epoch 1: training loss 11169.378981590271, eval loss 1117.1083731651306. Time elapsed: 0 h 0 m 4 s.
# Epoch 2: training loss 11124.175868272781, eval loss 1113.4783372879028. Time elapsed: 0 h 0 m 9 s.
# Epoch 3: training loss 11095.221644878387, eval loss 1113.2315549850464. Time elapsed: 0 h 0 m 14 s.
# Epoch 4: training loss 11083.245060920715, eval loss 1105.8829982280731. Time elapsed: 0 h 0 m 19 s.
# Epoch 5: training loss 11058.51764535904, eval loss 1110.892092704773. Time elapsed: 0 h 0 m 24 s.
# Epoch 6: training loss 11047.105580568314, eval loss 1103.056819677353. Time elapsed: 0 h 0 m 29 s.
# Epoch 7: training loss 11037.224895954132, eval loss 1104.0265092849731. Time elapsed: 0 h 0 m 33 s.
# Epoch 8: training loss 11027.09355354309, eval loss 1103.067881345749. Time elapsed: 0 h 0 m 38 s.
# Epoch 9: training loss 11019.340077400208, eval loss 1104.0921082496643. Time elapsed: 0 h 0 m 43 s.
# Epoch 10: training loss 11011.295037269592, eval loss 1106.5453870296478. Time elapsed: 0 h 0 m 48 s.
# Epoch 11: training loss 11000.5523686409, eval loss 1102.867380142212. Time elapsed: 0 h 0 m 53 s.
# Epoch 12: training loss 10994.504715681076, eval loss 1102.8573939800262. Time elapsed: 0 h 0 m 58 s.
# Epoch 13: training loss 10986.116550207138, eval loss 1106.4059300422668. Time elapsed: 0 h 1 m 2 s.
# Epoch 14: training loss 10978.64384150505, eval loss 1106.0248322486877. Time elapsed: 0 h 1 m 7 s.
# Epoch 15: training loss 10970.391780376434, eval loss 1105.172378540039. Time elapsed: 0 h 1 m 12 s.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23716/2406172998.py in <module>
# ----> 1 train_losses_by_sigma, eval_losses_by_sigma = plasticity_analysis(DNN, approx_bnn,
#       2                     DNN_params, (BNN_weights, BNN_non_linearities),
#       3                     sigmas, batch_size, num_epochs, X_train, X_test, verbose=2)
#
# /tmp/ipykernel_23716/2506314020.py in plasticity_analysis(DNN, BNN, DNN_params, BNN_params, sigmas, batch_size, num_epochs, X_train, X_test, verbose)
#      21             print(f'Processing simga={sigma} ({i+1}/{n_sigmas})')
#      22
# ---> 23         sigma_train_losses, sigma_eval_losses = transfer_learning_with_plasticity(
#      24             DNN, BNN, DNN_params, BNN_params,
#      25             sigma, batch_size, num_epochs,
#
# /tmp/ipykernel_23716/666408339.py in transfer_learning_with_plasticity(DNN, BNN, DNN_params, BNN_params, sigma, batch_size, num_epochs, X_train, X_test, alpha, verbose)
#      27
#      28     if isinstance(DNN, FeedForwardDNN):
# ---> 29         train_losses, eval_losses = train(
#      30             model=DNN,
#      31             train_loader=train_dataloader, test_loader=test_dataloader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#      36             optimiser.zero_grad()
#      37             loss.backward()
# ---> 38             optimiser.step()
#      39
#      40             epoch_loss += loss.item()
#
# ~/.local/lib/python3.9/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/.local/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/.local/lib/python3.9/site-packages/torch/optim/adam.py in step(self, closure)
#     139                     state_steps.append(state['step'])
#     140
# --> 141             F.adam(params_with_grad,
#     142                    grads,
#     143                    exp_avgs,
#
# ~/.local/lib/python3.9/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#      96         # Decay the first and second moment running average coefficient
#      97         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 98         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#      99         if amsgrad:
#     100             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
for i in range(train_losses_by_sigma.shape[0]):
    plt.plot(train_losses_by_sigma[i,:], label=f'sigma=1e-{i}')
plt.legend()
plt.show()

# %%
batch_size
# Out:
# 200

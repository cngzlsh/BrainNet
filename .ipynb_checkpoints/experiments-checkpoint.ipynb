# %% [markdown]
# # Experiments

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import seaborn as sns
from models import *
from utils import *
from torch.utils.data import DataLoader

sns.set(font_scale=1.2)
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Approximate BNN

# %%
# load data generated from approximate BNN
X_train, Y_train = load_data('./data/', 'train_abnn_16_256_0.5_4_16_0.5_10000.pkl')
X_test, Y_test = load_data('./data/', 'test_abnn_16_256_0.5_4_16_0.5_1000.pkl')

batch_size = 200    # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 200      # number of training epochs

# %% [markdown]
# ### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
def param_grid_search(hidden_dims, n_layerss):
    final_eval_loss = np.zeros((len(hidden_dims), len(n_layerss)))

    for i, hidden_dim in enumerate(hidden_dims):
        for j, n_layers in enumerate(n_layerss):

            # deep learning model
            DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)

            # training parameters
            optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
            criterion = nn.MSELoss()    

            train_losses, eval_losses = train(
                model=DNN,
                train_loader=train_dataloader, test_loader=test_dataloader,
                optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
                verbose=False, force_stop=False)

            print(f'{n_layers} layers, {hidden_dim} hidden units, final eval loss: {eval_losses[-1]}', end='\r')
            final_eval_loss[i,j] = eval_losses[-1]
    
    return final_eval_loss

def repeated_param_grid_search(hidden_dims, n_layerss, n_repeats):
    
    final_eval_loss_matrix = np.zeros((len(hidden_dims), len(n_layerss)))
    start = time.time()
    
    for i in range(n_repeats):
        
        repeat_end = time.time()
        _, elapsed_m, elapsed_s = elapsed_time(start, repeat_end)
        
        final_eval_loss = param_grid_search(hidden_dims, n_layerss)
        final_eval_loss_matrix += final_eval_loss
        
        r, c = find_argmin_in_matrix(final_eval_loss)
        print(f'{i+1}th repeat: best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}, final eval loss: {final_eval_loss[r,c]}, time elapsed: {elapsed_m} m {elapsed_s} s')
    
    return final_eval_loss_matrix / n_repeats

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=10)
# Out:
# 1th repeat: best hidden unit: 64, best layers: 2, final_eval_loss: 0.0002307878530700691, time elapsed: 0 m 0 s
# 2th repeat: best hidden unit: 128, best layers: 2, final_eval_loss: 3.9877399103716016e-05, time elapsed: 3 m 21 s
# 3th repeat: best hidden unit: 128, best layers: 2, final_eval_loss: 5.043343776378606e-06, time elapsed: 6 m 45 s
# 4th repeat: best hidden unit: 128, best layers: 4, final_eval_loss: 3.6389240449352656e-05, time elapsed: 10 m 14 s
# 5th repeat: best hidden unit: 128, best layers: 2, final_eval_loss: 4.00039953092346e-05, time elapsed: 13 m 41 s
# 6th repeat: best hidden unit: 32, best layers: 1, final_eval_loss: 2.117205667673261e-05, time elapsed: 17 m 29 s
# 7th repeat: best hidden unit: 64, best layers: 1, final_eval_loss: 4.1983762457675766e-05, time elapsed: 21 m 3 s
# 8th repeat: best hidden unit: 128, best layers: 2, final_eval_loss: 2.808140925480984e-05, time elapsed: 24 m 35 s
# 9th repeat: best hidden unit: 32, best layers: 1, final_eval_loss: 4.5729816520179156e-05, time elapsed: 28 m 7 s
# 10th repeat: best hidden unit: 64, best layers: 2, final_eval_loss: 1.63612048709183e-05, time elapsed: 31 m 45 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss')
# Out:
# Best hidden unit: 64, best layers: 1

# %% [markdown]
# ###  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=64, n_layers=1, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()    

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 0.03608187474310398
# Epoch 1: training loss 0.05570624221581966, eval loss 0.0024849633628036827. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 0.018442351138219237, eval loss 0.0012831686763092875. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 0.008901660941774026, eval loss 0.0006546306249219924. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 0.005294227310514543, eval loss 0.00045519341074395925. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 0.003970628611568827, eval loss 0.00035499386285664514. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 0.0029352738965826575, eval loss 0.0002443692173983436. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 0.0018988292049471056, eval loss 0.0001621770607016515. Time elapsed: 0 h 0 m 0 s.
# Epoch 8: training loss 0.0013187093172746245, eval loss 0.000120787428386393. Time elapsed: 0 h 0 m 0 s.
# Epoch 9: training loss 0.0010321315730834613, eval loss 9.865542415354867e-05. Time elapsed: 0 h 0 m 0 s.
# Epoch 10: training loss 0.0008697219582245452, eval loss 8.463379344902933e-05. Time elapsed: 0 h 0 m 0 s.
# Epoch 11: training loss 0.000762959730309376, eval loss 7.466635997843696e-05. Time elapsed: 0 h 0 m 0 s.
# Epoch 12: training loss 0.0006862892960270983, eval loss 6.741910146956798e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 0.0006285679037318914, eval loss 6.18288040641346e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 0.0005836787104271934, eval loss 5.745786074839998e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 15: training loss 0.0005481052348841331, eval loss 5.4096957683213986e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 16: training loss 0.0005201031108299503, eval loss 5.1476731641741935e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 17: training loss 0.0004979115610694862, eval loss 4.939023347105831e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 18: training loss 0.0004803194387932308, eval loss 4.773258297063876e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 19: training loss 0.0004661793764171307, eval loss 4.637711026589386e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 20: training loss 0.00045461963691195706, eval loss 4.527896271611098e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 21: training loss 0.0004451476515896502, eval loss 4.438500855030725e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 22: training loss 0.00043743568585341563, eval loss 4.365206041256897e-05. Time elapsed: 0 h 0 m 1 s.
# Epoch 23: training loss 0.00043111314607813256, eval loss 4.305702077544993e-05. Time elapsed: 0 h 0 m 2 s.
# Epoch 24: training loss 0.0004259092847860302, eval loss 4.257762157067191e-05. Time elapsed: 0 h 0 m 2 s.
# Epoch 25: training loss 0.00042162789395661093, eval loss 4.2188804400211666e-05. Time elapsed: 0 h 0 m 2 s.
# Training completed with final epoch loss 0.00042162789395661093. Time elapsed: 0 h 0 m 2 s.

# %% [markdown]
# ### 3. Testing against predicting the mean

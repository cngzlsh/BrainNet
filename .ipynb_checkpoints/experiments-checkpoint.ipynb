# %% [markdown]
# # Experiments

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import numpy as np
import time
import seaborn as sns

from models import *
from utils import *
from train import *

sns.set(font_scale=1.2)
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Approximate BNNs
# ### Feedforward BNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_ff_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_ff_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_ff_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=20,
    **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.2236513085663319, time elapsed: 0 h 5 m 53 s
# 2th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3796061798930168, time elapsed: 0 h 11 m 49 s
# 3th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4214531369507313, time elapsed: 0 h 17 m 42 s
# 4th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5031835921108723, time elapsed: 0 h 23 m 36 s
# 5th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3559647090733051, time elapsed: 0 h 29 m 30 s
# 6th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.4109087698161602, time elapsed: 0 h 35 m 24 s
# 7th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3112598918378353, time elapsed: 0 h 41 m 18 s
# 8th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4069683142006397, time elapsed: 0 h 47 m 12 s
# 9th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3792462646961212, time elapsed: 0 h 53 m 6 s
# 10th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.2824228294193745, time elapsed: 0 h 59 m 0 s
# 11th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.423352349549532, time elapsed: 1 h 4 m 52 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3886688724160194, time elapsed: 1 h 10 m 43 s
# 13th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.34787892177701, time elapsed: 1 h 16 m 35 s
# 14th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3388245441019535, time elapsed: 1 h 22 m 27 s
# 15th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3775753788650036, time elapsed: 1 h 28 m 18 s
# 16th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3388367779552937, time elapsed: 1 h 34 m 10 s
# 17th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.3071992136538029, time elapsed: 1 h 40 m 2 s
# 18th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.2356889434158802, time elapsed: 1 h 45 m 54 s
# 19th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.335600707679987, time elapsed: 1 h 51 m 45 s
# 20th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4589847885072231, time elapsed: 1 h 57 m 37 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average log loss', fname='param_search_log_ff')
# Out:
# Best hidden unit: 256, best layers: 3

# %% [markdown]
# ####  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_train[13,:], DNN(X_train[13,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_train[13,:], DNN(X_train[13,:])) # visualise after training
# Out:
# Initial eval loss: 4.695026874542236
# Epoch 1: training loss 36.213128477334976, eval loss 3.0576266646385193. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 28.73745220899582, eval loss 2.692495971918106. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 25.523059725761414, eval loss 2.4244983792304993. Time elapsed: 0 h 0 m 1 s.
# Epoch 4: training loss 23.432956963777542, eval loss 2.258539229631424. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 21.74177534878254, eval loss 2.064207971096039. Time elapsed: 0 h 0 m 2 s.
# Epoch 6: training loss 20.384284481406212, eval loss 1.9508095383644104. Time elapsed: 0 h 0 m 2 s.
# Epoch 7: training loss 18.95094195008278, eval loss 1.8807568848133087. Time elapsed: 0 h 0 m 3 s.
# Epoch 8: training loss 17.921368807554245, eval loss 1.7931607961654663. Time elapsed: 0 h 0 m 3 s.
# Epoch 9: training loss 17.057888701558113, eval loss 1.7380847036838531. Time elapsed: 0 h 0 m 4 s.
# Epoch 10: training loss 16.016517370939255, eval loss 1.6945154815912247. Time elapsed: 0 h 0 m 4 s.
# Epoch 11: training loss 15.052668407559395, eval loss 1.663290098309517. Time elapsed: 0 h 0 m 5 s.
# Epoch 12: training loss 14.134040832519531, eval loss 1.6450935900211334. Time elapsed: 0 h 0 m 5 s.
# Epoch 13: training loss 13.332975968718529, eval loss 1.5892184376716614. Time elapsed: 0 h 0 m 6 s.
# Epoch 14: training loss 12.81228357553482, eval loss 1.5855966806411743. Time elapsed: 0 h 0 m 6 s.
# Epoch 15: training loss 12.28164418041706, eval loss 1.532541036605835. Time elapsed: 0 h 0 m 7 s.
# Epoch 16: training loss 11.652895346283913, eval loss 1.549174576997757. Time elapsed: 0 h 0 m 7 s.
# Epoch 17: training loss 10.925517775118351, eval loss 1.5175185799598694. Time elapsed: 0 h 0 m 8 s.
# Epoch 18: training loss 10.371365614235401, eval loss 1.4352670460939407. Time elapsed: 0 h 0 m 8 s.
# Epoch 19: training loss 9.860728353261948, eval loss 1.4671168327331543. Time elapsed: 0 h 0 m 9 s.
# Epoch 20: training loss 9.27283488214016, eval loss 1.4312467128038406. Time elapsed: 0 h 0 m 9 s.
# Epoch 21: training loss 9.05293969064951, eval loss 1.4545334726572037. Time elapsed: 0 h 0 m 10 s.
# Epoch 22: training loss 8.432463139295578, eval loss 1.3885030448436737. Time elapsed: 0 h 0 m 10 s.
# Epoch 23: training loss 8.131646186113358, eval loss 1.426739364862442. Time elapsed: 0 h 0 m 11 s.
# Epoch 24: training loss 7.656352996826172, eval loss 1.448170855641365. Time elapsed: 0 h 0 m 11 s.
# Epoch 25: training loss 7.160667099058628, eval loss 1.3741137236356735. Time elapsed: 0 h 0 m 12 s.
# Epoch 26: training loss 6.710712410509586, eval loss 1.326524555683136. Time elapsed: 0 h 0 m 12 s.
# Epoch 27: training loss 6.218168072402477, eval loss 1.5375768095254898. Time elapsed: 0 h 0 m 13 s.
# Epoch 28: training loss 6.538337513804436, eval loss 1.3621197640895844. Time elapsed: 0 h 0 m 13 s.
# Epoch 29: training loss 5.726955384016037, eval loss 1.3709072470664978. Time elapsed: 0 h 0 m 14 s.
# Epoch 30: training loss 4.973205529153347, eval loss 1.4158759415149689. Time elapsed: 0 h 0 m 14 s.
# Epoch 31: training loss 4.952128671109676, eval loss 1.4123932868242264. Time elapsed: 0 h 0 m 15 s.
# Epoch 32: training loss 4.786670595407486, eval loss 1.427502304315567. Time elapsed: 0 h 0 m 15 s.
# Epoch 33: training loss 4.33021105825901, eval loss 1.3447878956794739. Time elapsed: 0 h 0 m 16 s.
# Epoch 34: training loss 4.10090359300375, eval loss 1.4058776497840881. Time elapsed: 0 h 0 m 16 s.
# Epoch 35: training loss 3.8517416305840015, eval loss 1.356712982058525. Time elapsed: 0 h 0 m 17 s.
# Epoch 36: training loss 3.772450417280197, eval loss 1.4126961827278137. Time elapsed: 0 h 0 m 17 s.
# Epoch 37: training loss 3.6260838732123375, eval loss 1.42783984541893. Time elapsed: 0 h 0 m 18 s.
# Epoch 38: training loss 3.574735291302204, eval loss 1.3875664174556732. Time elapsed: 0 h 0 m 18 s.
# Epoch 39: training loss 3.4775686599314213, eval loss 1.4239789694547653. Time elapsed: 0 h 0 m 19 s.
# Epoch 40: training loss 3.3579453490674496, eval loss 1.369759887456894. Time elapsed: 0 h 0 m 19 s.
# Epoch 41: training loss 3.2271864153444767, eval loss 1.3489930331707. Time elapsed: 0 h 0 m 20 s.
# Epoch 42: training loss 3.167201206088066, eval loss 1.4097652435302734. Time elapsed: 0 h 0 m 20 s.
# Epoch 43: training loss 3.2690865099430084, eval loss 1.4354430139064789. Time elapsed: 0 h 0 m 21 s.
# Epoch 44: training loss 3.182692486792803, eval loss 1.426760122179985. Time elapsed: 0 h 0 m 21 s.
# Epoch 45: training loss 3.1541046798229218, eval loss 1.3847186267375946. Time elapsed: 0 h 0 m 22 s.
# Epoch 46: training loss 3.0434286408126354, eval loss 1.3546516448259354. Time elapsed: 0 h 0 m 22 s.
# Epoch 47: training loss 2.8834328316152096, eval loss 1.342402383685112. Time elapsed: 0 h 0 m 23 s.
# Epoch 48: training loss 2.9786080047488213, eval loss 1.5071235597133636. Time elapsed: 0 h 0 m 23 s.
# Epoch 49: training loss 2.8873115815222263, eval loss 1.3219475895166397. Time elapsed: 0 h 0 m 24 s.
# Epoch 50: training loss 2.805552862584591, eval loss 1.4681207686662674. Time elapsed: 0 h 0 m 24 s.
# Training completed with final epoch loss 2.805552862584591. Time elapsed: 0 h 0 m 24 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    pred_mean = DNN(X_train)
    
print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.2936, grad_fn=<MseLossBackward0>)
# Predicting mean MSE error on test set tensor(0.9366)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_1414/4047130697.py:5: UserWarning: Using a target size (torch.Size([1000, 16])) that is different to the input size (torch.Size([16])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))

# %% [markdown]
# ### Residual BNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_resid_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_resid_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_resid_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=20, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5967381224036217, time elapsed: 0 h 5 m 52 s
# 2th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.433569222688675, time elapsed: 0 h 11 m 45 s
# 3th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.412415325641632, time elapsed: 0 h 17 m 37 s
# 4th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.535665601491928, time elapsed: 0 h 23 m 29 s
# 5th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.6068566665053368, time elapsed: 0 h 29 m 22 s
# 6th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4701523035764694, time elapsed: 0 h 35 m 14 s
# 7th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.6413992196321487, time elapsed: 0 h 41 m 6 s
# 8th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5728920251131058, time elapsed: 0 h 46 m 58 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.3817531391978264, time elapsed: 0 h 52 m 51 s
# 10th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.470106951892376, time elapsed: 0 h 58 m 43 s
# 11th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5287975147366524, time elapsed: 1 h 4 m 35 s
# 12th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5984190851449966, time elapsed: 1 h 10 m 27 s
# 13th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.6116824746131897, time elapsed: 1 h 16 m 19 s
# 14th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.429640181362629, time elapsed: 1 h 22 m 12 s
# 15th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5206275805830956, time elapsed: 1 h 28 m 4 s
# 16th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5126023888587952, time elapsed: 1 h 33 m 56 s
# 17th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.4933289512991905, time elapsed: 1 h 39 m 49 s
# 18th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.489557333290577, time elapsed: 1 h 45 m 41 s
# 19th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5030639842152596, time elapsed: 1 h 51 m 34 s
# 20th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.4897226989269257, time elapsed: 1 h 57 m 26 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average log loss', fname='param_search_resid')
# Out:
# Best hidden unit: 256, best layers: 4

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_train[v_idx,:], DNN(X_train[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_train[v_idx,:], DNN(X_train[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 0.9302728772163391
# Epoch 1: training loss 36.048550099134445, eval loss 0.5894066691398621. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 26.959660708904266, eval loss 0.5070626139640808. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 23.32795399427414, eval loss 0.4452381432056427. Time elapsed: 0 h 0 m 1 s.
# Epoch 4: training loss 20.570971339941025, eval loss 0.41240665316581726. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 18.454230085015297, eval loss 0.39105111360549927. Time elapsed: 0 h 0 m 2 s.
# Epoch 6: training loss 17.294301003217697, eval loss 0.377877414226532. Time elapsed: 0 h 0 m 2 s.
# Epoch 7: training loss 16.016077175736427, eval loss 0.36723098158836365. Time elapsed: 0 h 0 m 3 s.
# Epoch 8: training loss 15.049422726035118, eval loss 0.3662862479686737. Time elapsed: 0 h 0 m 3 s.
# Epoch 9: training loss 14.330031514167786, eval loss 0.3601977825164795. Time elapsed: 0 h 0 m 4 s.
# Epoch 10: training loss 13.556216314435005, eval loss 0.34337466955184937. Time elapsed: 0 h 0 m 4 s.
# Epoch 11: training loss 12.985445261001587, eval loss 0.3349613845348358. Time elapsed: 0 h 0 m 5 s.
# Epoch 12: training loss 12.330808773636818, eval loss 0.3529401421546936. Time elapsed: 0 h 0 m 5 s.
# Epoch 13: training loss 11.929618701338768, eval loss 0.3251825273036957. Time elapsed: 0 h 0 m 6 s.
# Epoch 14: training loss 11.692429095506668, eval loss 0.33229583501815796. Time elapsed: 0 h 0 m 6 s.
# Epoch 15: training loss 10.924965217709541, eval loss 0.3175015449523926. Time elapsed: 0 h 0 m 7 s.
# Epoch 16: training loss 10.236103467643261, eval loss 0.31721246242523193. Time elapsed: 0 h 0 m 7 s.
# Epoch 17: training loss 10.016958467662334, eval loss 0.3062743842601776. Time elapsed: 0 h 0 m 8 s.
# Epoch 18: training loss 9.477560810744762, eval loss 0.3070299029350281. Time elapsed: 0 h 0 m 8 s.
# Epoch 19: training loss 9.056361943483353, eval loss 0.29794222116470337. Time elapsed: 0 h 0 m 9 s.
# Epoch 20: training loss 8.716686271131039, eval loss 0.30643215775489807. Time elapsed: 0 h 0 m 9 s.
# Epoch 21: training loss 8.673752814531326, eval loss 0.29876476526260376. Time elapsed: 0 h 0 m 10 s.
# Epoch 22: training loss 8.172729082405567, eval loss 0.2935679852962494. Time elapsed: 0 h 0 m 10 s.
# Epoch 23: training loss 7.779513828456402, eval loss 0.29315075278282166. Time elapsed: 0 h 0 m 10 s.
# Epoch 24: training loss 7.350888967514038, eval loss 0.3007490932941437. Time elapsed: 0 h 0 m 11 s.
# Epoch 25: training loss 7.146546423435211, eval loss 0.281921923160553. Time elapsed: 0 h 0 m 11 s.
# Epoch 26: training loss 6.550353184342384, eval loss 0.27113237977027893. Time elapsed: 0 h 0 m 12 s.
# Epoch 27: training loss 5.955376207828522, eval loss 0.29933080077171326. Time elapsed: 0 h 0 m 12 s.
# Epoch 28: training loss 5.423660911619663, eval loss 0.2875944972038269. Time elapsed: 0 h 0 m 13 s.
# Epoch 29: training loss 5.0911045372486115, eval loss 0.2984236180782318. Time elapsed: 0 h 0 m 13 s.
# Epoch 30: training loss 5.308401547372341, eval loss 0.3060677647590637. Time elapsed: 0 h 0 m 14 s.
# Epoch 31: training loss 5.257389008998871, eval loss 0.2825716435909271. Time elapsed: 0 h 0 m 14 s.
# Epoch 32: training loss 4.89793049544096, eval loss 0.28491929173469543. Time elapsed: 0 h 0 m 15 s.
# Epoch 33: training loss 5.455772064626217, eval loss 0.3247804343700409. Time elapsed: 0 h 0 m 15 s.
# Epoch 34: training loss 4.780480980873108, eval loss 0.2979300916194916. Time elapsed: 0 h 0 m 16 s.
# Epoch 35: training loss 4.21528735011816, eval loss 0.28254014253616333. Time elapsed: 0 h 0 m 16 s.
# Epoch 36: training loss 4.058562770485878, eval loss 0.2923843264579773. Time elapsed: 0 h 0 m 17 s.
# Epoch 37: training loss 3.9552830532193184, eval loss 0.27885669469833374. Time elapsed: 0 h 0 m 17 s.
# Epoch 38: training loss 3.80244342982769, eval loss 0.27767494320869446. Time elapsed: 0 h 0 m 18 s.
# Epoch 39: training loss 3.7322698161005974, eval loss 0.29276415705680847. Time elapsed: 0 h 0 m 18 s.
# Epoch 40: training loss 3.6871776953339577, eval loss 0.28660935163497925. Time elapsed: 0 h 0 m 19 s.
# Epoch 41: training loss 3.5230518244206905, eval loss 0.28653684258461. Time elapsed: 0 h 0 m 19 s.
# Epoch 42: training loss 3.510879673063755, eval loss 0.2882004976272583. Time elapsed: 0 h 0 m 20 s.
# Epoch 43: training loss 3.3650311790406704, eval loss 0.287695050239563. Time elapsed: 0 h 0 m 20 s.
# Epoch 44: training loss 3.2893353030085564, eval loss 0.27765199542045593. Time elapsed: 0 h 0 m 20 s.
# Epoch 45: training loss 3.1995052322745323, eval loss 0.2744542062282562. Time elapsed: 0 h 0 m 21 s.
# Epoch 46: training loss 3.1675176173448563, eval loss 0.27858301997184753. Time elapsed: 0 h 0 m 21 s.
# Epoch 47: training loss 3.068267296999693, eval loss 0.2737596035003662. Time elapsed: 0 h 0 m 22 s.
# Epoch 48: training loss 3.017794355750084, eval loss 0.2772218585014343. Time elapsed: 0 h 0 m 22 s.
# Epoch 49: training loss 3.0171720050275326, eval loss 0.281751811504364. Time elapsed: 0 h 0 m 23 s.
# Epoch 50: training loss 3.065863098949194, eval loss 0.26851195096969604. Time elapsed: 0 h 0 m 23 s.
# Training completed with final epoch loss 3.065863098949194. Time elapsed: 0 h 0 m 23 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    pred_mean = DNN(X_train)
    
print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.2685, grad_fn=<MseLossBackward0>)
# Predicting mean MSE error on test set tensor(0.9281)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_1414/4047130697.py:5: UserWarning: Using a target size (torch.Size([100, 16])) that is different to the input size (torch.Size([16])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))

# %% [markdown]
# ### Recurrent RNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_recur_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_recur_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_recur_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=20, **{'_type':'RNN', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_layers=1, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')
# Out:
# Initial eval loss: 5.040354251861572
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_1284/609967341.py in <module>
#       8 criterion = nn.MSELoss()
#       9
# ---> 10 train_losses, eval_losses = train_rnn(
#      11     model=DNN,
#      12     train_loader=train_dataloader, test_loader=test_dataloader,
#
# ~/Documents/BrainNet/train.py in train_rnn(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#     104         for i, (X, Y) in enumerate(iter(train_loader)): # X: [batch_size, time_step, input_dim]
#     105
# --> 106             Y_hat, rec_prev = model(X, rec_prev)
#     107             loss = criterion(Y_hat, Y)
#     108
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/BrainNet/models.py in forward(self, x, rec_prev)
#      56         x = self.transfer_function(x)
#      57
# ---> 58         x = self.hidden1(x)
#      59         x = self.transfer_function(x)
#      60
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# %debug
# Out:
# > /home/daniel/.local/lib/python3.9/site-packages/torch/nn/modules/rnn.py(747)forward()
#     745                         msg = ("For batched 3-D input, hx and cx should "
#     746                                f"also be 3-D but got ({hx[0].dim()}-D, {hx[1].dim()}-D) tensors")
# --> 747                         raise RuntimeError(msg)
#     748                 else:
#     749                     if hx[0].dim() != 2 or hx[1].dim() != 2:
# ipdb>  c_prev
# *** NameError: name 'c_prev' is not defined

# %% [markdown]
# # Experiments

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import numpy as np
import time
import seaborn as sns

from models import *
from utils import *
from train import *

sns.set(font_scale=1.2)
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Approximate BNNs
# ### Feedforward BNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_ff_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_ff_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_ff_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=20,
    **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.255809247493744, time elapsed: 3 m 38 s
# 7 layers, 8 hidden units, final eval loss: 16.210961043834686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_79743/3695624783.py in <module>
#       2 n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]
#       3
# ----> 4 avg_final_eval_loss = repeated_param_grid_search(
#       5     hidden_dims, n_layerss, n_repeats=50,
#       6     **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in repeated_param_grid_search(hidden_dims, n_layerss, n_repeats, **kwargs)
#     231     for i in range(n_repeats):
#     232
# --> 233         final_eval_loss = param_grid_search(hidden_dims, n_layerss, **kwargs)
#     234         final_eval_loss_matrix += final_eval_loss
#     235
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in param_grid_search(hidden_dims, n_layerss, **kwargs)
#     213             criterion = nn.MSELoss()
#     214
# --> 215             train_losses, eval_losses = train(
#     216                 model=DNN,
#     217                 train_loader=valid_loader, test_loader=test_loader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#     132                 break
#     133
# --> 134         eval_loss = eval(model, test_loader, criterion)
#     135
#     136         train_losses.append(epoch_loss)
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in eval(model, test_loader, criterion)
#     162         eval_loss = 0
#     163
# --> 164         for _, (X, Y) in enumerate(iter(test_loader)):
#     165
#     166             Y_hat = model(X)
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/utils.py in __getitem__(self, idx)
#      63
#      64     def __getitem__(self, idx):
# ---> 65         input = self.inputs[idx,:]
#      66         label = self.labels[idx,:]
#      67         return input, label
#
# KeyboardInterrupt:

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average log loss', fname='param_search_log_ff')
# Out:
# Best hidden unit: 256, best layers: 3

# %% [markdown]
# ####  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_train[13,:], DNN(X_train[13,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_train[13,:], DNN(X_train[13,:])) # visualise after training
# Out:
# Initial eval loss: 4.69523298740387
# Epoch 1: training loss 36.68087023496628, eval loss 3.0915587544441223. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 28.851396083831787, eval loss 2.6946181058883667. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 25.6065870821476, eval loss 2.4122732281684875. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 23.367661982774734, eval loss 2.208168715238571. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 21.711021974682808, eval loss 2.0505310893058777. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 20.27371659874916, eval loss 1.9597993195056915. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 19.088912293314934, eval loss 1.8796273469924927. Time elapsed: 0 h 0 m 0 s.
# Epoch 8: training loss 18.17594785988331, eval loss 1.7910193800926208. Time elapsed: 0 h 0 m 0 s.
# Epoch 9: training loss 17.089602395892143, eval loss 1.7434249818325043. Time elapsed: 0 h 0 m 0 s.
# Epoch 10: training loss 16.06836622953415, eval loss 1.7131671011447906. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 15.135158896446228, eval loss 1.6338318139314651. Time elapsed: 0 h 0 m 1 s.
# Epoch 12: training loss 14.199973419308662, eval loss 1.601848915219307. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 13.614966243505478, eval loss 1.5477523058652878. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 12.809017524123192, eval loss 1.5750181823968887. Time elapsed: 0 h 0 m 1 s.
# Epoch 15: training loss 12.370456621050835, eval loss 1.5603350102901459. Time elapsed: 0 h 0 m 1 s.
# Epoch 16: training loss 11.454502709209919, eval loss 1.498118370771408. Time elapsed: 0 h 0 m 1 s.
# Epoch 17: training loss 11.143708616495132, eval loss 1.514185145497322. Time elapsed: 0 h 0 m 1 s.
# Epoch 18: training loss 10.532257921993732, eval loss 1.4257297813892365. Time elapsed: 0 h 0 m 1 s.
# Epoch 19: training loss 9.958767771720886, eval loss 1.398961216211319. Time elapsed: 0 h 0 m 2 s.
# Epoch 20: training loss 9.445953123271465, eval loss 1.4480744302272797. Time elapsed: 0 h 0 m 2 s.
# Epoch 21: training loss 8.767128385603428, eval loss 1.4190137684345245. Time elapsed: 0 h 0 m 2 s.
# Epoch 22: training loss 8.403459526598454, eval loss 1.4811712503433228. Time elapsed: 0 h 0 m 2 s.
# Epoch 23: training loss 7.826493293046951, eval loss 1.4729217886924744. Time elapsed: 0 h 0 m 2 s.
# Epoch 24: training loss 7.258513309061527, eval loss 1.6458812654018402. Time elapsed: 0 h 0 m 2 s.
# Epoch 25: training loss 7.460275590419769, eval loss 1.694737657904625. Time elapsed: 0 h 0 m 2 s.
# Epoch 26: training loss 6.6535472348332405, eval loss 1.4043057560920715. Time elapsed: 0 h 0 m 2 s.
# Epoch 27: training loss 5.8427101373672485, eval loss 1.5305419117212296. Time elapsed: 0 h 0 m 2 s.
# Epoch 28: training loss 5.768844753503799, eval loss 1.6143028438091278. Time elapsed: 0 h 0 m 2 s.
# Epoch 29: training loss 5.286265067756176, eval loss 1.5257759243249893. Time elapsed: 0 h 0 m 3 s.
# Epoch 30: training loss 4.86975521594286, eval loss 1.3908856213092804. Time elapsed: 0 h 0 m 3 s.
# Epoch 31: training loss 4.7223175168037415, eval loss 1.4634489119052887. Time elapsed: 0 h 0 m 3 s.
# Epoch 32: training loss 4.551399551331997, eval loss 1.4515507519245148. Time elapsed: 0 h 0 m 3 s.
# Epoch 33: training loss 4.442861050367355, eval loss 1.434654638171196. Time elapsed: 0 h 0 m 3 s.
# Epoch 34: training loss 4.227326113730669, eval loss 1.3727028220891953. Time elapsed: 0 h 0 m 3 s.
# Epoch 35: training loss 4.121409434825182, eval loss 1.3565322905778885. Time elapsed: 0 h 0 m 3 s.
# Epoch 36: training loss 3.9283707439899445, eval loss 1.4039499759674072. Time elapsed: 0 h 0 m 3 s.
# Epoch 37: training loss 3.7379712499678135, eval loss 1.378533199429512. Time elapsed: 0 h 0 m 3 s.
# Epoch 38: training loss 3.69503016397357, eval loss 1.4122228622436523. Time elapsed: 0 h 0 m 4 s.
# Epoch 39: training loss 3.6401867493987083, eval loss 1.33153036236763. Time elapsed: 0 h 0 m 4 s.
# Epoch 40: training loss 3.601352948695421, eval loss 1.3950197398662567. Time elapsed: 0 h 0 m 4 s.
# Epoch 41: training loss 3.457190427929163, eval loss 1.3705706894397736. Time elapsed: 0 h 0 m 4 s.
# Epoch 42: training loss 3.2996606454253197, eval loss 1.3210036605596542. Time elapsed: 0 h 0 m 4 s.
# Epoch 43: training loss 3.243393149226904, eval loss 1.3895819783210754. Time elapsed: 0 h 0 m 4 s.
# Epoch 44: training loss 3.23762296885252, eval loss 1.3415913730859756. Time elapsed: 0 h 0 m 4 s.
# Epoch 45: training loss 3.0869113951921463, eval loss 1.2883212268352509. Time elapsed: 0 h 0 m 4 s.
# Epoch 46: training loss 3.092054907232523, eval loss 1.3221664428710938. Time elapsed: 0 h 0 m 4 s.
# Epoch 47: training loss 3.1778712049126625, eval loss 1.405062973499298. Time elapsed: 0 h 0 m 5 s.
# Epoch 48: training loss 3.2157656252384186, eval loss 1.3484024703502655. Time elapsed: 0 h 0 m 5 s.
# Epoch 49: training loss 3.205407679080963, eval loss 1.4060045033693314. Time elapsed: 0 h 0 m 5 s.
# Epoch 50: training loss 3.0890381783246994, eval loss 1.3466359823942184. Time elapsed: 0 h 0 m 5 s.
# Training completed with final epoch loss 3.0890381783246994. Time elapsed: 0 h 0 m 5 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    pred_mean = DNN(X_train)
    
print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.2694, device='cuda:0', grad_fn=<MseLossBackward0>)
# Predicting mean MSE error on test set tensor(0.9366, device='cuda:0')
# /tmp/ipykernel_68121/4047130697.py:5: UserWarning: Using a target size (torch.Size([1000, 16])) that is different to the input size (torch.Size([16])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))

# %% [markdown]
# ### Residual BNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_resid_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_resid_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_resid_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=20, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4796407669782639, time elapsed: 0 h 5 m 48 s
# 2th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5535445287823677, time elapsed: 0 h 11 m 33 s
# 3th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5108963027596474, time elapsed: 0 h 17 m 18 s
# 4th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.625996544957161, time elapsed: 0 h 23 m 4 s
# 5th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.4950257167220116, time elapsed: 0 h 28 m 50 s
# 6th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.6027601808309555, time elapsed: 0 h 34 m 36 s
# 7th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5317018628120422, time elapsed: 0 h 40 m 20 s
# 8th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5494886115193367, time elapsed: 0 h 46 m 3 s
# 9th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5204248577356339, time elapsed: 0 h 51 m 47 s
# 10th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5452962666749954, time elapsed: 0 h 57 m 30 s
# 11th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.4562800601124763, time elapsed: 1 h 3 m 14 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5826731249690056, time elapsed: 1 h 8 m 57 s
# 13th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4629689082503319, time elapsed: 1 h 14 m 41 s
# 14th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.6306475028395653, time elapsed: 1 h 20 m 24 s
# 15th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5612600669264793, time elapsed: 1 h 26 m 8 s
# 16th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.489156499505043, time elapsed: 1 h 31 m 51 s
# 17th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4529613852500916, time elapsed: 1 h 37 m 35 s
# 18th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4846907332539558, time elapsed: 1 h 43 m 18 s
# 19th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.6097221225500107, time elapsed: 1 h 49 m 2 s
# 20th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.598231390118599, time elapsed: 1 h 54 m 46 s
# 21th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.532789260149002, time elapsed: 2 h 0 m 29 s
# 22th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.4381498247385025, time elapsed: 2 h 6 m 13 s
# 23th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5706420689821243, time elapsed: 2 h 11 m 57 s
# 24th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.5366915240883827, time elapsed: 2 h 17 m 42 s
# 25th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.4654260128736496, time elapsed: 2 h 23 m 26 s
# 26th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.5197260901331902, time elapsed: 2 h 29 m 11 s
# 5 layers, 64 hidden units, final eval loss: 8.2632211148738862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_1642/1565924752.py in <module>
#       2 n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]
#       3
# ----> 4 avg_final_eval_loss = repeated_param_grid_search(
#       5     hidden_dims, n_layerss, n_repeats=50, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
#
# ~/Documents/BrainNet/utils.py in repeated_param_grid_search(hidden_dims, n_layerss, n_repeats, **kwargs)
#     312     for i in range(n_repeats):
#     313
# --> 314         final_eval_loss = param_grid_search(hidden_dims, n_layerss, **kwargs)
#     315         final_eval_loss_matrix += final_eval_loss
#     316
#
# ~/Documents/BrainNet/utils.py in param_grid_search(hidden_dims, n_layerss, **kwargs)
#     294             criterion = nn.MSELoss()
#     295
# --> 296             train_losses, eval_losses = train(
#     297                 model=DNN,
#     298                 train_loader=valid_loader, test_loader=test_loader,
#
# ~/Documents/BrainNet/utils.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#     132                 break
#     133
# --> 134         eval_loss = eval(model, test_loader, criterion)
#     135
#     136         train_losses.append(epoch_loss)
#
# ~/Documents/BrainNet/utils.py in eval(model, test_loader, criterion)
#     164         for _, (X, Y) in enumerate(iter(test_loader)):
#     165
# --> 166             Y_hat = model(X)
#     167             loss = criterion(Y_hat, Y)
#     168
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/BrainNet/models.py in forward(self, input_pattern)
#      25
#      26     def forward(self, input_pattern):
# ---> 27         return self.layers(input_pattern)
#      28
#      29 class RecurrentDNN(nn.Module):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/activation.py in forward(self, input)
#      96
#      97     def forward(self, input: Tensor) -> Tensor:
# ---> 98         return F.relu(input, inplace=self.inplace)
#      99
#     100     def extra_repr(self) -> str:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py in relu(input, inplace)
#    1440         result = torch.relu_(input)
#    1441     else:
# -> 1442         result = torch.relu(input)
#    1443     return result
#    1444
#
# KeyboardInterrupt:

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average log loss', fname='param_search_resid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_1642/3806180496.py in <module>
# ----> 1 r, c = find_argmin_in_matrix(avg_final_eval_loss)
#       2 print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
#       3 plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
#       4                x_label='Hidden units', y_label='Layers', z_label='Average log loss', fname='param_search_resid')
#
# NameError: name 'avg_final_eval_loss' is not defined

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_train[v_idx,:], DNN(X_train[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_train[v_idx,:], DNN(X_train[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 0.9302523732185364
# Epoch 1: training loss 36.01911252737045, eval loss 0.5721434950828552. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 26.786294728517532, eval loss 0.5058890581130981. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 23.611456245183945, eval loss 0.46041226387023926. Time elapsed: 0 h 0 m 1 s.
# Epoch 4: training loss 20.940164983272552, eval loss 0.4130915403366089. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 18.764892414212227, eval loss 0.3819584548473358. Time elapsed: 0 h 0 m 2 s.
# Epoch 6: training loss 17.418373331427574, eval loss 0.38525626063346863. Time elapsed: 0 h 0 m 2 s.
# Epoch 7: training loss 16.377521365880966, eval loss 0.3600161671638489. Time elapsed: 0 h 0 m 3 s.
# Epoch 8: training loss 15.57878415286541, eval loss 0.3544914126396179. Time elapsed: 0 h 0 m 3 s.
# Epoch 9: training loss 14.71186076104641, eval loss 0.34353092312812805. Time elapsed: 0 h 0 m 4 s.
# Epoch 10: training loss 14.216370984911919, eval loss 0.357000470161438. Time elapsed: 0 h 0 m 4 s.
# Epoch 11: training loss 13.7173460572958, eval loss 0.34003719687461853. Time elapsed: 0 h 0 m 5 s.
# Epoch 12: training loss 13.189636558294296, eval loss 0.34903088212013245. Time elapsed: 0 h 0 m 5 s.
# Epoch 13: training loss 12.5480677485466, eval loss 0.3287458121776581. Time elapsed: 0 h 0 m 6 s.
# Epoch 14: training loss 12.16582915186882, eval loss 0.3190993666648865. Time elapsed: 0 h 0 m 6 s.
# Epoch 15: training loss 11.809680163860321, eval loss 0.32222625613212585. Time elapsed: 0 h 0 m 7 s.
# Epoch 16: training loss 11.051363572478294, eval loss 0.3154374361038208. Time elapsed: 0 h 0 m 7 s.
# Epoch 17: training loss 10.658053010702133, eval loss 0.3176875412464142. Time elapsed: 0 h 0 m 8 s.
# Epoch 18: training loss 10.12767779827118, eval loss 0.31190600991249084. Time elapsed: 0 h 0 m 8 s.
# Epoch 19: training loss 9.878618516027927, eval loss 0.3144112825393677. Time elapsed: 0 h 0 m 9 s.
# Epoch 20: training loss 9.29693515598774, eval loss 0.3422756493091583. Time elapsed: 0 h 0 m 9 s.
# Epoch 21: training loss 8.908596731722355, eval loss 0.32872748374938965. Time elapsed: 0 h 0 m 10 s.
# Epoch 22: training loss 8.448074713349342, eval loss 0.31086987257003784. Time elapsed: 0 h 0 m 10 s.
# Epoch 23: training loss 8.11399745196104, eval loss 0.3017106354236603. Time elapsed: 0 h 0 m 11 s.
# Epoch 24: training loss 7.703742429614067, eval loss 0.289238840341568. Time elapsed: 0 h 0 m 11 s.
# Epoch 25: training loss 7.316645555198193, eval loss 0.296993613243103. Time elapsed: 0 h 0 m 11 s.
# Epoch 26: training loss 7.277636803686619, eval loss 0.308839350938797. Time elapsed: 0 h 0 m 12 s.
# Epoch 27: training loss 6.195673234760761, eval loss 0.2890487313270569. Time elapsed: 0 h 0 m 12 s.
# Epoch 28: training loss 5.937493413686752, eval loss 0.2889854311943054. Time elapsed: 0 h 0 m 13 s.
# Epoch 29: training loss 5.957814604043961, eval loss 0.3005695641040802. Time elapsed: 0 h 0 m 13 s.
# Epoch 30: training loss 5.5945500284433365, eval loss 0.29948198795318604. Time elapsed: 0 h 0 m 14 s.
# Epoch 31: training loss 5.3491131365299225, eval loss 0.29740601778030396. Time elapsed: 0 h 0 m 14 s.
# Epoch 32: training loss 4.863706849515438, eval loss 0.28644418716430664. Time elapsed: 0 h 0 m 15 s.
# Epoch 33: training loss 4.669520683586597, eval loss 0.2841305434703827. Time elapsed: 0 h 0 m 15 s.
# Epoch 34: training loss 4.486977905035019, eval loss 0.31259745359420776. Time elapsed: 0 h 0 m 16 s.
# Epoch 35: training loss 4.353096641600132, eval loss 0.30399614572525024. Time elapsed: 0 h 0 m 16 s.
# Epoch 36: training loss 4.201913475990295, eval loss 0.29089152812957764. Time elapsed: 0 h 0 m 17 s.
# Epoch 37: training loss 4.17906404286623, eval loss 0.28875771164894104. Time elapsed: 0 h 0 m 17 s.
# Epoch 38: training loss 4.156281270086765, eval loss 0.3015369474887848. Time elapsed: 0 h 0 m 18 s.
# Epoch 39: training loss 3.99441596865654, eval loss 0.2961217761039734. Time elapsed: 0 h 0 m 18 s.
# Epoch 40: training loss 3.773432932794094, eval loss 0.3024115562438965. Time elapsed: 0 h 0 m 19 s.
# Epoch 41: training loss 3.68619092553854, eval loss 0.29834696650505066. Time elapsed: 0 h 0 m 19 s.
# Epoch 42: training loss 3.6164195612072945, eval loss 0.30066993832588196. Time elapsed: 0 h 0 m 20 s.
# Epoch 43: training loss 3.5898865200579166, eval loss 0.2981504201889038. Time elapsed: 0 h 0 m 20 s.
# Epoch 44: training loss 3.541018396615982, eval loss 0.29294875264167786. Time elapsed: 0 h 0 m 21 s.
# Epoch 45: training loss 3.4959190785884857, eval loss 0.2983381152153015. Time elapsed: 0 h 0 m 21 s.
# Epoch 46: training loss 3.4651752784848213, eval loss 0.2951822578907013. Time elapsed: 0 h 0 m 22 s.
# Epoch 47: training loss 3.460420984774828, eval loss 0.2965083122253418. Time elapsed: 0 h 0 m 22 s.
# Epoch 48: training loss 3.395513940602541, eval loss 0.2914491593837738. Time elapsed: 0 h 0 m 23 s.
# Epoch 49: training loss 3.4048061333596706, eval loss 0.29558834433555603. Time elapsed: 0 h 0 m 23 s.
# Epoch 50: training loss 3.511471539735794, eval loss 0.2906462848186493. Time elapsed: 0 h 0 m 24 s.
# Training completed with final epoch loss 3.511471539735794. Time elapsed: 0 h 0 m 24 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    pred_mean = DNN(X_train)
    
print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.2636, device='cuda:0', grad_fn=<MseLossBackward0>)
# Predicting mean MSE error on test set tensor(0.9281, device='cuda:0')
# /tmp/ipykernel_79743/4047130697.py:5: UserWarning: Using a target size (torch.Size([100, 16])) that is different to the input size (torch.Size([16])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0), Y_test))

# %% [markdown]
# ### Recurrent RNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_recur_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_recur_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_recur_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=20, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_layers=1, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')
# Out:
# Initial eval loss: 5.040354251861572
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_1284/609967341.py in <module>
#       8 criterion = nn.MSELoss()
#       9
# ---> 10 train_losses, eval_losses = train_rnn(
#      11     model=DNN,
#      12     train_loader=train_dataloader, test_loader=test_dataloader,
#
# ~/Documents/BrainNet/train.py in train_rnn(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#     104         for i, (X, Y) in enumerate(iter(train_loader)): # X: [batch_size, time_step, input_dim]
#     105
# --> 106             Y_hat, rec_prev = model(X, rec_prev)
#     107             loss = criterion(Y_hat, Y)
#     108
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/BrainNet/models.py in forward(self, x, rec_prev)
#      56         x = self.transfer_function(x)
#      57
# ---> 58         x = self.hidden1(x)
#      59         x = self.transfer_function(x)
#      60
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# %debug
# Out:
# > /home/daniel/.local/lib/python3.9/site-packages/torch/nn/modules/rnn.py(747)forward()
#     745                         msg = ("For batched 3-D input, hx and cx should "
#     746                                f"also be 3-D but got ({hx[0].dim()}-D, {hx[1].dim()}-D) tensors")
# --> 747                         raise RuntimeError(msg)
#     748                 else:
#     749                     if hx[0].dim() != 2 or hx[1].dim() != 2:
# ipdb>  c_prev
# *** NameError: name 'c_prev' is not defined

# %% [markdown]
# # Experiments

# %%
import torch
import torch.nn as nn
import numpy as np
from models import *
from utils import *
from torch.utils.data import DataLoader

seed = 123
torch.manual_seed(seed)
np.random.seed(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Approximate BNN

# %%
# load data generated from approximate BNN
X_train, Y_train = load_data('./data/', 'train_abnn_16_256_0.5_4_16_0.5_10000.pkl')
X_test, Y_test = load_data('./data/', 'test_abnn_16_256_0.5_4_16_0.5_1000.pkl')

batch_size = 50    # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 25      # number of training epochs

# %% [markdown]
# ###  1. Learning with random parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=128, n_layers=2, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()    

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 0.04123974544927478
# Epoch 1: training loss 0.08118536151596345, eval loss 0.007392620173050091. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 0.07366527325939387, eval loss 0.007353611581493169. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 0.07346577159478329, eval loss 0.007343280623899773. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 0.07340743660461158, eval loss 0.007339688658248633. Time elapsed: 0 h 0 m 1 s.
# Epoch 5: training loss 0.07338614790933207, eval loss 0.007338257448282093. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 0.07337584553170018, eval loss 0.007337614806601778. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 0.07337087861378677, eval loss 0.007337239134358242. Time elapsed: 0 h 0 m 2 s.
# Epoch 8: training loss 0.073368478420889, eval loss 0.007337006478337571. Time elapsed: 0 h 0 m 2 s.
# Epoch 9: training loss 0.07336706120986491, eval loss 0.007337108458159491. Time elapsed: 0 h 0 m 2 s.
# Epoch 10: training loss 0.0733667004678864, eval loss 0.007336896669585258. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 0.0733658138778992, eval loss 0.007337037561228499. Time elapsed: 0 h 0 m 3 s.
# Epoch 12: training loss 0.07336556861991994, eval loss 0.007336901355301961. Time elapsed: 0 h 0 m 3 s.
# Epoch 13: training loss 0.07336574338842183, eval loss 0.0073367535951547325. Time elapsed: 0 h 0 m 3 s.
# Epoch 14: training loss 0.0733656735974364, eval loss 0.007336664479225874. Time elapsed: 0 h 0 m 3 s.
# Epoch 15: training loss 0.07336515866336413, eval loss 0.007336613925872371. Time elapsed: 0 h 0 m 4 s.
# Epoch 16: training loss 0.07336446305271238, eval loss 0.007336713111726567. Time elapsed: 0 h 0 m 4 s.
# Epoch 17: training loss 0.07336403633235022, eval loss 0.0073372220795135945. Time elapsed: 0 h 0 m 4 s.
# Epoch 18: training loss 0.07336413409211673, eval loss 0.007337496354011819. Time elapsed: 0 h 0 m 5 s.
# Epoch 19: training loss 0.07336397701874375, eval loss 0.007337565300986171. Time elapsed: 0 h 0 m 5 s.
# Epoch 20: training loss 0.07336378749459982, eval loss 0.007337458431720734. Time elapsed: 0 h 0 m 5 s.
# Epoch 21: training loss 0.07336365155060776, eval loss 0.007337250804994255. Time elapsed: 0 h 0 m 5 s.
# Epoch 22: training loss 0.07336327005759813, eval loss 0.007337199174799025. Time elapsed: 0 h 0 m 6 s.
# Epoch 23: training loss 0.07336293303524144, eval loss 0.007337173825362697. Time elapsed: 0 h 0 m 6 s.
# Epoch 24: training loss 0.07336263623437844, eval loss 0.00733715362730436. Time elapsed: 0 h 0 m 6 s.
# Epoch 25: training loss 0.07336235378170386, eval loss 0.007337137620197609. Time elapsed: 0 h 0 m 7 s.
# Training completed with final epoch loss 0.07336235378170386. Time elapsed: 0 h 0 m 7 s.

# %% [markdown]
# ### 2. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
def param_grid_search(hidden_dims, n_layerss):
    final_eval_loss = np.zeros((len(hidden_dims), len(n_layerss)))

    for i, hidden_dim in enumerate(hidden_dims):
        for j, n_layers in enumerate(n_layerss):

            # deep learning model
            DNN = FeedForwardDNN(input_dim=16, hidden_dim=hidden_dim, n_layers=n_layers, output_dim=16).to(device)

            # training parameters
            optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
            criterion = nn.MSELoss()    

            train_losses, eval_losses = train(
                model=DNN,
                train_loader=train_dataloader, test_loader=test_dataloader,
                optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
                verbose=False, force_stop=False)

            print(f'{n_layers} layers, {hidden_dim} hidden units, final eval loss: {eval_losses[-1]}', end='\r')
            final_eval_loss[i,j] = eval_losses[-1]
    
    return final_eval_loss

def repeated_param_grid_search(hidden_dims, n_layerss, n_repeats):
    
    final_eval_loss_matrix = np.zeros((len(hidden_dims), len(n_layerss)))
    for i in range(n_repeats):
        final_eval_loss = param_grid_search(hidden_dims, n_layerss)
        final_eval_loss_matrix += final_eval_loss
    
    return final_eval_loss_matrix / n_repeats

# %%
repeated_param_grid_search(
    hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256],
    n_layerss=[1, 2, 3, 4, 5, 6, 7, 8],
    n_repeats=50)
# Out:
# 5 layers, 2 hidden units, final eval loss: 0.006580831715837121
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_984/186915004.py in <module>
# ----> 1 repeated_param_grid_search(
#       2     hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256],
#       3     n_layerss=[1, 2, 3, 4, 5, 6, 7, 8],
#       4     n_repeats=50)
#
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_984/3275547320.py in repeated_param_grid_search(hidden_dims, n_layerss, n_repeats)
#      27     final_eval_loss_matrix = np.zeros((len(hidden_dims), len(n_layerss)))
#      28     for _ in range(n_repeats):
# ---> 29         final_eval_loss = param_grid_search(hidden_dims, n_layerss)
#      30         final_eval_loss_matrix += final_eval_loss
#      31
#
# /var/folders/2b/t0zm4sh96cqbt0s1pdb4mwg80000gn/T/ipykernel_984/3275547320.py in param_grid_search(hidden_dims, n_layerss)
#      12             criterion = nn.MSELoss()
#      13
# ---> 14             train_losses, eval_losses = train(
#      15                 model=DNN,
#      16                 train_loader=train_dataloader, test_loader=test_dataloader,
#
# ~/Documents/BrainNet/utils.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#     124             optimiser.zero_grad()
#     125             loss.backward()
# --> 126             optimiser.step()
#     127
#     128             epoch_loss += loss.item()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/optim/adam.py in step(self, closure)
#     139                     state_steps.append(state['step'])
#     140
# --> 141             F.adam(params_with_grad,
#     142                    grads,
#     143                    exp_avgs,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#      96         # Decay the first and second moment running average coefficient
#      97         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 98         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#      99         if amsgrad:
#     100             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

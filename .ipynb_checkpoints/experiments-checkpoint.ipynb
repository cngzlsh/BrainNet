# %% [markdown]
# # Experiments

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import numpy as np
import time
import seaborn as sns

from models import *
from utils import *
from train import *
from bvc import *

sns.set(font_scale=1.2)
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Approximate BNNs
# ### Feedforward BNN

# %%
X_train, Y_train = load_data('./data/', 'ff_train_abnn_256_0.5_4_5.pkl')
X_test, Y_test = load_data('./data/', 'ff_test_abnn_256_0.5_4_5.pkl')
X_valid, Y_valid = load_data('./data/', 'ff_valid_abnn_256_0.5_4_5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30,
    **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.41823095083236694, time elapsed: 0 h 2 m 44 s
# 2th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4276036322116852, time elapsed: 0 h 5 m 33 s
# 3th repeat: best hidden unit: 256, best layers: 2, final eval loss: 0.42645274102687836, time elapsed: 0 h 8 m 21 s
# 4th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.4382685124874115, time elapsed: 0 h 11 m 9 s
# 5th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4215661883354187, time elapsed: 0 h 13 m 57 s
# 6th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.4378806874155998, time elapsed: 0 h 16 m 44 s
# 7th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.42620816826820374, time elapsed: 0 h 19 m 34 s
# 8th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4268849417567253, time elapsed: 0 h 22 m 22 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.42778123915195465, time elapsed: 0 h 25 m 10 s
# 10th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4227156713604927, time elapsed: 0 h 27 m 57 s
# 11th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.42316485196352005, time elapsed: 0 h 30 m 46 s
# 12th repeat: best hidden unit: 256, best layers: 2, final eval loss: 0.4192281737923622, time elapsed: 0 h 33 m 35 s
# 13th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.42575013637542725, time elapsed: 0 h 36 m 24 s
# 14th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.4250783994793892, time elapsed: 0 h 39 m 14 s
# 15th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.44083085656166077, time elapsed: 0 h 42 m 4 s
# 16th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4309961497783661, time elapsed: 0 h 44 m 52 s
# 17th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.42364051938056946, time elapsed: 0 h 47 m 43 s
# 18th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4423111379146576, time elapsed: 0 h 50 m 31 s
# 19th repeat: best hidden unit: 256, best layers: 2, final eval loss: 0.427063524723053, time elapsed: 0 h 53 m 22 s
# 20th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.4296455830335617, time elapsed: 0 h 56 m 11 s
# 21th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.42249850928783417, time elapsed: 0 h 59 m 0 s
# 22th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4187697619199753, time elapsed: 1 h 1 m 52 s
# 23th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4215283542871475, time elapsed: 1 h 4 m 40 s
# 24th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4238482415676117, time elapsed: 1 h 7 m 29 s
# 25th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.4326871335506439, time elapsed: 1 h 10 m 20 s
# 26th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.4266863241791725, time elapsed: 1 h 13 m 10 s
# 27th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.4368010610342026, time elapsed: 1 h 16 m 0 s
# 28th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.41956014931201935, time elapsed: 1 h 18 m 49 s
# 29th repeat: best hidden unit: 256, best layers: 2, final eval loss: 0.43347498029470444, time elapsed: 1 h 21 m 37 s
# 30th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.4153645560145378, time elapsed: 1 h 24 m 29 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=np.log(avg_final_eval_loss),
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='param_search_log_ff')
# Out:
# Best hidden unit: 256, best layers: 4

# %% [markdown]
# ####  2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=4, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 5.023743808269501
# Epoch 1: training loss 27.44285362958908, eval loss 1.7013375759124756. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 16.022566825151443, eval loss 1.330637127161026. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 13.086907431483269, eval loss 1.1356037259101868. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 10.580090165138245, eval loss 0.977423682808876. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 8.825427770614624, eval loss 0.758546769618988. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 7.604596063494682, eval loss 1.0028192400932312. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 6.778873577713966, eval loss 0.6104001849889755. Time elapsed: 0 h 0 m 0 s.
# Epoch 8: training loss 5.989201202988625, eval loss 0.6066014096140862. Time elapsed: 0 h 0 m 0 s.
# Epoch 9: training loss 5.480251178145409, eval loss 0.5094501748681068. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 4.949532680213451, eval loss 0.4988596811890602. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 4.720620647072792, eval loss 0.5006789565086365. Time elapsed: 0 h 0 m 1 s.
# Epoch 12: training loss 4.619416914880276, eval loss 0.479617103934288. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 4.342245936393738, eval loss 0.4407120645046234. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 4.112297363579273, eval loss 0.4158991053700447. Time elapsed: 0 h 0 m 1 s.
# Epoch 15: training loss 3.8145786970853806, eval loss 0.4144473597407341. Time elapsed: 0 h 0 m 1 s.
# Epoch 16: training loss 4.003295086324215, eval loss 0.46655919402837753. Time elapsed: 0 h 0 m 1 s.
# Epoch 17: training loss 3.7213794738054276, eval loss 0.39427413791418076. Time elapsed: 0 h 0 m 2 s.
# Epoch 18: training loss 3.446361683309078, eval loss 0.382828451693058. Time elapsed: 0 h 0 m 2 s.
# Epoch 19: training loss 3.5503147803246975, eval loss 0.43077999353408813. Time elapsed: 0 h 0 m 2 s.
# Epoch 20: training loss 3.3188310340046883, eval loss 0.4002635106444359. Time elapsed: 0 h 0 m 2 s.
# Epoch 21: training loss 3.316433761268854, eval loss 0.39010998606681824. Time elapsed: 0 h 0 m 2 s.
# Epoch 22: training loss 3.2409552931785583, eval loss 0.3652321621775627. Time elapsed: 0 h 0 m 2 s.
# Epoch 23: training loss 3.1064167581498623, eval loss 0.37158700078725815. Time elapsed: 0 h 0 m 2 s.
# Epoch 24: training loss 3.0965208895504475, eval loss 0.3673066943883896. Time elapsed: 0 h 0 m 2 s.
# Epoch 25: training loss 3.0116024762392044, eval loss 0.3901524245738983. Time elapsed: 0 h 0 m 2 s.
# Epoch 26: training loss 3.0455431938171387, eval loss 0.3573717698454857. Time elapsed: 0 h 0 m 3 s.
# Epoch 27: training loss 2.878888711333275, eval loss 0.34667688608169556. Time elapsed: 0 h 0 m 3 s.
# Epoch 28: training loss 2.8590217158198357, eval loss 0.3553989380598068. Time elapsed: 0 h 0 m 3 s.
# Epoch 29: training loss 2.7824409678578377, eval loss 0.34773313999176025. Time elapsed: 0 h 0 m 3 s.
# Epoch 30: training loss 2.807107262313366, eval loss 0.34628790616989136. Time elapsed: 0 h 0 m 3 s.
# Epoch 31: training loss 2.722190532833338, eval loss 0.35461823642253876. Time elapsed: 0 h 0 m 3 s.
# Epoch 32: training loss 2.7678618878126144, eval loss 0.35173916071653366. Time elapsed: 0 h 0 m 3 s.
# Epoch 33: training loss 2.5833685882389545, eval loss 0.3858509510755539. Time elapsed: 0 h 0 m 3 s.
# Epoch 34: training loss 2.608261078596115, eval loss 0.33179638534784317. Time elapsed: 0 h 0 m 4 s.
# Epoch 35: training loss 2.5101514644920826, eval loss 0.3397291302680969. Time elapsed: 0 h 0 m 4 s.
# Epoch 36: training loss 2.510420549660921, eval loss 0.3264835849404335. Time elapsed: 0 h 0 m 4 s.
# Epoch 37: training loss 2.499566726386547, eval loss 0.33031313493847847. Time elapsed: 0 h 0 m 4 s.
# Epoch 38: training loss 2.439197711646557, eval loss 0.3286695368587971. Time elapsed: 0 h 0 m 4 s.
# Epoch 39: training loss 2.611481435596943, eval loss 0.3382691815495491. Time elapsed: 0 h 0 m 4 s.
# Epoch 40: training loss 2.3114863857626915, eval loss 0.31738612800836563. Time elapsed: 0 h 0 m 4 s.
# Epoch 41: training loss 2.4231548197567463, eval loss 0.34062106907367706. Time elapsed: 0 h 0 m 4 s.
# Epoch 42: training loss 2.3501762077212334, eval loss 0.3380594104528427. Time elapsed: 0 h 0 m 4 s.
# Epoch 43: training loss 2.2627244405448437, eval loss 0.31019459292292595. Time elapsed: 0 h 0 m 5 s.
# Epoch 44: training loss 2.230944339185953, eval loss 0.33270278573036194. Time elapsed: 0 h 0 m 5 s.
# Epoch 45: training loss 2.277853276580572, eval loss 0.33029238134622574. Time elapsed: 0 h 0 m 5 s.
# Epoch 46: training loss 2.1975757963955402, eval loss 0.31305815279483795. Time elapsed: 0 h 0 m 5 s.
# Epoch 47: training loss 2.234551604837179, eval loss 0.31640203669667244. Time elapsed: 0 h 0 m 5 s.
# Epoch 48: training loss 2.295691180974245, eval loss 0.30949198827147484. Time elapsed: 0 h 0 m 5 s.
# Epoch 49: training loss 2.1402294412255287, eval loss 0.3250586986541748. Time elapsed: 0 h 0 m 5 s.
# Epoch 50: training loss 2.148122526705265, eval loss 0.3221140094101429. Time elapsed: 0 h 0 m 5 s.
# Training completed with final epoch loss 2.148122526705265. Time elapsed: 0 h 0 m 5 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad(): 
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.0644, device='cuda:0')
# Predicting mean MSE error on test set tensor(0.9990, device='cuda:0')

# %% [markdown]
# ### Residual BNN

# %%
X_train, Y_train = load_data('./data/', 'resid_train_abnn_256_0.5_4_5.pkl')
X_test, Y_test = load_data('./data/', 'resid_test_abnn_256_0.5_4_5.pkl')
X_valid, Y_valid = load_data('./data/', 'resid_valid_abnn_256_0.5_4_5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### 1. Parameter grid search: number of layers vs number of hidden units
#
# Repeat 50 times to obtain the main final evaluation loss for each parameter set.

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1331539452075958, time elapsed: 0 h 2 m 32 s
# 2th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.0759582370519638, time elapsed: 0 h 5 m 16 s
# 3th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.112314149737358, time elapsed: 0 h 8 m 0 s
# 4th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1214865893125534, time elapsed: 0 h 10 m 45 s
# 5th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.1162987053394318, time elapsed: 0 h 13 m 32 s
# 6th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1327287256717682, time elapsed: 0 h 16 m 18 s
# 7th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.0945728570222855, time elapsed: 0 h 19 m 5 s
# 8th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.103964164853096, time elapsed: 0 h 21 m 52 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.0942693501710892, time elapsed: 0 h 24 m 42 s
# 10th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1489256620407104, time elapsed: 0 h 27 m 33 s
# 11th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1126219779253006, time elapsed: 0 h 30 m 19 s
# 12th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.113884225487709, time elapsed: 0 h 33 m 6 s
# 13th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.0847383588552475, time elapsed: 0 h 35 m 53 s
# 14th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1022713333368301, time elapsed: 0 h 38 m 40 s
# 15th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.1022372543811798, time elapsed: 0 h 41 m 29 s
# 16th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.1031084656715393, time elapsed: 0 h 44 m 19 s
# 17th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.1092983484268188, time elapsed: 0 h 47 m 11 s
# 18th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.152875378727913, time elapsed: 0 h 50 m 2 s
# 19th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1413667500019073, time elapsed: 0 h 52 m 59 s
# 20th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.0778251588344574, time elapsed: 0 h 55 m 48 s
# 21th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.1100314259529114, time elapsed: 0 h 58 m 36 s
# 22th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1374418884515762, time elapsed: 1 h 1 m 25 s
# 23th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1183994561433792, time elapsed: 1 h 4 m 15 s
# 24th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1208090633153915, time elapsed: 1 h 7 m 4 s
# 25th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.1372906267642975, time elapsed: 1 h 9 m 50 s
# 26th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.10824553668499, time elapsed: 1 h 12 m 35 s
# 27th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1242356151342392, time elapsed: 1 h 15 m 24 s
# 28th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.100138783454895, time elapsed: 1 h 18 m 11 s
# 29th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.0669836103916168, time elapsed: 1 h 20 m 59 s
# 30th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.148037314414978, time elapsed: 1 h 23 m 48 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='param_search_resid')
# Out:
# Best hidden unit: 256, best layers: 3

# %% [markdown]
# #### 2. Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(Y_test[v_idx,:], DNN(X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 3.7936206459999084
# Epoch 1: training loss 27.696831166744232, eval loss 1.9891024231910706. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 20.986399576067924, eval loss 1.6429495811462402. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 18.254225999116898, eval loss 1.4708519876003265. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 16.944531708955765, eval loss 1.368052288889885. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 15.766708105802536, eval loss 1.308748036623001. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 14.779866352677345, eval loss 1.2279099822044373. Time elapsed: 0 h 0 m 0 s.
# Epoch 7: training loss 13.998306468129158, eval loss 1.297394335269928. Time elapsed: 0 h 0 m 0 s.
# Epoch 8: training loss 13.4624582529068, eval loss 1.1707604378461838. Time elapsed: 0 h 0 m 0 s.
# Epoch 9: training loss 12.327529162168503, eval loss 1.1655480861663818. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 11.437696233391762, eval loss 1.141964003443718. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 10.565865747630596, eval loss 1.0998045653104782. Time elapsed: 0 h 0 m 1 s.
# Epoch 12: training loss 10.080179072916508, eval loss 1.160795509815216. Time elapsed: 0 h 0 m 1 s.
# Epoch 13: training loss 9.833769954741001, eval loss 1.0837687999010086. Time elapsed: 0 h 0 m 1 s.
# Epoch 14: training loss 9.593517310917377, eval loss 1.0719167739152908. Time elapsed: 0 h 0 m 1 s.
# Epoch 15: training loss 8.934404164552689, eval loss 1.0967152118682861. Time elapsed: 0 h 0 m 1 s.
# Epoch 16: training loss 8.75124692171812, eval loss 1.1189972758293152. Time elapsed: 0 h 0 m 1 s.
# Epoch 17: training loss 8.29235840588808, eval loss 1.1130034625530243. Time elapsed: 0 h 0 m 1 s.
# Epoch 18: training loss 7.977417945861816, eval loss 1.1627761721611023. Time elapsed: 0 h 0 m 2 s.
# Epoch 19: training loss 9.031409054994583, eval loss 1.0505932122468948. Time elapsed: 0 h 0 m 2 s.
# Epoch 20: training loss 7.000914081931114, eval loss 1.0988346338272095. Time elapsed: 0 h 0 m 2 s.
# Epoch 21: training loss 6.1570272371172905, eval loss 1.0026413798332214. Time elapsed: 0 h 0 m 2 s.
# Epoch 22: training loss 5.299240753054619, eval loss 1.0421169698238373. Time elapsed: 0 h 0 m 2 s.
# Epoch 23: training loss 4.822901912033558, eval loss 1.0282921344041824. Time elapsed: 0 h 0 m 2 s.
# Epoch 24: training loss 4.7265360429883, eval loss 1.010619968175888. Time elapsed: 0 h 0 m 2 s.
# Epoch 25: training loss 4.991549864411354, eval loss 1.0611508637666702. Time elapsed: 0 h 0 m 2 s.
# Epoch 26: training loss 5.018103733658791, eval loss 1.0753621757030487. Time elapsed: 0 h 0 m 2 s.
# Epoch 27: training loss 4.768848218023777, eval loss 0.9962839037179947. Time elapsed: 0 h 0 m 2 s.
# Epoch 28: training loss 3.964054848998785, eval loss 0.9732363969087601. Time elapsed: 0 h 0 m 3 s.
# Epoch 29: training loss 3.7830581292510033, eval loss 0.9703345373272896. Time elapsed: 0 h 0 m 3 s.
# Epoch 30: training loss 5.941881999373436, eval loss 1.0364270210266113. Time elapsed: 0 h 0 m 3 s.
# Epoch 31: training loss 3.745376717299223, eval loss 0.9645662680268288. Time elapsed: 0 h 0 m 3 s.
# Epoch 32: training loss 3.5072659254074097, eval loss 0.9831274077296257. Time elapsed: 0 h 0 m 3 s.
# Epoch 33: training loss 3.944399170577526, eval loss 0.9898082166910172. Time elapsed: 0 h 0 m 3 s.
# Epoch 34: training loss 6.121353793889284, eval loss 1.1749675124883652. Time elapsed: 0 h 0 m 3 s.
# Epoch 35: training loss 4.4050904512405396, eval loss 1.0195719003677368. Time elapsed: 0 h 0 m 3 s.
# Epoch 36: training loss 3.377155836671591, eval loss 0.992577001452446. Time elapsed: 0 h 0 m 3 s.
# Epoch 37: training loss 4.646277949213982, eval loss 0.9779550135135651. Time elapsed: 0 h 0 m 3 s.
# Epoch 38: training loss 3.1703360192477703, eval loss 0.9946747720241547. Time elapsed: 0 h 0 m 4 s.
# Epoch 39: training loss 3.4081185311079025, eval loss 0.9937271475791931. Time elapsed: 0 h 0 m 4 s.
# Epoch 40: training loss 2.925889752805233, eval loss 0.9716870784759521. Time elapsed: 0 h 0 m 4 s.
# Epoch 41: training loss 3.430624548345804, eval loss 1.0581601560115814. Time elapsed: 0 h 0 m 4 s.
# Epoch 42: training loss 3.4922655262053013, eval loss 1.0111377090215683. Time elapsed: 0 h 0 m 4 s.
# Epoch 43: training loss 4.801342092454433, eval loss 1.0185063779354095. Time elapsed: 0 h 0 m 4 s.
# Epoch 44: training loss 3.6992458924651146, eval loss 0.973801389336586. Time elapsed: 0 h 0 m 4 s.
# Epoch 45: training loss 5.538077916949987, eval loss 1.123713493347168. Time elapsed: 0 h 0 m 4 s.
# Epoch 46: training loss 3.456326834857464, eval loss 0.9525293260812759. Time elapsed: 0 h 0 m 5 s.
# Epoch 47: training loss 2.588192116469145, eval loss 0.9273217022418976. Time elapsed: 0 h 0 m 5 s.
# Epoch 48: training loss 2.394791979342699, eval loss 0.9301365241408348. Time elapsed: 0 h 0 m 5 s.
# Epoch 49: training loss 2.3828950114548206, eval loss 0.9442168623209. Time elapsed: 0 h 0 m 5 s.
# Epoch 50: training loss 2.211600210517645, eval loss 0.9282171577215195. Time elapsed: 0 h 0 m 5 s.
# Training completed with final epoch loss 2.211600210517645. Time elapsed: 0 h 0 m 5 s.

# %% [markdown]
# #### 3. Testing against predicting the mean

# %%
with torch.no_grad():
    print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(X_test), Y_test))
    print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat(1000,1), Y_test))
# Out:
# DNN prediction MSE error on test set:  tensor(0.1856, device='cuda:0')
# Predicting mean MSE error on test set tensor(0.7493, device='cuda:0')

# %% [markdown]
# ### Recurrent BNN

# %%
X_train, Y_train = load_data('./data/', 'recur_train_abnn_256_0.5_4_2.pkl')
X_test, Y_test = load_data('./data/', 'recur_test_abnn_256_0.5_4_2.pkl')
X_valid, Y_valid = load_data('./data/', 'recur_valid_abnn_256_0.5_4_2.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
_X_train = X_train.view(-1, 16)
_Y_train = Y_train.view(-1, 16)
_X_test = X_test.view(-1, 16)
_Y_test = Y_test.view(-1, 16)

_train_dataset = BNN_Dataset(_X_train, _Y_train)
_train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

_test_dataset = BNN_Dataset(_X_test, _Y_test)
_test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6622260808944702, time elapsed: 0 h 3 m 35 s
# 2th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6862332224845886, time elapsed: 0 h 6 m 47 s
# 3th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6799342185258865, time elapsed: 0 h 9 m 52 s
# 4th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.6717042624950409, time elapsed: 0 h 12 m 58 s
# 5th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6997532099485397, time elapsed: 0 h 16 m 6 s
# 6th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6710559949278831, time elapsed: 0 h 19 m 13 s
# 7th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6976431459188461, time elapsed: 0 h 22 m 19 s
# 8th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6765982732176781, time elapsed: 0 h 25 m 25 s
# 9th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6754309311509132, time elapsed: 0 h 28 m 30 s
# 10th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6773463189601898, time elapsed: 0 h 31 m 36 s
# 11th repeat: best hidden unit: 256, best layers: 6, final eval loss: 0.6727663353085518, time elapsed: 0 h 34 m 43 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6739119291305542, time elapsed: 0 h 37 m 51 s
# 13th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6609156876802444, time elapsed: 0 h 40 m 58 s
# 14th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6826591119170189, time elapsed: 0 h 44 m 5 s
# 15th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6770859733223915, time elapsed: 0 h 47 m 13 s
# 16th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6876308470964432, time elapsed: 0 h 50 m 19 s
# 17th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6652536541223526, time elapsed: 0 h 53 m 25 s
# 18th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.673003762960434, time elapsed: 0 h 56 m 30 s
# 19th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6634465754032135, time elapsed: 0 h 59 m 37 s
# 20th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6877870857715607, time elapsed: 1 h 2 m 44 s
# 21th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6617150977253914, time elapsed: 1 h 6 m 29 s
# 22th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6903662979602814, time elapsed: 1 h 12 m 19 s
# 23th repeat: best hidden unit: 256, best layers: 4, final eval loss: 0.6699162647128105, time elapsed: 1 h 18 m 10 s
# 24th repeat: best hidden unit: 256, best layers: 3, final eval loss: 0.6811288669705391, time elapsed: 1 h 24 m 0 s
# 25th repeat: best hidden unit: 256, best layers: 5, final eval loss: 0.6810770481824875, time elapsed: 1 h 29 m 50 s
# 5 layers, 8 hidden units, final eval loss: 3.4184398651123047
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4636/3407263236.py in <module>
#       2 n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]
#       3
# ----> 4 avg_final_eval_loss = repeated_param_grid_search(
#       5     hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in repeated_param_grid_search(hidden_dims, n_layerss, n_repeats, **kwargs)
#     226     for i in range(n_repeats):
#     227
# --> 228         final_eval_loss = param_grid_search(hidden_dims, n_layerss, **kwargs)
#     229         final_eval_loss_matrix += final_eval_loss
#     230
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in param_grid_search(hidden_dims, n_layerss, **kwargs)
#     190                 criterion = nn.MSELoss()
#     191
# --> 192                 train_losses, eval_losses = train(
#     193                     model=DNN,
#     194                     train_loader=valid_loader, test_loader=test_loader,
#
# ~/Documents/MSc_ML_UCL/Project/BrainNet/train.py in train(model, train_loader, test_loader, optimiser, criterion, num_epochs, verbose, force_stop)
#      38             optimiser.step()
#      39
# ---> 40             epoch_loss += loss.item()
#      41
#      42             if force_stop and i == 20:
#
# KeyboardInterrupt:

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='param_search_recur_mlp')

# %% [markdown]
# ##### b) Learning with best parameter

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = FeedForwardDNN(input_dim=16, hidden_dim=256, n_layers=3, output_dim=16).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()
visualise_prediction(_Y_test[v_idx,:], DNN(_X_test[v_idx,:]))

train_losses, eval_losses = train(
    model=DNN,
    train_loader=_train_dataloader, test_loader=_test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

visualise_prediction(_Y_test[v_idx,:], DNN(_X_test[v_idx,:])) # visualise after training
# Out:
# Initial eval loss: 4.104119718074799
# Epoch 1: training loss 25.31748676300049, eval loss 1.8728303909301758. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 16.29193902015686, eval loss 1.4147752225399017. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 13.025853410363197, eval loss 1.2081980407238007. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 11.39355418086052, eval loss 1.1075210720300674. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 10.291381299495697, eval loss 1.023419350385666. Time elapsed: 0 h 0 m 0 s.
# Epoch 6: training loss 9.542202949523926, eval loss 0.9413210153579712. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 9.101683303713799, eval loss 0.8849138468503952. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 8.383697777986526, eval loss 0.8414915055036545. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 8.03074362874031, eval loss 0.8016484379768372. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 7.894235342741013, eval loss 0.8040937632322311. Time elapsed: 0 h 0 m 1 s.
# Epoch 11: training loss 7.488520994782448, eval loss 0.7860187292098999. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 7.321737110614777, eval loss 0.7393293976783752. Time elapsed: 0 h 0 m 2 s.
# Epoch 13: training loss 7.152475446462631, eval loss 0.7470827847719193. Time elapsed: 0 h 0 m 2 s.
# Epoch 14: training loss 6.9877554178237915, eval loss 0.7246219515800476. Time elapsed: 0 h 0 m 2 s.
# Epoch 15: training loss 6.765748970210552, eval loss 0.7095179110765457. Time elapsed: 0 h 0 m 2 s.
# Epoch 16: training loss 6.626949995756149, eval loss 0.6970229372382164. Time elapsed: 0 h 0 m 3 s.
# Epoch 17: training loss 6.485526069998741, eval loss 0.6918718665838242. Time elapsed: 0 h 0 m 3 s.
# Epoch 18: training loss 6.372971549630165, eval loss 0.6895584985613823. Time elapsed: 0 h 0 m 3 s.
# Epoch 19: training loss 6.291952781379223, eval loss 0.6802608072757721. Time elapsed: 0 h 0 m 3 s.
# Epoch 20: training loss 6.177914649248123, eval loss 0.6641370803117752. Time elapsed: 0 h 0 m 3 s.
# Epoch 21: training loss 6.051630176603794, eval loss 0.6558839529752731. Time elapsed: 0 h 0 m 4 s.
# Epoch 22: training loss 5.969863831996918, eval loss 0.6497868448495865. Time elapsed: 0 h 0 m 4 s.
# Epoch 23: training loss 5.906062811613083, eval loss 0.6450177952647209. Time elapsed: 0 h 0 m 4 s.
# Epoch 24: training loss 5.816556207835674, eval loss 0.6412211805582047. Time elapsed: 0 h 0 m 4 s.
# Epoch 25: training loss 5.744570158421993, eval loss 0.6353849992156029. Time elapsed: 0 h 0 m 4 s.
# Epoch 26: training loss 5.6712290570139885, eval loss 0.6315060555934906. Time elapsed: 0 h 0 m 5 s.
# Epoch 27: training loss 5.599722281098366, eval loss 0.6248130276799202. Time elapsed: 0 h 0 m 5 s.
# Epoch 28: training loss 5.531737431883812, eval loss 0.6198545172810555. Time elapsed: 0 h 0 m 5 s.
# Epoch 29: training loss 5.478620558977127, eval loss 0.6169292256236076. Time elapsed: 0 h 0 m 5 s.
# Epoch 30: training loss 5.408554561436176, eval loss 0.6129350736737251. Time elapsed: 0 h 0 m 5 s.
# Epoch 31: training loss 5.357330493628979, eval loss 0.6093010231852531. Time elapsed: 0 h 0 m 5 s.
# Epoch 32: training loss 5.325727790594101, eval loss 0.6071667447686195. Time elapsed: 0 h 0 m 6 s.
# Epoch 33: training loss 5.281843692064285, eval loss 0.6056679114699364. Time elapsed: 0 h 0 m 6 s.
# Epoch 34: training loss 5.2086301147937775, eval loss 0.6079352274537086. Time elapsed: 0 h 0 m 6 s.
# Epoch 35: training loss 5.160015545785427, eval loss 0.6025294959545135. Time elapsed: 0 h 0 m 6 s.
# Epoch 36: training loss 5.1174656972289085, eval loss 0.6003498435020447. Time elapsed: 0 h 0 m 6 s.
# Epoch 37: training loss 5.066289097070694, eval loss 0.6006654500961304. Time elapsed: 0 h 0 m 7 s.
# Epoch 38: training loss 5.026654973626137, eval loss 0.5977354124188423. Time elapsed: 0 h 0 m 7 s.
# Epoch 39: training loss 4.978895537555218, eval loss 0.5977141559123993. Time elapsed: 0 h 0 m 7 s.
# Epoch 40: training loss 4.936568185687065, eval loss 0.5981206223368645. Time elapsed: 0 h 0 m 7 s.
# Epoch 41: training loss 4.901833184063435, eval loss 0.593568429350853. Time elapsed: 0 h 0 m 7 s.
# Epoch 42: training loss 4.862831696867943, eval loss 0.5938529297709465. Time elapsed: 0 h 0 m 7 s.
# Epoch 43: training loss 4.823411576449871, eval loss 0.5881334319710732. Time elapsed: 0 h 0 m 8 s.
# Epoch 44: training loss 4.78622292727232, eval loss 0.584107294678688. Time elapsed: 0 h 0 m 8 s.
# Epoch 45: training loss 4.739384986460209, eval loss 0.579948253929615. Time elapsed: 0 h 0 m 8 s.
# Epoch 46: training loss 4.686951324343681, eval loss 0.5773307979106903. Time elapsed: 0 h 0 m 8 s.
# Epoch 47: training loss 4.638470709323883, eval loss 0.5739219263195992. Time elapsed: 0 h 0 m 8 s.
# Epoch 48: training loss 4.590354382991791, eval loss 0.5680311545729637. Time elapsed: 0 h 0 m 9 s.
# Epoch 49: training loss 4.5443475395441055, eval loss 0.5695597603917122. Time elapsed: 0 h 0 m 9 s.
# Epoch 50: training loss 4.530032806098461, eval loss 0.5671187862753868. Time elapsed: 0 h 0 m 9 s.
# Training completed with final epoch loss 4.530032806098461. Time elapsed: 0 h 0 m 9 s.

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(DNN(_X_test), _Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(_Y_test, dim=0).repeat([50000,1]), _Y_test))

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})
# Out:
# Training on:  NVIDIA GeForce RTX 3070 Laptop GPU
# 1th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1775511652231216, time elapsed: 0 h 3 m 14 s
# 2th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1685474514961243, time elapsed: 0 h 6 m 33 s
# 3th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1775284111499786, time elapsed: 0 h 10 m 6 s
# 4th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.1772110909223557, time elapsed: 0 h 13 m 38 s
# 5th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.1891040056943893, time elapsed: 0 h 17 m 11 s
# 6th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.182258516550064, time elapsed: 0 h 20 m 44 s
# 7th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.1878353208303452, time elapsed: 0 h 24 m 20 s
# 8th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.1775005161762238, time elapsed: 0 h 27 m 55 s
# 9th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.168931096792221, time elapsed: 0 h 31 m 34 s
# 10th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.166264846920967, time elapsed: 0 h 35 m 6 s
# 11th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1504797339439392, time elapsed: 0 h 38 m 40 s
# 12th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1416075527668, time elapsed: 0 h 42 m 15 s
# 13th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.1924103796482086, time elapsed: 0 h 45 m 54 s
# 14th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1811621338129044, time elapsed: 0 h 49 m 34 s
# 15th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.1616123020648956, time elapsed: 0 h 53 m 11 s
# 16th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.17094324529171, time elapsed: 0 h 56 m 46 s
# 17th repeat: best hidden unit: 256, best layers: 5, final eval loss: 1.1557669639587402, time elapsed: 1 h 0 m 24 s
# 18th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.1557907462120056, time elapsed: 1 h 4 m 2 s
# 19th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.1692192554473877, time elapsed: 1 h 7 m 45 s
# 20th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.160208135843277, time elapsed: 1 h 11 m 23 s
# 21th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.1713672131299973, time elapsed: 1 h 15 m 0 s
# 22th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.1545292139053345, time elapsed: 1 h 18 m 40 s
# 23th repeat: best hidden unit: 256, best layers: 3, final eval loss: 1.1647204160690308, time elapsed: 1 h 22 m 19 s
# 24th repeat: best hidden unit: 256, best layers: 1, final eval loss: 1.1658376455307007, time elapsed: 1 h 25 m 55 s
# 25th repeat: best hidden unit: 256, best layers: 7, final eval loss: 1.1897310316562653, time elapsed: 1 h 29 m 31 s
# 26th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.1818555146455765, time elapsed: 1 h 33 m 6 s
# 27th repeat: best hidden unit: 256, best layers: 8, final eval loss: 1.1686578392982483, time elapsed: 1 h 36 m 39 s
# 28th repeat: best hidden unit: 256, best layers: 2, final eval loss: 1.153528481721878, time elapsed: 1 h 40 m 17 s
# 29th repeat: best hidden unit: 256, best layers: 4, final eval loss: 1.170419156551361, time elapsed: 1 h 43 m 52 s
# 30th repeat: best hidden unit: 256, best layers: 6, final eval loss: 1.1639328598976135, time elapsed: 1 h 47 m 28 s

# %%
r, c = find_argmin_in_matrix(avg_final_eval_loss)
print(f'Best hidden unit: {hidden_dims[r]}, best layers: {n_layerss[c]}')
plot_3d_scatter(x=hidden_dims, y=n_layerss, z=avg_final_eval_loss,
               x_label='Hidden units', y_label='Layers', z_label='Average loss', fname='param_search_recur_lstm')
# Out:
# Best hidden unit: 256, best layers: 2

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=2, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])
# Out:
# Initial eval loss: 13.928428411483765
# Epoch 1: training loss 42.69041097164154, eval loss 2.4860836267471313. Time elapsed: 0 h 0 m 0 s.
# Epoch 2: training loss 21.867699712514877, eval loss 2.0355549454689026. Time elapsed: 0 h 0 m 0 s.
# Epoch 3: training loss 19.862395584583282, eval loss 1.9043523967266083. Time elapsed: 0 h 0 m 0 s.
# Epoch 4: training loss 18.50702866911888, eval loss 1.7685088515281677. Time elapsed: 0 h 0 m 0 s.
# Epoch 5: training loss 17.122821420431137, eval loss 1.6380216181278229. Time elapsed: 0 h 0 m 1 s.
# Epoch 6: training loss 15.963249117136002, eval loss 1.5424688458442688. Time elapsed: 0 h 0 m 1 s.
# Epoch 7: training loss 15.143390417098999, eval loss 1.474016159772873. Time elapsed: 0 h 0 m 1 s.
# Epoch 8: training loss 14.52387660741806, eval loss 1.4215799868106842. Time elapsed: 0 h 0 m 1 s.
# Epoch 9: training loss 14.04197233915329, eval loss 1.3792876303195953. Time elapsed: 0 h 0 m 1 s.
# Epoch 10: training loss 13.64703443646431, eval loss 1.344130426645279. Time elapsed: 0 h 0 m 2 s.
# Epoch 11: training loss 13.310323655605316, eval loss 1.3152247965335846. Time elapsed: 0 h 0 m 2 s.
# Epoch 12: training loss 13.032260239124298, eval loss 1.2918832153081894. Time elapsed: 0 h 0 m 2 s.
# Epoch 13: training loss 12.795710787177086, eval loss 1.2714675962924957. Time elapsed: 0 h 0 m 2 s.
# Epoch 14: training loss 12.58989492058754, eval loss 1.253747209906578. Time elapsed: 0 h 0 m 2 s.
# Epoch 15: training loss 12.407454580068588, eval loss 1.2373556047677994. Time elapsed: 0 h 0 m 3 s.
# Epoch 16: training loss 12.238140478730202, eval loss 1.2226959019899368. Time elapsed: 0 h 0 m 3 s.
# Epoch 17: training loss 12.081097424030304, eval loss 1.2093932628631592. Time elapsed: 0 h 0 m 3 s.
# Epoch 18: training loss 11.938679471611977, eval loss 1.1971245557069778. Time elapsed: 0 h 0 m 3 s.
# Epoch 19: training loss 11.806750103831291, eval loss 1.1851134151220322. Time elapsed: 0 h 0 m 3 s.
# Epoch 20: training loss 11.684126868844032, eval loss 1.1742120832204819. Time elapsed: 0 h 0 m 4 s.
# Epoch 21: training loss 11.57291592657566, eval loss 1.1648641526699066. Time elapsed: 0 h 0 m 4 s.
# Epoch 22: training loss 11.472971975803375, eval loss 1.1548513323068619. Time elapsed: 0 h 0 m 4 s.
# Epoch 23: training loss 11.377671375870705, eval loss 1.1477910876274109. Time elapsed: 0 h 0 m 4 s.
# Epoch 24: training loss 11.293162673711777, eval loss 1.1395786255598068. Time elapsed: 0 h 0 m 4 s.
# Epoch 25: training loss 11.210600450634956, eval loss 1.1316090822219849. Time elapsed: 0 h 0 m 5 s.
# Epoch 26: training loss 11.133634477853775, eval loss 1.1244865953922272. Time elapsed: 0 h 0 m 5 s.
# Epoch 27: training loss 11.060802951455116, eval loss 1.1171907186508179. Time elapsed: 0 h 0 m 5 s.
# Epoch 28: training loss 10.992152243852615, eval loss 1.1105115711688995. Time elapsed: 0 h 0 m 5 s.
# Epoch 29: training loss 10.921488180756569, eval loss 1.1046440303325653. Time elapsed: 0 h 0 m 6 s.
# Epoch 30: training loss 10.862240687012672, eval loss 1.0979728996753693. Time elapsed: 0 h 0 m 6 s.
# Epoch 31: training loss 10.79305499792099, eval loss 1.0927533656358719. Time elapsed: 0 h 0 m 6 s.
# Epoch 32: training loss 10.727781161665916, eval loss 1.0879782438278198. Time elapsed: 0 h 0 m 6 s.
# Epoch 33: training loss 10.67042875289917, eval loss 1.0814812928438187. Time elapsed: 0 h 0 m 6 s.
# Epoch 34: training loss 10.618191316723824, eval loss 1.0778996497392654. Time elapsed: 0 h 0 m 7 s.
# Epoch 35: training loss 10.56903725862503, eval loss 1.072456181049347. Time elapsed: 0 h 0 m 7 s.
# Epoch 36: training loss 10.525945842266083, eval loss 1.0692365616559982. Time elapsed: 0 h 0 m 7 s.
# Epoch 37: training loss 10.479720667004585, eval loss 1.0649760961532593. Time elapsed: 0 h 0 m 7 s.
# Epoch 38: training loss 10.439976781606674, eval loss 1.0617353171110153. Time elapsed: 0 h 0 m 7 s.
# Epoch 39: training loss 10.399951338768005, eval loss 1.057331621646881. Time elapsed: 0 h 0 m 8 s.
# Epoch 40: training loss 10.362423911690712, eval loss 1.0548180043697357. Time elapsed: 0 h 0 m 8 s.
# Epoch 41: training loss 10.329151421785355, eval loss 1.05186165869236. Time elapsed: 0 h 0 m 8 s.
# Epoch 42: training loss 10.300160735845566, eval loss 1.0495872795581818. Time elapsed: 0 h 0 m 8 s.
# Epoch 43: training loss 10.262697279453278, eval loss 1.0477736443281174. Time elapsed: 0 h 0 m 8 s.
# Epoch 44: training loss 10.231523245573044, eval loss 1.0436739027500153. Time elapsed: 0 h 0 m 9 s.
# Epoch 45: training loss 10.19925008714199, eval loss 1.0405258387327194. Time elapsed: 0 h 0 m 9 s.
# Epoch 46: training loss 10.167962729930878, eval loss 1.0380397140979767. Time elapsed: 0 h 0 m 9 s.
# Epoch 47: training loss 10.133929550647736, eval loss 1.0351769477128983. Time elapsed: 0 h 0 m 9 s.
# Epoch 48: training loss 10.103785395622253, eval loss 1.0327761769294739. Time elapsed: 0 h 0 m 10 s.
# Epoch 49: training loss 10.078832358121872, eval loss 1.0300067961215973. Time elapsed: 0 h 0 m 10 s.
# Epoch 50: training loss 10.049441576004028, eval loss 1.0281945914030075. Time elapsed: 0 h 0 m 10 s.
# Training completed with final epoch loss 10.049441576004028. Time elapsed: 0 h 0 m 10 s.

# %% [markdown]
# ##### c) Testing against predicting the mean

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))
print('Predicting mean MSE error on test set', F.mse_loss(torch.mean(Y_test, dim=0).repeat([1000,1,1]), Y_test))

# %%
print('DNN prediction MSE error on test set: ', F.mse_loss(Y_hats, Y_test))

# %% [markdown]
# ### Complex BNN

# %%
X_train, Y_train = load_data('./data/', 'abnn_cplx_train_256_0.5_4_0.5.pkl')
X_test, Y_test = load_data('./data/', 'abnn_cplx_test_256_0.5_4_0.5.pkl')
X_valid, Y_valid = load_data('./data/', 'abnn_cplx_valid_256_0.5_4_0.5.pkl')

batch_size = 200   # number of data points in each mini-batch
n_train = 10000    # number of data used, from 1 to len(X_train)
n_epochs = 50      # number of training epochs

train_dataset = BNN_Dataset(X_train[:n_train], Y_train[:n_train])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

test_dataset = BNN_Dataset(X_test, Y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

valid_dataset = BNN_Dataset(X_valid, Y_valid)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### 1. Using MLP

# %% [markdown]
# ##### a) Parameter search

# %%
_X_train = X_train.view(-1, 16)
_Y_train = Y_train.view(-1, 16)
_X_test = X_test.view(-1, 16)
_Y_test = Y_test.view(-1, 16)

_train_dataset = BNN_Dataset(_X_train, _Y_train)
_train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

_test_dataset = BNN_Dataset(_X_test, _Y_test)
_test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'FF', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %% [markdown]
# ##### b) Learning with best parameter

# %% [markdown]
# ##### c) Testing against predicting the mean

# %% [markdown]
# #### 2. Using RNN

# %% [markdown]
# ##### a) Parameter search

# %%
hidden_dims=[2, 4, 8, 16, 32, 64, 128, 256]
n_layerss=[1, 2, 3, 4, 5, 6, 7, 8]

avg_final_eval_loss = repeated_param_grid_search(
    hidden_dims, n_layerss, n_repeats=30, **{'_type':'RNN', 'train_loader':train_dataloader, 'valid_loader':valid_dataloader, 'test_loader':test_dataloader, 'n_epochs':n_epochs})

# %% [markdown]
# ##### b) Learning with best parameter

# %%
v_idx = np.random.randint(0, len(Y_test)) # a random label in the test set to visualise

# deep learning model
DNN = RecurrentDNN(input_dim=16, hidden_dim=256, n_linear_layers=2, output_dim=16, n_lstm_layers=1).to(device)

# training parameters
optimiser = torch.optim.Adam(DNN.parameters(), lr=1e-3)
criterion = nn.MSELoss()

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)

visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

train_losses, eval_losses = train_rnn(
    model=DNN,
    train_loader=train_dataloader, test_loader=test_dataloader,
    optimiser=optimiser, criterion=criterion, num_epochs=n_epochs,
    verbose=True, force_stop=False)

plot_loss_curves(train_losses, eval_losses, loss_func='MSE Loss')

_, Y_hats = eval_rnn(DNN, test_dataloader, criterion, save_Y_hat=True)
visualise_prediction(Y_test[v_idx,0,:], Y_hats[v_idx,0,:])

# %% [markdown]
# ##### c) Testing against predicting the mean

# %% [markdown]
# ## BVC Simulation

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F

import numpy as np
import time
import seaborn as sns

from models import *
from utils import *
from train import *
from bvc import *

sns.set(font_scale=1.2)
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class RectangleEnvironment:
    '''
    Rectangular environment to obtain BVC and PC firing rates
    '''
    def __init__(self, l, w):
        self.l = torch.Tensor([l]) # maximum length
        self.w = torch.Tensor([w]) # maximum width
        self.aspect_ratio = l / w
        
    def compute_wall_dist(self, loc):
        '''
        Calculates the distances, bearings and subtended angles of a rat location
        returns distances, bearings, angles. Each list of length 4
        left/up - positive dist, right/down - negative dist
        '''
        x, y = loc
        x = torch.Tensor([x]) if not isinstance(x, torch.Tensor) else x
        y = torch.Tensor([y]) if not isinstance(y, torch.Tensor) else y
        assert torch.any(x) > 0 and torch.any(x) < self.l
        assert torch.any(y) > 0 and torch.any(y) < self.w
        
        distances, bearings, angles = [], [], []
        
        # up wall
        distances.append(y)
        bearings.append(0 * torch.pi)
        angles.append(torch.arctan(x/y) + torch.arctan((self.l-x)/y))

        # right wall
        distances.append(self.l - x)
        bearings.append(1/2 * torch.pi)
        angles.append(torch.arctan(y/(self.l-x)) + torch.arctan((self.w-y)/(self.l-x)))
        
        # down wall
        distances.append(self.w - y)
        bearings.append(1 * torch.pi)
        angles.append(torch.arctan(x/(self.w-y)) + torch.arctan((self.l-x)/(self.w-y)))

        # left wall
        distances.append(x)
        bearings.append(3/2* torch.pi)
        angles.append(torch.arctan(y/x) + torch.arctan((self.w-y)/x))
        
        return distances, bearings, angles

    def visualise_bvc_firing_rate(self, bvc, n=100):
        x, y = torch.meshgrid(
            torch.linspace(1e-3, self.l.item()-1e-3, n),
            torch.linspace(1e-3, self.w.item()-1e-3, n))
        distances, bearings, angles = self.compute_wall_dist((x,y))
        firing_rates = bvc.obtain_net_firing_rate(distances, bearings, angles)
        
        plt.figure(figsize=(6, 6/self.aspect_ratio))
        plt.scatter(x, self.w-y, c= firing_rates)
        plt.show()

# %%
class BVC:
    '''
    A boundary vector cell with preferred distance and angle
    Hartley 2000: sigma_ang = 0.2 fixed, sigma_rad = [(peak_dist/beta)+1]*sigma_zero where sigma_zerp speifies sigma for zero distances and
    beta controls the rate at which sigma_rad increases
    Defaults - all distances in mm
    '''
    def __init__(self, r, theta, sigma_zero=122, beta=1830, sigma_ang=0.2, scaling_factor=1) -> None:
        self.r = torch.Tensor([r])
        self.theta = torch.Tensor([theta])
        self.sigma_zero = sigma_zero                        # Hartley 2000: sigZero = 122 mm
        self.beta = beta                                    # Hartley 2000: beta = 1830 mm
        self.sigma_ang = torch.Tensor([sigma_ang])          # Hartley 2000: angSig = 0.2 rad
        self.sigma_rad = torch.Tensor([((self.r/self.beta)+1) * self.sigma_zero])
        self.scaling_factor = scaling_factor

    def obtain_firing_rate_single_boundary(self, d, phi):
        '''
        Computes the firing of BVC given a current distance and angle to a single boundary.
        Firing rate is proportional to product of two gaussians centerred at the preferred distance and angle
        Vectorised: d and phi can be arrays or matricesd
        '''
        unscaled_firing_rate = torch.exp(-(self.r - d) ** 2 / (2 * self.sigma_rad ** 2))/ \
                torch.sqrt(2 * torch.pi * self.sigma_rad ** 2) * \
                    torch.exp(-(self.theta - phi) ** 2 / (2 * self.sigma_ang ** 2))/ \
                        torch.sqrt(2 * torch.pi * self.sigma_ang ** 2)
        
        return unscaled_firing_rate
    
    def obtain_net_firing_rate(self, distances, bearings, subtended_angles):
        '''
        A section of wall at distance r, bearing theta, subtending a angle dtheta at the rat contributes
        dfi = gi(r, theta) * dtheta
        The firing rate is found by integrating to find the net contribution of all the environment's boundaries
        '''
        n_boundaries = len(distances)
        net_unscaled_firing_rates = torch.stack([self.obtain_firing_rate_single_boundary(distances[i], bearings[i]) for i in range(n_boundaries)], dim=0)
        # print(net_unscaled_firing_rates)
        subtended_angles = torch.stack(subtended_angles, dim=0)
        return self.scaling_factor * torch.sum(torch.multiply(net_unscaled_firing_rates, subtended_angles), dim=0)

l = 80
w = 80
env = RectangleEnvironment(l, w)
bvc1 = BVC(80, 0*torch.pi)
bvc2 = BVC(50, 1/2*torch.pi)
bvc3 = BVC(50, 0.8*torch.pi)
plot_bvc_firing_field([bvc3], max_d=800)
distances, bearings, angles = env.compute_wall_dist((70,50))
bvc3.obtain_net_firing_rate(distances, bearings, angles)
# Out:
# tensor([6.7310e-05])

# %%
env.visualise_bvc_firing_rate(bvc3)
